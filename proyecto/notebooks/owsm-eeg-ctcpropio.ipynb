# %% [markdown]
# # OWSM + sEEG (B2T'25) — versión Google Colab con barrido de experimentos
#
# Adaptación del notebook local para Colab. Cambios principales respecto a la versión local:
#
# ## Novedades de esta versión (v4): objetivo CTC de caracteres
#
# `gen1` cerró el diagnóstico: el modelo memoriza una sesión (`overfit` → `cer_ctc` 0.117) pero no generaliza ni dentro de un solo día (`gen1`, misma sesión y solo validación real → se atasca en 0.75, `valid_loss_ctc` sube de 49 a 120). Con una sola sesión no hay deriva ni confusión entre días de por medio, así que la causa queda aislada: **no se puede aprender un mapeo neuronal → 50.002 clases BPE con ~348 frases.**
#
# Esta versión añade un objetivo CTC de **caracteres** (~32 clases en vez de 50.002):
#
# | | BPE (lo anterior) | Caracteres (nuevo) |
# |---|---|---|
# | objetivo del CTC | subpalabras de OWSM | letras `a-z`, apóstrofo, espacio |
# | nº de clases | 50.002 | 32 |
# | tokenizado | `tokenizer.text2tokens` | letra a letra |
# | cabeza `ctc_lo` | `Linear(384, 50002)` heredada | `Linear(384, 32)` desde cero |
# | `cer_ctc` del log | CER sobre BPE | CER sobre caracteres |
#
# Se activa con `objetivo_ctc="char"` en el panel. **Cambia solo el objetivo del CTC**: el decoder de atención de OWSM sigue en BPE (por eso con `char` se omite el beam search híbrido — CTC y decoder tendrían vocabularios distintos —, y la evaluación es CTC greedy, que es justo la métrica honesta que interesa aquí).
#
# **Aviso de interpretación:** `cer_ctc` en modo char es CER de caracteres, no de BPE. No se compara en valor absoluto con las tablas de `overfit`/`gen1`. Lo que sí es comparable es la historia: cuánto memoriza (`charOverfit`) frente a cuánto generaliza (`charGen1`), y si el salto respecto a `gen1`=0.75 confirma que las 50k clases eran el cuello de botella.
#
# Nota sobre POWSM: existe un modelo hermano, `espnet/powsm`, misma arquitectura que OWSM v3.1 pero preentrenado en tareas de fonos (reconocimiento de fonemas, G2P). Es el candidato natural para la fase de fonemas más adelante — se enchufaría cambiando solo el string del modelo. Hoy no se toca.
#
# ## Cómo usarlo
#
# 1. **Entorno de ejecución → Cambiar tipo de entorno de ejecución → GPU L4**. Marca *High RAM* solo si vas a usar `n_sessions >= 30` con `PRELOAD_RAM = True`.
# 2. Comprueba que `DRIVE_DATA` (celda 1) apunta a tu carpeta `hdf5_data_final` en Drive.
# 3. Ejecuta las celdas 0 a 10 en orden. Reinicia el entorno cuando te lo pida la celda de instalación.
# 4. Edita la lista `BARRIDO` (celda 11) y lanza la celda 12.
#
# Los resultados se van acumulando en `resultados.csv` en tu Drive: si Colab te desconecta, vuelves a lanzar y se salta los experimentos ya hechos.

# %% [markdown]
# ## 0. Instalación
#
# Ejecuta esta celda, **reinicia el entorno** (`Entorno de ejecución → Reiniciar sesión`) y continúa desde la celda 1. Si no reinicias, numpy se queda cargado en la versión antigua y aparecen errores de tipos difíciles de diagnosticar.

# %%
# !nvidia-smi

# Instalación (~3 min la primera vez).
# Truco para sesiones siguientes: descarga las ruedas a Drive una sola vez con
#   !pip download -q espnet espnet_model_zoo loralib h5py -d /content/drive/MyDrive/TFG/wheels
# y luego instala offline en ~20 s con
#   !pip install -q --no-index --find-links=/content/drive/MyDrive/TFG/wheels espnet espnet_model_zoo loralib h5py
# !pip install -q espnet espnet_model_zoo loralib h5py

import torch
print("PyTorch:", torch.__version__, "| CUDA disponible:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("SIN GPU: revisa Entorno de ejecucion > Cambiar tipo de entorno de ejecucion")
print("\n>>> REINICIA EL ENTORNO AHORA y sigue desde la celda 1 <<<")
# Out:
# Fri Jul 31 00:20:46 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   42C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 29.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 kB 20.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 97.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 86.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 107.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 64.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 69.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 120.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 61.8 MB/s eta 0:00:00
#   Building wheel for fast-bss-eval (setup.py) ... done
#   Building wheel for pyworld (pyproject.toml) ... done
#   Building wheel for ci_sdr (setup.py) ... done
#   Building wheel for distance (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# PyTorch: 2.11.0+cu128 | CUDA disponible: True
# GPU: NVIDIA L4
#
# >>> REINICIA EL ENTORNO AHORA y sigue desde la celda 1 <<<

# %% [markdown]
# ## 1. Panel de control
#
# Todo lo configurable vive aquí. `DEFAULTS` son los valores base de un experimento; en el barrido (celda 11) solo indicas lo que cambia respecto a estos.

# %%
# ══ RUTAS ══════════════════════════════════════════════════════════
DRIVE_ROOT  = "/content/drive/MyDrive/TFG"                       # <<< tu carpeta en Drive
DRIVE_DATA  = f"{DRIVE_ROOT}/DatosEEG_crudos/hdf5_data_final"    # <<< donde estan los HDF5
DATA_ROOT   = "/content/data/hdf5_data_final"    # cache en el disco local de la VM
OUTPUT_DIR  = "/content/exp"                     # checkpoints en local, NO en Drive
RESULTS_DIR = f"{DRIVE_ROOT}/resultados"         # solo lo que quieres conservar

# ══ MODELO ═════════════════════════════════════════════════════════
FINETUNE_MODEL = "espnet/owsm_v3.1_ebf_base"       # ~101M params
LANGUAGE       = "eng"
LORA_TARGET    = ["w_1", "w_2", "merge_proj", "linear_q", "linear_k", "linear_v", "linear_out"]

# ══ DATOS ══════════════════════════════════════════════════════════
PRELOAD_RAM   = False   # False = lectura perezosa del HDF5 (seguro con 45 sesiones)
                        # True  = todo en RAM (~1.6 MB/trial; necesita High RAM si n_sessions>25)
SOLO_SESIONES_COMPLETAS = True   # ignora sesiones sin data_val.hdf5 (p.ej. t15.2023.08.11)

# ══ EVALUACION ═════════════════════════════════════════════════════
EVAL_N    = 50    # trials de validacion sobre los que calcular CER/WER al final de cada run
BEAM_SIZE = 5
EVAL_GREEDY_CTC = True   # ademas del beam search, decodificacion CTC greedy (metrica honesta:
                         # no pasa por el decoder, asi que no puede "hacer trampa" con el
                         # prior del ingles preentrenado)

# ══ CONTROL DEL BARRIDO ════════════════════════════════════════════
SKIP_IF_DONE = True    # no repetir experimentos ya presentes en resultados.csv
GUARDAR_CKPT = False   # copiar el mejor .pth a Drive (~470 MB por experimento)

# ══ VALORES POR DEFECTO DE UN EXPERIMENTO ══════════════════════════
DEFAULTS = dict(
    nombre        = "base",     # etiqueta legible para las tablas de la memoria
    n_sessions    = 10,         # 45 disponibles
    max_epoch     = 30,
    warmup        = 100,
    val_igual_train = False,    # True = test de sobreajuste (val == train)

    frontend      = "conv2d",   # "conv2d" | "linear" | "conv1d"
    objetivo_ctc  = "bpe",      # "bpe"  = tokens BPE de OWSM (50.002 clases; el original)
                                # "char" = caracteres (~32 clases). Cambia SOLO el objetivo
                                #          del CTC; el decoder de atencion sigue en BPE.
    capa_sesion   = False,      # True = transformada afin por sesion + softsign delante del
                                # frontend (es LA caracteristica del baseline de B2T'25: la
                                # senal del mismo fonema cambia de un dia a otro por deriva
                                # de los electrodos, y 45 sesiones abarcan 20 meses)
    norm          = "trial",    # "trial"  = z-score por trial y canal (lo que hacias)
                                # "ninguna"= usar los HDF5 tal cual (ya vienen z-scoreados
                                #            por bloque; los trabajos publicados no renormalizan)
    unfreeze_encoder = True,
    unfreeze_n_layers = None,   # None = encoder entero; int = solo las N primeras capas
    usar_lora     = True,

    batch_type    = "sorted",   # "sorted" (batch_size) | "numel" (batch_bins)
    batch_size    = 16,
    batch_bins    = 6_000_000,
    accum_grad    = 1,

    lr            = 1e-3,
    enc_lr_scale  = 1.0,        # <1.0 = LR menor para el encoder preentrenado (p.ej. 0.01)
    weight_decay  = 1e-6,
    grad_clip     = 5.0,
    ctc_weight    = 0.3,        # ahora SI afecta al loss de entrenamiento
    ctc_weight_decode = None,   # None = mismo que ctc_weight
    seed          = 2024,
    criterio      = "cer_ctc",  # metrica con la que se elige el mejor checkpoint.
                                # "cer_ctc" = la del sEEG. "loss" = la total, que con
                                # ctc_weight bajo es sobre todo perdida de atencion y
                                # toca fondo en 4-5 epocas por el prior del ingles.
    num_workers   = 0,          # 0 = sin fork. Con HDF5 es lo mas seguro y no cuesta
                                # nada: el modelo es compute-bound y los datos estan en
                                # disco local. Sube a 2 solo si ves la GPU esperando.
)

print("Panel cargado.")
# Out:
# Panel cargado.

# %% [markdown]
# ## 2. Drive y datos
#
# Tus HDF5 ya están en Drive, así que solo hay que montarlo. Lo que **no** conviene es entrenar leyendo directamente de `/content/drive`: Drive limita las operaciones de E/S por fichero y acaba dando `OSError: [Errno 5] Input/output error` a mitad de una época.
#
# La solución es una caché: las sesiones se copian de Drive al disco local de la VM **solo cuando un experimento las necesita**. Si el barrido empieza con 2 sesiones, se copian 2 (unos segundos) y no las 45.
#
# Esta celda solo monta Drive y comprueba qué hay. La copia ocurre sola más adelante.

# %%
import os, time, shutil, glob

from google.colab import drive
drive.mount("/content/drive")

os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(DATA_ROOT, exist_ok=True)

# Localizar la carpeta de datos aunque este en otro sitio dentro de DRIVE_ROOT
if not os.path.isdir(DRIVE_DATA):
    print(f"No esta en {DRIVE_DATA}; buscando 'hdf5_data_final' bajo {DRIVE_ROOT} ...")
    cands = glob.glob(f"{DRIVE_ROOT}/**/hdf5_data_final", recursive=True)
    if cands:
        DRIVE_DATA = cands[0]
        print("Encontrada:", DRIVE_DATA)
    else:
        raise FileNotFoundError(
            f"No encuentro la carpeta hdf5_data_final dentro de {DRIVE_ROOT}.\n"
            f"Ajusta DRIVE_ROOT / DRIVE_DATA en el panel de control."
        )

# Inventario: que sesiones hay y cuales tienen train Y val
inventario, sin_val, bytes_tot = [], [], 0
for s in sorted(os.listdir(DRIVE_DATA)):
    d = os.path.join(DRIVE_DATA, s)
    if not os.path.isdir(d):
        continue
    tr = os.path.join(d, "data_train.hdf5")
    va = os.path.join(d, "data_val.hdf5")
    if not os.path.exists(tr):
        continue
    inventario.append(s)
    if not os.path.exists(va):
        sin_val.append(s)
    bytes_tot += os.path.getsize(tr) + (os.path.getsize(va) if os.path.exists(va) else 0)

print(f"\n{len(inventario)} sesiones con data_train.hdf5 · {bytes_tot/1e9:.1f} GB (train+val)")
if sin_val:
    print(f"{len(sin_val)} sin data_val.hdf5: {sin_val}")
    print("  -> con SOLO_SESIONES_COMPLETAS=True se ignoran (evita que train y val no cuadren)")
print("\nPrimeras sesiones:", inventario[:5])
print("Disco libre en la VM:")
os.system("df -h /content | tail -1")
# Out:
# Mounted at /content/drive
#
# 45 sesiones con data_train.hdf5 · 11.2 GB (train+val)
# 4 sin data_val.hdf5: ['t15.2023.08.11', 't15.2024.03.03', 't15.2024.04.25', 't15.2024.04.28']
#   -> con SOLO_SESIONES_COMPLETAS=True se ignoran (evita que train y val no cuadren)
#
# Primeras sesiones: ['t15.2023.08.11', 't15.2023.08.13', 't15.2023.08.18', 't15.2023.08.20', 't15.2023.08.25']
# Disco libre en la VM:
# 0

# %% [markdown]
# ## 3. Imports, dispositivo y utilidades

# %%
import string, re, glob, argparse, logging, gc, copy, json, math
import h5py
import numpy as np
import pandas as pd
import torch
import loralib

import espnetez as ez
from espnet2.bin.s2t_inference import Speech2Text
from espnet2.layers.create_adapter_fn import create_lora_adapter
from espnet.nets.pytorch_backend.transformer.subsampling import Conv2dSubsampling

os.environ["HF_HUB_DOWNLOAD_TIMEOUT"] = "120"

DEVICE  = "cuda" if torch.cuda.is_available() else "cpu"
NGPU    = 1 if torch.cuda.is_available() else 0
USE_AMP = torch.cuda.is_available()

GPU_NAME = torch.cuda.get_device_name(0) if NGPU else "CPU"

# Tarifas aproximadas de compute units/hora (medidas en marzo de 2026; pueden variar)
TARIFAS = {"T4": 1.19, "L4": 1.71, "A100-SXM4-40GB": 5.40, "A100-SXM4-80GB": 7.52,
           "RTX PRO 6000": 8.71, "H100": 9.0}
def units_por_hora(nombre_gpu):
    for k, v in TARIFAS.items():
        if k.lower().replace("-", " ") in nombre_gpu.lower().replace("-", " "):
            return v
    return float("nan")
CU_H = units_por_hora(GPU_NAME)

print(f"Dispositivo: {DEVICE} · {GPU_NAME} · AMP: {USE_AMP}")
print(f"Coste estimado: {CU_H} compute units/hora (~${CU_H*0.10:.2f}/h)")


def normaliza(x, modo="trial"):
    """Normalizacion de la senal sEEG antes de entrar al modelo.

    Los HDF5 de B2T'25 ya vienen binneados a 20 ms y z-scoreados por bloque, asi que
    "ninguna" reproduce lo que hacen los trabajos publicados; "trial" vuelve a normalizar
    por trial y canal (util para comparar, pero borra la amplitud relativa entre trials).
    """
    x = x.astype(np.float32)
    if modo == "ninguna":
        return x
    return (x - x.mean(axis=0, keepdims=True)) / (x.std(axis=0, keepdims=True) + 1e-8)

def remove_punctuation(text):
    return text.translate(str.maketrans("", "", string.punctuation))

def decode_transcription(arr):
    arr = np.asarray(arr).ravel()
    return "".join(chr(int(x)) for x in arr if int(x) != 0)
# Out:
# Failed to import Flash Attention, using ESPnet default: No module named 'flash_attn'
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# /usr/local/lib/python3.12/dist-packages/espnet2/enh/encoder/stft_encoder.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /usr/local/lib/python3.12/dist-packages/espnet2/enh/layers/uses2_swin.py:329: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# Dispositivo: cuda · NVIDIA L4 · AMP: True
# Coste estimado: 1.71 compute units/hora (~$0.17/h)

# %% [markdown]
# ## 4. Datasets (carga perezosa)
#
# `SeeGDataset` guarda solo un **índice** `(fichero, clave)` y lee cada trial del HDF5 cuando hace falta. Así las 45 sesiones (~17 GB en float32) no tienen que caber en RAM. El handle de h5py se reabre por proceso para que funcione con `num_workers > 0`.
#
# Con `PRELOAD_RAM = True` vuelve al comportamiento local (todo en memoria), que es algo más rápido si tienes RAM de sobra.

# %%
class SeeGDataset(torch.utils.data.Dataset):
    """Lee trials del HDF5 bajo demanda. Si preload=True los cachea todos en RAM."""

    def __init__(self, index, preload=False):
        self.index = index          # [(ruta_hdf5, clave), ...]
        self.preload = preload
        self._files = {}
        self._pid = os.getpid()
        self._cache = None
        if preload:
            self._cache = [self._leer(i) for i in range(len(index))]
            self.cerrar()

    def _handle(self, path):
        if os.getpid() != self._pid:      # tras un fork, los handles del padre no valen
            self._files, self._pid = {}, os.getpid()
        if path not in self._files:
            self._files[path] = h5py.File(path, "r")
        return self._files[path]

    def cerrar(self):
        """Cierra los handles. IMPRESCINDIBLE antes de que el DataLoader haga fork:
        la libreria HDF5 no es fork-safe y heredar handles abiertos puede colgar el proceso."""
        for f in self._files.values():
            try: f.close()
            except Exception: pass
        self._files = {}

    def _leer(self, idx):
        path, key, sid = self.index[idx]
        t = self._handle(path)[key]
        return {"input_features": t["input_features"][:],
                "text_raw": decode_transcription(t["transcription"][()]),
                "session_idx": sid}

    def __len__(self):
        return len(self.index)

    def __getitem__(self, idx):
        d = self._cache[idx] if self._cache is not None else self._leer(idx)
        text_lower = d["text_raw"].lower()
        return {
            "input_features": d["input_features"],
            "session_idx": d["session_idx"],
            "text":      f"<{LANGUAGE}><asr><notimestamps> {text_lower}",
            "text_prev": "<na>",
            "text_ctc":  remove_punctuation(text_lower),
            "text_raw":  d["text_raw"],
        }


def construir_indice(sesiones, split):
    """Recorre las claves de cada HDF5 sin leer los datos.

    Cada entrada es (ruta, clave, indice_de_sesion). El indice es la posicion en la
    lista `sesiones`, la misma para train y val, y es lo que consume la capa por sesion.
    """
    index = []
    for sid, s in enumerate(sesiones):
        path = os.path.join(DATA_ROOT, s, f"data_{split}.hdf5")
        if not os.path.exists(path):
            print(f"  [aviso] no encontrado: {path}")
            continue
        with h5py.File(path, "r") as f:
            index.extend((path, k, sid) for k in sorted(f.keys()))
    return index


def sesiones_disponibles():
    """Sesiones utilizables, listadas desde Drive (la fuente de la verdad)."""
    out = []
    for s in sorted(os.listdir(DRIVE_DATA)):
        d = os.path.join(DRIVE_DATA, s)
        if not os.path.isdir(d) or not os.path.exists(os.path.join(d, "data_train.hdf5")):
            continue
        if SOLO_SESIONES_COMPLETAS and not os.path.exists(os.path.join(d, "data_val.hdf5")):
            continue
        out.append(s)
    return out


def copiar_sesion(sesion):
    """Trae data_train/data_val de esa sesion al disco local de la VM (solo la primera vez)."""
    src = os.path.join(DRIVE_DATA, sesion)
    dst = os.path.join(DATA_ROOT, sesion)
    os.makedirs(dst, exist_ok=True)
    for split in ("train", "val"):
        f_src = os.path.join(src, f"data_{split}.hdf5")
        f_dst = os.path.join(dst, f"data_{split}.hdf5")
        if os.path.exists(f_src) and not os.path.exists(f_dst):
            shutil.copy(f_src, f_dst)      # data_test.hdf5 no se copia: no tiene etiquetas
    return dst


def elegir_sesiones(n_sessions):
    ses = sesiones_disponibles()[:n_sessions]
    faltan = [s for s in ses
              if not os.path.exists(os.path.join(DATA_ROOT, s, "data_train.hdf5"))]
    if faltan:
        print(f"Copiando {len(faltan)} sesion(es) de Drive al disco local de la VM...")
        t0 = time.time()
        for i, s in enumerate(faltan, 1):
            copiar_sesion(s)
            print(f"  [{i}/{len(faltan)}] {s}")
        print(f"  copiadas en {time.time()-t0:.0f}s")
    return ses


_CACHE_DATOS = {}

def get_datos(cfg):
    """Devuelve (train_raw, val_raw, stats_dir, n_sesiones_reales).

    La clave de cache incluye todo lo que cambia la FORMA del tensor de entrada
    (capa_sesion anade un canal: 512 -> 513), porque los shape files de ESPnet
    dejan de valer si eso cambia.
    """
    n_sessions      = cfg["n_sessions"]
    val_igual_train = cfg["val_igual_train"]
    clave = (n_sessions, val_igual_train, PRELOAD_RAM, cfg["capa_sesion"], cfg["objetivo_ctc"])
    if clave in _CACHE_DATOS:
        return _CACHE_DATOS[clave]

    sesiones = elegir_sesiones(n_sessions)
    print(f"Sesiones ({len(sesiones)}): {sesiones[:3]}{' ...' if len(sesiones) > 3 else ''}")
    idx_train = construir_indice(sesiones, "train")
    idx_val   = idx_train if val_igual_train else construir_indice(sesiones, "val")

    train_raw = SeeGDataset(idx_train, preload=PRELOAD_RAM)
    val_raw   = train_raw if val_igual_train else SeeGDataset(idx_val, preload=PRELOAD_RAM)

    stats_dir = (f"{OUTPUT_DIR}/stats_n{n_sessions}"
                 f"{'_vt' if val_igual_train else ''}"
                 f"{'_sess' if cfg['capa_sesion'] else ''}"
                 f"{'_char' if cfg['objetivo_ctc'] == 'char' else ''}")
    print(f"Train: {len(idx_train)} trials · Val: {len(idx_val)} trials")

    _CACHE_DATOS[clave] = (train_raw, val_raw, stats_dir, len(sesiones))
    return _CACHE_DATOS[clave]


# Comprobacion rapida: copia UNA sesion y lee un trial
_ses = sesiones_disponibles()[:1]
assert _ses, "No hay sesiones utilizables; revisa DRIVE_DATA y SOLO_SESIONES_COMPLETAS"
copiar_sesion(_ses[0])
_ds = SeeGDataset(construir_indice(_ses, "train"))
_it = _ds[0]
_x  = _it["input_features"]
print(f"\nSesion de prueba: {_ses[0]} ({len(_ds)} trials)")
print("text    :", _it["text"])
print("text_ctc:", _it["text_ctc"])
print("features:", _x.shape, _x.dtype)
# Los HDF5 de B2T'25 ya vienen z-scoreados por bloque: si esto ya esta cerca de (0, 1),
# volver a normalizar por trial (norm="trial") borra la amplitud relativa entre trials.
print(f"estadisticas del HDF5 crudo: media={_x.mean():+.3f} std={_x.std():.3f} "
      f"min={_x.min():+.2f} max={_x.max():+.2f}")
# Out:
# Sesion de prueba: t15.2023.08.13 (348 trials)
# text    : <eng><asr><notimestamps> which is most unfortunate because we all lose out.
# text_ctc: which is most unfortunate because we all lose out
# features: (1023, 512) float32
# estadisticas del HDF5 crudo: media=-0.000 std=0.999 min=-2.64 max=+10.00

# %% [markdown]
# ## 5. Tokenizador y configuración base de OWSM
#
# Se carga el modelo preentrenado **una sola vez** por sesión: de él salen el tokenizador, la config base y una copia de los pesos que reutilizan todos los experimentos.

# %%
pretrained = Speech2Text.from_pretrained(FINETUNE_MODEL, lang_sym=f"<{LANGUAGE}>", beam_size=5)
pretrain_config = vars(pretrained.s2t_train_args)
tokenizer = pretrained.tokenizer
converter = pretrained.converter
_pretrained_state_dict = {k: v.cpu().clone() for k, v in pretrained.s2t_model.state_dict().items()}
del pretrained
gc.collect()

def tokenize(text):
    return np.array(converter.tokens2ids(tokenizer.text2tokens(text)), dtype=np.int64)

BLANK_ID = converter.token_list.index("<blank>") if "<blank>" in converter.token_list else 0

# ── Vocabulario de caracteres para el objetivo CTC alternativo ──────────────
# Solo lo que aparece en las transcripciones de B2T'25 (ingles en minusculas, sin
# puntuacion). El indice 0 se reserva para el blank de CTC.
_CHARS = list("abcdefghijklmnopqrstuvwxyz'") + [" "]
CHAR_BLANK_ID = 0
_CHAR2ID = {c: i + 1 for i, c in enumerate(_CHARS)}      # 0 = blank
_ID2CHAR = {i + 1: c for i, c in enumerate(_CHARS)}
CHAR_VOCAB = len(_CHARS) + 1                              # +1 por el blank

def tokenize_char(text):
    """Trocea en caracteres. Ignora cualquier simbolo fuera del vocabulario."""
    return np.array([_CHAR2ID[c] for c in text.lower() if c in _CHAR2ID], dtype=np.int64)

def destok_char(ids):
    """De ids de caracteres a texto (ya sin blanks; el colapso CTC se hace fuera)."""
    return "".join(_ID2CHAR[i] for i in ids if i in _ID2CHAR)


def objetivo_info(cfg):
    """Devuelve (funcion_tokenizar, id_del_blank, tam_vocab, destok) segun el objetivo."""
    if cfg["objetivo_ctc"] == "char":
        return tokenize_char, CHAR_BLANK_ID, CHAR_VOCAB, destok_char
    return tokenize, BLANK_ID, len(converter.token_list), \
           (lambda ids: tokenizer.tokens2text(converter.ids2tokens(list(ids))))


def preparar_speech(d, cfg):
    """Tensor de entrada al modelo: (T, 512) o (T, 513) si hay capa por sesion.

    El indice de sesion viaja como un canal extra constante. Es la forma menos invasiva
    de meterlo: el pipeline de ESPnet solo transporta 'speech', y el padding va al final
    (con ceros), asi que el frame 0 siempre es dato real y de ahi lo lee el frontend.
    """
    x = normaliza(d["input_features"], cfg["norm"])
    if cfg["capa_sesion"]:
        sid = np.full((x.shape[0], 1), float(d["session_idx"]), dtype=np.float32)
        x = np.concatenate([x, sid], axis=1)
    return x


def make_data_info(cfg):
    # text y text_prev SIEMPRE en BPE: alimentan el decoder de atencion de OWSM.
    # text_ctc usa el tokenizador del objetivo elegido (BPE o caracteres).
    tok_ctc, _, _, _ = objetivo_info(cfg)
    return {
        "speech":    lambda d: preparar_speech(d, cfg),
        "text":      lambda d: tokenize(d["text"]),
        "text_prev": lambda d: tokenize(d["text_prev"]),
        "text_ctc":  lambda d: tok_ctc(d["text_ctc"]),
    }

print("Tokenizador y config base cargados")
print("  ctc_weight original de OWSM:", pretrain_config.get("model_conf", {}).get("ctc_weight"))
print(f"  BPE: {len(converter.token_list)} clases (blank id {BLANK_ID}) · "
      f"caracteres: {CHAR_VOCAB} clases (blank id {CHAR_BLANK_ID})")
# Out:
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 29 files:   0%|          | 0/29 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Tokenizador y config base cargados
#   ctc_weight original de OWSM: 0.3
#   BPE: 50002 clases (blank id 0) · caracteres: 29 clases (blank id 0)

# %% [markdown]
# ## 6. Construcción del modelo
#
# Tres arreglos respecto a la versión local:
#
# 1. **`ctc_weight` se inyecta en `model_conf`.** Antes el modelo se construía desde `pretrain_config`, así que el peso del CTC en el loss era siempre el 0.3 de OWSM, dijeras lo que dijeras en el panel. (Se veía en los logs: `0.3·loss_ctc + 0.7·loss_att = loss`.)
# 2. **`usar_lora` es opcional**, para poder comparar con/sin adaptadores.
# 3. **`enc_lr_scale`** parchea `build_optimizers` para poner el encoder preentrenado en un grupo de parámetros con LR más bajo. Con Adam no vale escalar gradientes (es invariante a escala), hace falta grupos de verdad.
#
# **Nota sobre los frontends `linear`/`conv1d`:** heredan de `Conv2dSubsampling` aunque no usen su `__init__`. Es necesario porque el encoder de ESPnet decide si pasarle la máscara de padding al frontend mirando `isinstance(self.embed, Conv2dSubsampling)`; si la clase no hereda de ahí, ESPnet asume que es un embedding que no cambia la longitud de la secuencia (como un `nn.Embedding` de texto) y lo llama sin máscara, lo que revienta con `TypeError: forward() missing 1 required positional argument: 'x_mask'`.

# %%
def count_trainable(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable

def freeze_all(model):
    for p in model.parameters():
        p.requires_grad = False


def _subsample_mask(x_mask, subsample, target_len):
    """Recorta/rellena la mascara para que case EXACTAMENTE con la longitud de x tras el submuestreo."""
    if x_mask is None:
        return None
    m = x_mask[:, :, ::subsample]
    if m.size(2) > target_len:
        m = m[:, :, :target_len]
    elif m.size(2) < target_len:
        m = torch.nn.functional.pad(m, (0, target_len - m.size(2)), value=False)
    return m


class CapaSesion(torch.nn.Module):
    """Transformada afin por sesion + softsign (capa 'day-specific' del baseline de B2T'25).

    Por que hace falta: los 45 dias de grabacion abarcan 20 meses y la senal que produce
    un mismo fonema cambia de un dia a otro (deriva de los electrodos, micromovimientos
    del array). Un unico frontend compartido tiene que aprender N mapeos senal->fonema
    contradictorios a la vez y ademas adivinar de que dia es cada trial. Con una matriz
    por sesion, cada dia se alinea a un espacio comun y el resto del modelo ve un unico
    problema coherente.

    Se inicializa a la identidad, asi que al empezar solo aplica el softsign.
    Coste: n_sesiones x 512 x 512 parametros (~2.6 M con 10 sesiones, ~12 M con 45).
    """

    def __init__(self, n_sesiones, dim=512):
        super().__init__()
        self.n_sesiones = n_sesiones
        self.W = torch.nn.Parameter(torch.eye(dim).unsqueeze(0).repeat(n_sesiones, 1, 1))
        self.b = torch.nn.Parameter(torch.zeros(n_sesiones, dim))

    def forward(self, x):
        # x: (B, T, dim+1). El ultimo canal es el indice de sesion, constante en el tiempo.
        sid = x[:, 0, -1].round().long().clamp_(0, self.n_sesiones - 1)
        x = x[:, :, :-1]
        # baddbmm: b[sid] + x @ W[sid], por muestra del batch
        x = torch.baddbmm(self.b[sid].unsqueeze(1), x, self.W[sid])
        return torch.nn.functional.softsign(x)


def build_frontend(kind, pos_enc, capa_sesion=None):
    """Frontend (encoder.embed) que reemplaza al Conv2dSubsampling original de mel.

    IMPORTANTE: heredan de Conv2dSubsampling (aunque no usen su __init__) porque el
    encoder de ESPnet decide si pasar la mascara al embed mirando
    `isinstance(self.embed, Conv2dSubsampling)`. Si no se hereda de ahi, ESPnet llama
    a embed(x) SIN mascara (asumiendo que es un embedding de texto que no submuestrea)
    y revienta con "forward() missing 1 required positional argument: 'x_mask'".
    """
    import torch.nn as nn

    if kind == "conv2d":
        class Conv2dFrontend(Conv2dSubsampling):
            # OJO: ~66 GFLOP/muestra, el 85-90% del coste del modelo.
            def __init__(self):
                super().__init__(512, 384, dropout_rate=0.0, pos_enc=pos_enc)
                self.sesion = capa_sesion
            def forward(self, x, x_mask):
                if self.sesion is not None:
                    x = self.sesion(x)
                return super().forward(x, x_mask)
        return Conv2dFrontend()

    elif kind == "linear":
        class LinearFrontend(Conv2dSubsampling):
            def __init__(self, in_dim=512, out_dim=384, subsample=4):
                torch.nn.Module.__init__(self)   # NO llamar a Conv2dSubsampling.__init__
                self.sesion = capa_sesion
                self.proj = nn.Linear(in_dim, out_dim)
                self.subsample = subsample
                self.pos_enc = pos_enc
            def forward(self, x, x_mask):
                if self.sesion is not None:
                    x = self.sesion(x)
                x = self.proj(x)
                x = x[:, ::self.subsample, :]
                x = self.pos_enc(x)
                x_mask = _subsample_mask(x_mask, self.subsample, x.size(1))
                return x, x_mask
        return LinearFrontend()

    elif kind == "conv1d":
        class Conv1dFrontend(Conv2dSubsampling):
            def __init__(self, in_dim=512, out_dim=384):
                torch.nn.Module.__init__(self)   # NO llamar a Conv2dSubsampling.__init__
                self.sesion = capa_sesion
                self.conv = nn.Sequential(
                    nn.Conv1d(in_dim, out_dim, kernel_size=3, stride=2, padding=1), nn.ReLU(),
                    nn.Conv1d(out_dim, out_dim, kernel_size=3, stride=2, padding=1), nn.ReLU(),
                )
                self.pos_enc = pos_enc
            def forward(self, x, x_mask):
                if self.sesion is not None:
                    x = self.sesion(x)
                x = self.conv(x.transpose(1, 2)).transpose(1, 2)
                x = self.pos_enc(x)
                x_mask = _subsample_mask(x_mask, 4, x.size(1))
                return x, x_mask
        return Conv1dFrontend()

    raise ValueError(f"Frontend desconocido: {kind}")


def make_build_model_fn(cfg, n_sesiones=1, verbose=True):
    """Devuelve el build_model_fn que ESPnet-EZ usara para ESTE experimento."""
    def build_model_fn(args):
        from espnet2.tasks.s2t import S2TTask

        # ── ARREGLO: el ctc_weight del panel tiene que llegar al modelo ──
        conf = dict(pretrain_config)
        conf["model_conf"] = {**conf.get("model_conf", {}), "ctc_weight": cfg["ctc_weight"]}

        model = S2TTask.build_model(argparse.Namespace(**conf))
        model.load_state_dict(_pretrained_state_dict, strict=False)

        # sEEG entra directa: fuera frontend mel y normalizacion global
        model.frontend = None
        model.normalize = None

        pos_enc = model.encoder.embed.out[1]
        sesion = CapaSesion(n_sesiones) if cfg["capa_sesion"] else None
        model.encoder.embed = build_frontend(cfg["frontend"], pos_enc, sesion)

        # ── objetivo CTC de caracteres: nueva cabeza + error_calculator coherente ──
        if cfg["objetivo_ctc"] == "char" and model.ctc is not None:
            from espnet2.asr.ctc import CTC
            from espnet.nets.pytorch_backend.transformer.subsampling import Conv2dSubsampling  # noqa
            from espnet.nets.e2e_asr_common import ErrorCalculator
            enc_dim = model.ctc.ctc_lo.in_features
            # ctc_lo pasa de (enc_dim -> 50002) a (enc_dim -> ~32). Se entrena desde cero.
            model.ctc = CTC(odim=CHAR_VOCAB, encoder_output_size=enc_dim, zero_infinity=True)
            # El cer_ctc del train.log lo calcula el error_calculator con SU token_list;
            # hay que darle el de caracteres o las cifras del log no querran decir nada.
            char_list = ["<blank>"] + _CHARS
            model.error_calculator = ErrorCalculator(
                char_list, " ", "<blank>", report_cer=True, report_wer=True)
            model.token_list = char_list

        model.train()
        freeze_all(model)
        if cfg["usar_lora"]:
            create_lora_adapter(model, target_modules=LORA_TARGET)

        for p in model.encoder.embed.parameters():   # frontend nuevo (incl. capa de sesion)
            p.requires_grad = True
        if model.ctc is not None:                    # ESPnet lo pone a None si ctc_weight==0
            for p in model.ctc.parameters():
                p.requires_grad = True

        if cfg["unfreeze_encoder"]:
            if cfg["unfreeze_n_layers"] is None:
                for p in model.encoder.parameters():
                    p.requires_grad = True
            else:
                for layer in model.encoder.encoders[:cfg["unfreeze_n_layers"]]:
                    for p in layer.parameters():
                        p.requires_grad = True

        if verbose:
            total, trainable = count_trainable(model)
            extra = f" + capa_sesion({n_sesiones})" if cfg["capa_sesion"] else ""
            obj = (f"char({CHAR_VOCAB} clases)" if cfg["objetivo_ctc"] == "char"
                   else f"bpe({len(converter.token_list)} clases)")
            print(f"  frontend={cfg['frontend']}{extra} · objetivo_ctc={obj} · "
                  f"lora={cfg['usar_lora']} · "
                  f"encoder={'descongelado' if cfg['unfreeze_encoder'] else 'congelado'} · "
                  f"ctc_weight={cfg['ctc_weight']} · norm={cfg['norm']}")
            print(f"  {trainable:,} entrenables / {total:,} totales ({trainable/total*100:.2f}%)")
            if model.ctc is None:
                print("  [nota] ctc_weight=0 -> ESPnet desactiva la cabeza CTC")
            if getattr(model, "decoder", None) is None:
                print("  [nota] ctc_weight=1 -> ESPnet desactiva el decoder "
                      "(solo CTC; la evaluacion sera greedy)")
        return model

    return build_model_fn


# ── LR diferencial: grupos de parametros en el optimizador ────────────
def set_encoder_lr_scale(scale):
    """scale<1.0 -> el encoder preentrenado entrena con lr*scale; el frontend nuevo, CTC y LoRA con lr."""
    from espnet2.tasks.s2t import S2TTask

    if scale is None or scale == 1.0:
        if "build_optimizers" in S2TTask.__dict__:
            del S2TTask.build_optimizers      # restaura la implementacion original
        return

    OPTIMS = {"adam": torch.optim.Adam, "adamw": torch.optim.AdamW, "sgd": torch.optim.SGD}

    def build_optimizers(cls, args, model):
        if args.optim not in OPTIMS:
            raise ValueError(f"enc_lr_scale no soportado con optim={args.optim}")
        base_lr = args.optim_conf.get("lr", 1e-3)
        conf = {k: v for k, v in args.optim_conf.items() if k != "lr"}
        nuevos, preentrenados = [], []
        for name, p in model.named_parameters():
            if not p.requires_grad:
                continue
            es_nuevo = (name.startswith("encoder.embed") or name.startswith("ctc.")
                        or "lora_" in name)
            (nuevos if es_nuevo else preentrenados).append(p)
        grupos = [{"params": nuevos, "lr": base_lr},
                  {"params": preentrenados, "lr": base_lr * scale}]
        print(f"  LR diferencial: {len(nuevos)} tensores a {base_lr:g} · "
              f"{len(preentrenados)} a {base_lr*scale:g}")
        return [OPTIMS[args.optim](grupos, lr=base_lr, **conf)]

    S2TTask.build_optimizers = classmethod(build_optimizers)

print("Constructores de modelo listos.")
# Out:
# Constructores de modelo listos.

# %% [markdown]
# ## 7. Configuración de entrenamiento
#
# Además de lo que ya inyectabas en local, aquí van los ajustes específicos de GPU: `use_amp`, `cudnn_benchmark`, `cudnn_deterministic=False` (el valor por defecto `True` cuesta un 20-30 %), `keep_nbest_models=1` para no llenar el disco y `resume=True` para sobrevivir a las desconexiones de Colab.

# %%
YAML_BASE = """
use_lora: true

rir_scp: null
noise_scp: null
speech_volume_normalize: null
non_linguistic_symbols: null

preprocessor_conf:
  speech_name: speech
  text_name: text

seed: 2024
num_workers: 0
ngpu: 1
batch_type: sorted
batch_size: 8
accum_grad: 1
max_epoch: 1
patience: null
init: null
best_model_criterion:
- [valid, loss, min]
keep_nbest_models: 1
use_amp: true

optim: adam
optim_conf:
    lr: 0.001
    weight_decay: 0.000001
scheduler: warmuplr
scheduler_conf:
    warmup_steps: 20

specaug: null
ctc_weight: 0.0
grad_clip: 5.0
"""

with open("/content/finetune_b2t25.yaml", "w") as f:
    f.write(YAML_BASE)


def build_finetune_config(cfg, stats_dir):
    ft = ez.config.update_finetune_config(
        "s2t", copy.deepcopy(pretrain_config), "/content/finetune_b2t25.yaml")

    # ── entorno ──
    ft["ngpu"] = NGPU
    ft["use_amp"] = USE_AMP
    ft["num_workers"] = cfg["num_workers"]
    # cudnn_benchmark=True es CONTRAPRODUCENTE aqui: con batch_type sorted cada batch
    # tiene una longitud distinta, y cudnn vuelve a buscar el mejor algoritmo para cada
    # forma nueva (143 busquedas exhaustivas en la primera epoca).
    ft["cudnn_benchmark"] = False
    ft["cudnn_deterministic"] = False
    ft["multiple_iterator"] = False
    ft["iterator_type"] = "sequence"
    ft["log_interval"] = 10
    ft["num_iters_per_epoch"] = None
    ft["seed"] = cfg["seed"]
    ft["resume"] = True
    ft["keep_nbest_models"] = 1

    # ── criterio para elegir el mejor checkpoint ──
    # ARREGLO: con ctc_weight bajo, 'valid loss' es sobre todo perdida de atencion y
    # toca fondo hacia la epoca 4, cuando el cer_ctc todavia esta bajando. Seleccionar
    # por cer_ctc guarda el modelo que de verdad es mejor en la tarea.
    if cfg["criterio"] == "cer_ctc" and cfg["ctc_weight"] > 0:
        ft["best_model_criterion"] = [["valid", "cer_ctc", "min"]]
    else:
        ft["best_model_criterion"] = [["valid", "loss", "min"]]

    # ── batching ──
    ft["batch_type"] = cfg["batch_type"]
    if cfg["batch_type"] == "numel":
        ft["batch_bins"] = cfg["batch_bins"]
    else:
        ft["batch_size"] = cfg["batch_size"]
    ft["accum_grad"] = cfg["accum_grad"]

    # ── optimizacion ──
    ft["max_epoch"] = cfg["max_epoch"]
    ft["scheduler_conf"]["warmup_steps"] = cfg["warmup"]
    ft["optim_conf"]["lr"] = cfg["lr"]
    ft["optim_conf"]["weight_decay"] = cfg["weight_decay"]
    ft["grad_clip"] = cfg["grad_clip"]
    ft["ctc_weight"] = cfg["ctc_weight"]          # informativo, el que manda es model_conf
    ft["model_conf"] = {**ft.get("model_conf", {}), "ctc_weight": cfg["ctc_weight"]}

    # ── shape files ──
    nombres = ["speech_shape", "text_shape", "text_prev_shape", "text_ctc_shape"]
    ft["train_shape_file"] = [f"{stats_dir}/train/{n}" for n in nombres]
    ft["valid_shape_file"] = [f"{stats_dir}/valid/{n}" for n in nombres]
    return ft


def shape_files(stats_dir):
    nombres = ["speech_shape", "text_shape", "text_prev_shape", "text_ctc_shape"]
    return ([f"{stats_dir}/train/{n}" for n in nombres]
            + [f"{stats_dir}/valid/{n}" for n in nombres])

print("Constructor de config listo.")
# Out:
# Constructor de config listo.

# %% [markdown]
# ## 8. Logs y métricas por época
#
# ESPnet no escribe `train.log` por sí solo cuando se lanza desde un notebook (en las recetas sale de una redirección de shell). Aquí se captura el logger raíz a un fichero por experimento y solo se muestran en pantalla las líneas de resumen de época, así el notebook no se llena de miles de líneas.
#
# `parse_train_log` convierte ese log en un CSV con una fila por época: justo lo que necesitas para las curvas de la memoria.

# %%
class CapturaLog:
    """Redirige el logging de ESPnet a un fichero; en pantalla, solo el resumen por epoca."""

    CLAVES = ("batch:", "epoch results", "epoch started", "Saving", "best",
              "There are no improvements", "Stop training", "The training was finished")

    def __init__(self, path):
        self.path = path
        self.previos = None

    def __enter__(self):
        root = logging.getLogger()
        self.previos = (root.handlers[:], root.level)
        root.handlers = []
        root.setLevel(logging.INFO)

        fh = logging.FileHandler(self.path, mode="a", encoding="utf-8")
        fh.setFormatter(logging.Formatter("%(asctime)s %(levelname)s: %(message)s"))
        root.addHandler(fh)

        claves = self.CLAVES
        class Resumen(logging.Filter):
            def filter(self, record):
                return any(c in record.getMessage() for c in claves)
        sh = logging.StreamHandler()
        sh.addFilter(Resumen())
        sh.setFormatter(logging.Formatter("    %(message)s"))
        root.addHandler(sh)
        return self

    def __exit__(self, *exc):
        root = logging.getLogger()
        for h in root.handlers:
            try: h.close()
            except Exception: pass
        root.handlers, root.level = self.previos
        return False


PAR = re.compile(r"([a-zA-Z_][a-zA-Z_0-9]*)=(-?[\d.]+(?:[eE][-+]?\d+)?)")

def parse_train_log(path):
    """Extrae una fila por epoca del train.log de ESPnet."""
    filas = []
    if not os.path.exists(path):
        return pd.DataFrame()
    with open(path, encoding="utf-8", errors="ignore") as f:
        for linea in f:
            m = re.search(r"(\d+)epoch results:(.*)", linea)
            if not m:
                continue
            epoca, resto = int(m.group(1)), m.group(2)
            fila = {"epoch": epoca}
            partes = re.split(r"\[valid\]", resto)
            for prefijo, trozo in zip(["train_", "valid_"], partes):
                trozo = trozo.replace("[train]", "")
                for k, v in PAR.findall(trozo):
                    if k in ("time", "total_count"):
                        continue
                    fila[prefijo + k] = float(v)
            filas.append(fila)
    df = pd.DataFrame(filas)
    if len(df):
        df = df.drop_duplicates(subset="epoch", keep="last").sort_values("epoch")
    return df

print("Utilidades de log listas.")
# Out:
# Utilidades de log listas.

# %% [markdown]
# ## 9. Inferencia y CER/WER
#
# Igual que en local (beam search de OWSM reconectado al modelo fine-tuneado), pero el objeto `Speech2Text` se construye **una sola vez** y se reutiliza en todos los experimentos, y los pesos de decodificación (`ctc_weight`) se ajustan sobre la marcha.

# %%
_S2T = None

def get_s2t():
    global _S2T
    if _S2T is None:
        _S2T = Speech2Text.from_pretrained(
            FINETUNE_MODEL, lang_sym=f"<{LANGUAGE}>", task_sym="<asr>",
            beam_size=BEAM_SIZE, ctc_weight=0.3, device=DEVICE, nbest=1)
    return _S2T


def rebind_beam_search(s2t, model, ctc_weight):
    """Repunta decoder y CTC del beam search hacia el modelo fine-tuneado."""
    s2t.s2t_model = model
    bs = s2t.beam_search
    for d in (getattr(bs, "scorers", {}), getattr(bs, "full_scorers", {}),
              getattr(bs, "part_scorers", {})):
        if "decoder" in d:
            d["decoder"] = model.decoder
        if "ctc" in d and hasattr(d["ctc"], "ctc"):
            d["ctc"].ctc = model.ctc
    if hasattr(bs, "nn_dict") and "decoder" in bs.nn_dict:
        bs.nn_dict["decoder"] = model.decoder
    if hasattr(bs, "weights") and ctc_weight is not None:
        bs.weights["ctc"] = ctc_weight
        bs.weights["decoder"] = 1.0 - ctc_weight
    bs.to(device=DEVICE).eval()


def _norm(t):
    t = t.lower().replace("\x00", "")
    t = re.sub(r"<[^>]+>", " ", t)
    t = t.translate(str.maketrans("", "", string.punctuation))
    return re.sub(r"\s+", " ", t).strip()

def _lev(a, b):
    dp = list(range(len(b) + 1))
    for i, ca in enumerate(a, 1):
        prev, dp[0] = dp[0], i
        for j, cb in enumerate(b, 1):
            old = dp[j]
            dp[j] = min(dp[j] + 1, dp[j - 1] + 1, prev + (ca != cb))
            prev = old
    return dp[-1]

def cer(ref, hyp):
    r, h = _norm(ref), _norm(hyp)
    return 0.0 if len(r) == 0 else _lev(list(r), list(h)) / len(r)

def wer(ref, hyp):
    r, h = _norm(ref).split(), _norm(hyp).split()
    return 0.0 if len(r) == 0 else _lev(r, h) / len(r)


def find_best_checkpoint(exp_dir):
    for name in ["valid.cer_ctc.best.pth", "valid.loss.best.pth",
                 "valid.acc.best.pth", "train.loss.best.pth"]:
        p = os.path.join(exp_dir, name)
        if os.path.exists(p):
            return p
    cands = sorted(glob.glob(os.path.join(exp_dir, "*epoch.pth")), key=os.path.getmtime)
    if not cands:
        raise FileNotFoundError(f"No hay checkpoints en {exp_dir}")
    return cands[-1]


def cargar_modelo_entrenado(cfg, exp_dir, n_sesiones):
    ckpt = find_best_checkpoint(exp_dir)
    modelo = make_build_model_fn(cfg, n_sesiones, verbose=False)(None).to(DEVICE)
    try:
        state = torch.load(ckpt, map_location=DEVICE, weights_only=True)
    except Exception:
        state = torch.load(ckpt, map_location=DEVICE, weights_only=False)
    faltan = modelo.load_state_dict(state, strict=False)
    if faltan.missing_keys:
        print(f"    [aviso] {len(faltan.missing_keys)} tensores sin cargar del checkpoint, "
              f"p.ej. {faltan.missing_keys[0]}")
    return modelo.eval()


@torch.no_grad()
def evaluar_ctc_greedy(cfg, modelo, val_raw, n=EVAL_N, mostrar=3):
    """Decodificacion CTC greedy: argmax por frame, colapsar repeticiones, quitar blanks.
    No pasa por el decoder, asi que mide SOLO lo que el encoder extrae del sEEG.

    Devuelve DOS cifras, porque no son la misma:
      - cer_ctc_micro: exactamente como lo calcula ESPnet en el train.log (cadena de
        tokens BPE concatenados, sum(errores)/sum(longitudes)). Es la unica comparable
        con la columna cer_ctc de las curvas.
      - cer_texto: sobre el texto detokenizado y normalizado, media por trial. Es la
        que se parece a un CER "de verdad", pero la hunden los trials cortos que fallan.
    """
    from itertools import groupby
    tok_ctc, blank, _, destok = objetivo_info(cfg)
    n = min(n, len(val_raw))
    idxs = np.linspace(0, len(val_raw) - 1, n).astype(int)   # repartidos, no los n primeros

    err_bpe = ref_bpe = 0
    cers_txt, wers_txt, ejemplos = [], [], []
    for i in idxs:
        d = val_raw[int(i)]
        x = preparar_speech(d, cfg)
        speech = torch.tensor(x, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        lens = torch.tensor([speech.shape[1]], dtype=torch.long, device=DEVICE)
        enc, _ = modelo.encode(speech, lens)
        if isinstance(enc, tuple):
            enc = enc[0]
        ids = modelo.ctc.ctc_lo(enc).argmax(-1)[0].tolist()
        hyp_ids = [k for k, _ in groupby(ids) if k != blank]   # colapso CTC estandar
        ref_ids = tok_ctc(d["text_ctc"]).tolist()

        # cer_ctc(micro): identico a como lo calcula ESPnet, sobre la unidad del objetivo
        h = destok(hyp_ids)
        r = destok(ref_ids)
        err_bpe += _lev(list(h), list(r)); ref_bpe += len(r)

        hip = destok(hyp_ids)
        cers_txt.append(cer(d["text_raw"], hip))
        wers_txt.append(wer(d["text_raw"], hip))
        if len(ejemplos) < mostrar:
            ejemplos.append((_norm(d["text_raw"]), hip))

    for ref, hip in ejemplos:
        print(f"    [ctc] REF: {ref}\n    [ctc] HYP: {hip}")
    c = np.array(cers_txt)
    print(f"    por trial: mediana={np.median(c):.3f} p10={np.percentile(c,10):.3f} "
          f"p90={np.percentile(c,90):.3f} · {(c<0.2).mean()*100:.0f}% por debajo de 0.2")
    return err_bpe / max(1, ref_bpe), float(c.mean()), float(np.mean(wers_txt))


@torch.no_grad()
def evaluar(cfg, modelo, val_raw, n=EVAL_N, mostrar=3):
    """CER/WER con el beam search de OWSM (decoder + CTC)."""
    w_dec = cfg["ctc_weight_decode"]
    w_dec = cfg["ctc_weight"] if w_dec is None else w_dec
    s2t = get_s2t()
    rebind_beam_search(s2t, modelo, w_dec)

    lang_id   = s2t.converter.token2id[f"<{LANGUAGE}>"]
    task_id   = s2t.converter.token2id["<asr>"]
    notime_id = s2t.converter.token2id[s2t.preprocessor_conf["notime_symbol"]]

    nivel = logging.getLogger().level
    logging.getLogger().setLevel(logging.WARNING)   # el beam search es MUY verboso
    cers, wers, ejemplos = [], [], []
    try:
        n = min(n, len(val_raw))
        for i in range(n):
            d = val_raw[i]
            x = preparar_speech(d, cfg)
            speech = torch.tensor(x, dtype=torch.float32, device=DEVICE).unsqueeze(0)
            lens = torch.tensor([speech.shape[1]], dtype=torch.long, device=DEVICE)
            enc, _ = modelo.encode(speech, lens)
            if isinstance(enc, tuple):
                enc = enc[0]
            s2t.beam_search.set_hyp_primer([modelo.sos, lang_id, task_id, notime_id])
            res = s2t._decode_single_sample(enc[0])
            text, token, token_int, text_nospecial, hyp = res[0]
            hipotesis = (text_nospecial or text or "").strip()
            cers.append(cer(d["text_raw"], hipotesis))
            wers.append(wer(d["text_raw"], hipotesis))
            if i < mostrar:
                ejemplos.append((_norm(d["text_raw"]), hipotesis))
    finally:
        logging.getLogger().setLevel(nivel)

    for ref, hip in ejemplos:
        print(f"    REF: {ref}\n    HYP: {hip}")
    # Un modelo que ignora la senal sEEG produce siempre la misma frase generica:
    if ejemplos and len({h for _, h in ejemplos}) == 1:
        print("    [aviso] hipotesis identicas: el modelo esta ignorando la entrada")

    return float(np.mean(cers)), float(np.mean(wers)), n

print("Evaluacion lista.")
# Out:
# Evaluacion lista.

# %% [markdown]
# ## 10. `run_experiment`
#
# Une todo: datos → stats (cacheadas) → entrenamiento → métricas → guardado. Cada llamada deja en Drive una fila en `resultados.csv`, el `train.log` y un `epocas.csv` con la curva completa.

# %%
CSV_RESULTADOS = f"{RESULTS_DIR}/resultados.csv"

def hacer_tag(cfg):
    return (f"{cfg['nombre']}_n{cfg['n_sessions']}_{cfg['frontend']}"
            f"{'_sess' if cfg['capa_sesion'] else ''}"
            f"{'_char' if cfg['objetivo_ctc'] == 'char' else ''}"
            f"_unf{int(cfg['unfreeze_encoder'])}_lora{int(cfg['usar_lora'])}"
            f"_lr{cfg['lr']:g}_els{cfg['enc_lr_scale']:g}_ctc{cfg['ctc_weight']:g}"
            f"_bs{cfg['batch_size']}_ep{cfg['max_epoch']}")

def experimentos_hechos():
    if not os.path.exists(CSV_RESULTADOS):
        return set()
    try:
        return set(pd.read_csv(CSV_RESULTADOS)["exp_tag"].astype(str))
    except Exception:
        return set()

def guardar_resultado(fila):
    df_nueva = pd.DataFrame([fila])
    if os.path.exists(CSV_RESULTADOS):
        df = pd.concat([pd.read_csv(CSV_RESULTADOS), df_nueva], ignore_index=True)
    else:
        df = df_nueva
    df.to_csv(CSV_RESULTADOS, index=False)


def asegurar_stats(trainer, stats_dir):
    faltan = [p for p in shape_files(stats_dir)
              if not os.path.exists(p) or os.path.getsize(p) == 0]
    if not faltan:
        print("  shape files ya existen, se salta collect_stats")
        return
    print("  recopilando estadisticas (solo la primera vez por configuracion de datos)...")
    nivel = logging.getLogger().level
    logging.getLogger().setLevel(logging.WARNING)
    try:
        trainer.collect_stats()
    finally:
        logging.getLogger().setLevel(nivel)
    print("  collect_stats OK")


def run_experiment(cambios):
    cfg = {**DEFAULTS, **cambios}
    tag = hacer_tag(cfg)

    if SKIP_IF_DONE and tag in experimentos_hechos():
        print(f"[SALTADO] {tag}\n")
        return None

    print("=" * 78)
    print(f"[EXPERIMENTO] {tag}")
    print("=" * 78)

    exp_dir = f"{OUTPUT_DIR}/{tag}"
    os.makedirs(exp_dir, exist_ok=True)
    drive_dir = f"{RESULTS_DIR}/{tag}"
    os.makedirs(drive_dir, exist_ok=True)

    train_raw, val_raw, stats_dir, n_ses = get_datos(cfg)
    os.makedirs(stats_dir, exist_ok=True)

    data_info = make_data_info(cfg)
    train_ds = ez.dataset.ESPnetEZDataset(train_raw, data_info=data_info)
    valid_ds = ez.dataset.ESPnetEZDataset(val_raw,   data_info=data_info)

    set_encoder_lr_scale(cfg["enc_lr_scale"])
    log_path = f"{exp_dir}/train.log"

    def entrenar(batch_size):
        """Un intento de entrenamiento con el batch dado."""
        c = {**cfg, "batch_size": batch_size}
        ft = build_finetune_config(c, stats_dir)
        pasos = max(1, len(train_raw) // max(1, batch_size))
        print(f"  batch={batch_size} · ~{pasos} pasos/epoca · warmup {c['warmup']} "
              f"(~{c['warmup']/pasos:.1f} epocas)")
        trainer = ez.Trainer(
            task="s2t", train_config=ft,
            train_dataset=train_ds, valid_dataset=valid_ds,
            build_model_fn=make_build_model_fn(c, n_ses), data_info=data_info,
            output_dir=exp_dir, stats_dir=stats_dir, ngpu=NGPU,
        )
        asegurar_stats(trainer, stats_dir)
        train_raw.cerrar(); val_raw.cerrar()   # antes del fork (HDF5 no es fork-safe)
        with CapturaLog(log_path):
            trainer.train()
        del trainer

    t0 = time.time()
    error, bs_usado = "", cfg["batch_size"]
    for intento, bs in enumerate([cfg["batch_size"], max(1, cfg["batch_size"] // 2),
                                  max(1, cfg["batch_size"] // 4)]):
        try:
            bs_usado = bs
            entrenar(bs)
            error = ""
            break
        except torch.cuda.OutOfMemoryError as e:
            gc.collect(); torch.cuda.empty_cache()
            error = f"OutOfMemoryError (batch={bs})"
            if intento < 2:
                print(f"  [OOM con batch={bs}] reintentando con batch={max(1, bs // 2)}...")
            else:
                print(f"  [ERROR] OOM incluso con batch={bs}. Usa una GPU con mas VRAM.")
        except KeyboardInterrupt:
            error = "interrumpido"
            print("  [interrumpido por el usuario]")
            break
        except Exception as e:
            error = f"{type(e).__name__}: {e}"
            print(f"  [ERROR] {error}")
            break
    minutos = (time.time() - t0) / 60

    # ── metricas por epoca ──
    df_ep = parse_train_log(log_path)
    mejores = {}
    if len(df_ep):
        df_ep.insert(0, "exp_tag", tag)
        df_ep.to_csv(f"{drive_dir}/epocas.csv", index=False)
        mejores["epocas_hechas"] = int(df_ep["epoch"].max())
        # El minimo de cer_ctc SOBRE TODAS LAS EPOCAS. Es lo que hay que mirar: el
        # cer_ctc "en la epoca de menor loss" puede ser mucho peor si la loss esta
        # dominada por la perdida de atencion.
        if "valid_cer_ctc" in df_ep.columns and df_ep["valid_cer_ctc"].notna().any():
            j = df_ep["valid_cer_ctc"].idxmin()
            mejores["min_valid_cer_ctc"] = float(df_ep.loc[j, "valid_cer_ctc"])
            mejores["epoch_min_cer_ctc"] = int(df_ep.loc[j, "epoch"])
            ult = df_ep.tail(10)
            if len(ult) >= 5:   # ¿sigue bajando o esta plano?
                mejores["pendiente_cer_ctc"] = float(
                    np.polyfit(ult["epoch"], ult["valid_cer_ctc"], 1)[0])
        if "valid_loss" in df_ep.columns and df_ep["valid_loss"].notna().any():
            mejor = df_ep.loc[df_ep["valid_loss"].idxmin()]
            for k in df_ep.columns:
                if k.startswith("valid_") and pd.notna(mejor[k]):
                    mejores[f"best_{k}"] = float(mejor[k])
            mejores["best_epoch"] = int(mejor["epoch"])

    # ── CER/WER: greedy CTC (honesto) y beam search (con decoder) ──
    cer_m = wer_m = cer_g = wer_g = cer_micro = float("nan")
    if not error or "interrumpido" in error:
        modelo = None
        try:
            modelo = cargar_modelo_entrenado(cfg, exp_dir, n_ses)

            if EVAL_GREEDY_CTC and modelo.ctc is not None:
                print("  evaluando con CTC greedy...")
                cer_micro, cer_g, wer_g = evaluar_ctc_greedy(cfg, modelo, val_raw)
                print(f"  [CTC greedy] cer_ctc(micro, comparable con el log)={cer_micro:.3f} · "
                      f"CER texto={cer_g:.3f} · WER texto={wer_g:.3f}")

            if getattr(modelo, "decoder", None) is not None and cfg["objetivo_ctc"] == "bpe":
                print("  evaluando con beam search...")
                cer_m, wer_m, n_ev = evaluar(cfg, modelo, val_raw)
                print(f"  [beam]       CER={cer_m:.3f} · WER={wer_m:.3f} ({n_ev} trials)")
            elif cfg["objetivo_ctc"] == "char":
                print("  (objetivo char: la cabeza CTC y el decoder usan vocabularios "
                      "distintos, el beam search hibrido no aplica)")
            else:
                print("  (sin decoder: ctc_weight=1, se omite el beam search)")
        except Exception as e:
            print(f"  [evaluacion fallida] {type(e).__name__}: {e}")
        finally:
            del modelo
            gc.collect(); torch.cuda.empty_cache()

    # ── guardado ──
    for artefacto in ["train.log", "config.yaml"]:
        origen = f"{exp_dir}/{artefacto}"
        if os.path.exists(origen):
            shutil.copy(origen, f"{drive_dir}/{artefacto}")
    ckpt_tmp = f"{exp_dir}/checkpoint.pth"          # modelo+optimizador, ~1.4 GB
    if GUARDAR_CKPT:
        try:
            shutil.copy(find_best_checkpoint(exp_dir), f"{drive_dir}/valid.loss.best.pth")
        except Exception as e:
            print("  [aviso] no se pudo copiar el checkpoint:", e)
    if os.path.exists(ckpt_tmp) and not error:
        os.remove(ckpt_tmp)                          # libera disco de la VM

    fila = {"exp_tag": tag, "gpu": GPU_NAME, "minutos": round(minutos, 1),
            "compute_units": round(CU_H * minutos / 60, 2),
            "n_train": len(train_raw), "n_val": len(val_raw), "n_sesiones": n_ses,
            "batch_usado": bs_usado,
            "cer_ctc_micro": cer_micro,
            "cer_ctc_greedy": cer_g, "wer_ctc_greedy": wer_g,
            "cer_beam": cer_m, "wer_beam": wer_m, "error": error,
            **{k: v for k, v in cfg.items()}, **mejores}
    guardar_resultado(fila)

    del train_ds, valid_ds
    gc.collect(); torch.cuda.empty_cache()

    print(f"  hecho en {minutos:.1f} min (~{CU_H*minutos/60:.2f} compute units)\n")
    return fila

print("run_experiment listo.")
# Out:
# run_experiment listo.

# %% [markdown]
# ## 11. El barrido
#
# Cada entrada es solo lo que **cambia** respecto a `DEFAULTS`. El barrido está por fases: **lanza la fase 1 sola** y mira el resultado antes de seguir.
#
# ### Por qué el diagnóstico va primero
#
# Lo que dijo tu primera tanda, en una línea: `acc` empieza en 0.557 y acaba en 0.578 tras 30 épocas. Esa `acc` es la del decoder **con teacher forcing** — se le dan los tokens correctos anteriores y se mide si acierta el siguiente. Un ~57 % es lo que saca OWSM usando solo estadística del inglés, sin mirar la entrada. Que arranque ahí y no se mueva significa que el encoder no aporta nada. Y `wer=1.000` con `cer=0.34` lo confirma desde el otro lado: escribe inglés bien formado y no acierta ni una palabra.
#
# El `overfit` de la fase 1 elimina todas las salidas de escape a la vez: una sesión (sin deriva entre días), val = train (sin generalización que valga), `ctc_weight=1.0` (ESPnet desactiva el decoder, así que no hay prior lingüístico donde esconderse) y 200 épocas. Lo que quede es la capacidad del encoder de mapear sEEG → fonemas. Son ~10 min y 0.3 unidades.
#
# ### Por qué la capa por sesión
#
# Es *la* característica de este dataset: 45 sesiones repartidas en 20 meses, y la señal que produce un mismo fonema cambia de un día a otro por deriva de los electrodos. El algoritmo de referencia de B2T'25 pasa las características por una capa lineal específica del día seguida de un `softsign` antes de nada más, y los trabajos cross-subject recientes usan transformadas afines por día para alinear todo a un espacio común.
#
# Tú tenías un único frontend compartido para 10 sesiones: el modelo recibía diez mapeos señal→fonema contradictorios y tenía que deducir de qué día venía cada trial. `CapaSesion` aprende una matriz 512×512 más un sesgo por sesión, inicializados a la identidad, y aplica `softsign` después. El índice de sesión viaja hasta el frontend como un canal extra del tensor de entrada (512 → 513).
#
# ### Otros cambios respecto a la tanda anterior
#
# - **`enc_lr_scale=0.01`** en los dos runs de la fase 2: el encoder preentrenado a 1e-5 y el frontend nuevo a 1e-3. Con todo a 1e-3 lo más probable es que el warmup estuviera destruyendo los pesos de OWSM.
# - **`cer_ctc_greedy`** es la métrica a mirar en la tabla, no `cer_beam`. Sale de decodificar el `argmax` de la cabeza CTC colapsando repeticiones: sin decoder, sin beam, sin prior. Es la que no se puede falsear.

# %%
BARRIDO = [
    # (1) conv1d: no descarta frames al submuestrear
    dict(nombre="c1d", n_sessions=45, max_epoch=30, warmup=800,
         frontend="conv1d", ctc_weight=1.0, objetivo_ctc="char",
         capa_sesion=True, batch_size=32, enc_lr_scale=0.01),

    # (2) mismo linear de antes, pero sin machacar el encoder
    dict(nombre="lrdif", n_sessions=45, max_epoch=30, warmup=800,
         frontend="linear", ctc_weight=1.0, objetivo_ctc="char",
         capa_sesion=True, batch_size=32, enc_lr_scale=0.01),
]

# Referencia medida en L4: n=10, 30 epocas, frontend linear -> 59 min (2 min/epoca).
def estimar_min(cfg):
    c = {**DEFAULTS, **cfg}
    factor = 1.0 if "L4" in GPU_NAME else (2.0 if "T4" in GPU_NAME else 0.5)
    por_epoca = 2.0 * (c["n_sessions"] / 10) * (0.8 if c["ctc_weight"] == 1.0 else 1.0)
    return c["max_epoch"] * por_epoca * factor

total_min = sum(estimar_min(e) for e in BARRIDO)
print(f"GPU: {GPU_NAME} ({CU_H} unidades/h)")
print(f"{len(BARRIDO)} experimentos · ~{total_min/60:.1f} h · "
      f"~{CU_H*total_min/60:.1f} compute units (~${CU_H*total_min/60*0.10:.2f})\n")
for e in BARRIDO:
    print(f"  ~{estimar_min(e)/60:4.1f} h · {hacer_tag({**DEFAULTS, **e})}")
# Out:
# GPU: NVIDIA L4 (1.71 unidades/h)
# 2 experimentos · ~7.2 h · ~12.3 compute units (~$1.23)
#
#   ~ 3.6 h · c1d_n45_conv1d_sess_char_unf1_lora1_lr0.001_els0.01_ctc1_bs32_ep30
#   ~ 3.6 h · lrdif_n45_linear_sess_char_unf1_lora1_lr0.001_els0.01_ctc1_bs32_ep30

# %% [markdown]
# ## 12. Ejecutar
#
# Con Colab Pro+ puedes activar la ejecución en segundo plano y cerrar el navegador. Si te desconectan a mitad, vuelve a lanzar esta celda: los experimentos terminados se saltan y el que estuviera a medias reanuda desde su `checkpoint.pth`.

# %%
# !du -sh /content/exp/* | sort -h | tail -5
inicio = time.time()
for cambios in BARRIDO:
    run_experiment(cambios)

print("=" * 78)
print(f"BARRIDO COMPLETO en {(time.time()-inicio)/60:.0f} min "
      f"(~{CU_H*(time.time()-inicio)/3600:.1f} compute units)")
print("Resultados en:", CSV_RESULTADOS)
# Out:
# du: cannot access '/content/exp/*': No such file or directory
# ==============================================================================
# [EXPERIMENTO] c1d_n45_conv1d_sess_char_unf1_lora1_lr0.001_els0.01_ctc1_bs32_ep30
# ==============================================================================
# Copiando 40 sesion(es) de Drive al disco local de la VM...
#   [1/40] t15.2023.08.18
#   [2/40] t15.2023.08.20
#   [3/40] t15.2023.08.25
#   [4/40] t15.2023.08.27
#   [5/40] t15.2023.09.01
#   [6/40] t15.2023.09.03
#   [7/40] t15.2023.09.24
#   [8/40] t15.2023.09.29
#   [9/40] t15.2023.10.01
#   [10/40] t15.2023.10.06
#   [11/40] t15.2023.10.08
#   [12/40] t15.2023.10.13
#   [13/40] t15.2023.10.15
#   [14/40] t15.2023.10.20
#   [15/40] t15.2023.10.22
#   [16/40] t15.2023.11.03
#   [17/40] t15.2023.11.04
#   [18/40] t15.2023.11.17
#   [19/40] t15.2023.11.19
#   [20/40] t15.2023.11.26
#   [21/40] t15.2023.12.03
#   [22/40] t15.2023.12.08
#   [23/40] t15.2023.12.10
#   [24/40] t15.2023.12.17
#   [25/40] t15.2023.12.29
#   [26/40] t15.2024.02.25
#   [27/40] t15.2024.03.08
#   [28/40] t15.2024.03.15
#   [29/40] t15.2024.03.17
#   [30/40] t15.2024.05.10
#   [31/40] t15.2024.06.14
#   [32/40] t15.2024.07.19
#   [33/40] t15.2024.07.21
#   [34/40] t15.2024.07.28
#   [35/40] t15.2025.01.10
#   [36/40] t15.2025.01.12
#   [37/40] t15.2025.03.14
#   [38/40] t15.2025.03.16
#   [39/40] t15.2025.03.30
#   [40/40] t15.2025.04.13
#   copiadas en 722s
# Sesiones (41): ['t15.2023.08.13', 't15.2023.08.18', 't15.2023.08.20'] ...
# Train: 7051 trials · Val: 1426 trials
#   batch=32 · ~220 pasos/epoca · warmup 800 (~3.6 epocas)
#   recopilando estadisticas (solo la primera vez por configuracion de datos)...
# /usr/bin/python3 /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-423e56c3-d614-4921-8fdd-3ae026ea1ba4.json
# WARNING:root:Set decoder to none as ctc_weight==1.0
#   frontend=conv1d + capa_sesion(41) · objetivo_ctc=char(29 clases) · lora=True · encoder=descongelado · ctc_weight=1.0 · norm=trial
#   37,531,037 entrenables / 37,531,037 totales (100.00%)
#   [nota] ctc_weight=1 -> ESPnet desactiva el decoder (solo CTC; la evaluacion sera greedy)
#   LR diferencial: 116 tensores a 0.001 · 230 a 1e-05
#   collect_stats OK
# /usr/bin/python3 /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-423e56c3-d614-4921-8fdd-3ae026ea1ba4.json
#     Saving the configuration in /content/exp/c1d_n45_conv1d_sess_char_unf1_lora1_lr0.001_els0.01_ctc1_bs32_ep30/config.yaml
#   frontend=conv1d + capa_sesion(41) · objetivo_ctc=char(29 clases) · lora=True · encoder=descongelado · ctc_weight=1.0 · norm=trial
#   37,531,037 entrenables / 37,531,037 totales (100.00%)
#   [nota] ctc_weight=1 -> ESPnet desactiva el decoder (solo CTC; la evaluacion sera greedy)
#   LR diferencial: 116 tensores a 0.001 · 230 a 1e-05
# /usr/local/lib/python3.12/dist-packages/espnet2/train/trainer.py:219: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
#     1/30epoch started
# /usr/local/lib/python3.12/dist-packages/espnet2/train/trainer.py:638: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(
# /usr/local/lib/python3.12/dist-packages/espnet2/s2t/espnet_model.py:338: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(False):
#     1epoch:train:1-10batch: iter_time=0.827, forward_time=0.277, loss_ctc=428.066, loss=428.066, backward_time=0.199, grad_norm=1.798e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.022, optim0_lr0=8.125e-06optim0_lr1=8.125e-08, train_time=1.463
#     1epoch:train:11-20batch: iter_time=0.823, forward_time=0.145, loss_ctc=419.843, loss=419.843, backward_time=0.126, grad_norm=1.379e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=2.062e-05, optim0_lr1=2.063e-07, train_time=1.254
#     1epoch:train:21-30batch: iter_time=0.846, forward_time=0.148, loss_ctc=405.198, loss=405.198, backward_time=0.127, grad_norm=1.770e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=3.312e-05, optim0_lr1=3.313e-07, train_time=1.283
#     1epoch:train:31-40batch: iter_time=0.858, forward_time=0.138, loss_ctc=372.377, loss=372.377, backward_time=0.120, grad_norm=1.028e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=4.563e-05, optim0_lr1=4.563e-07, train_time=1.269
#     1epoch:train:41-50batch: iter_time=0.866, forward_time=0.145, loss_ctc=350.466, loss=350.466, backward_time=0.125, grad_norm=1.405e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=5.812e-05, optim0_lr1=5.813e-07, train_time=1.297
#     1epoch:train:51-60batch: iter_time=0.810, forward_time=0.130, loss_ctc=260.980, loss=260.980, backward_time=0.115, grad_norm=1.573e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.063e-05, optim0_lr1=7.063e-07, train_time=1.202
#     1epoch:train:61-70batch: iter_time=0.838, forward_time=0.131, loss_ctc=166.811, loss=166.811, backward_time=0.115, grad_norm=4.268e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.313e-05, optim0_lr1=8.313e-07, train_time=1.233
#     1epoch:train:71-80batch: iter_time=0.860, forward_time=0.142, loss_ctc=150.336, loss=150.336, backward_time=0.124, grad_norm=3.152e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.563e-05, optim0_lr1=9.563e-07, train_time=1.285
#     1epoch:train:81-90batch: iter_time=0.864, forward_time=0.143, loss_ctc=135.947, loss=135.947, backward_time=0.125, grad_norm=1.955e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=1.081e-04, optim0_lr1=1.081e-06, train_time=1.292
#     1epoch:train:91-100batch: iter_time=0.869, forward_time=0.139, loss_ctc=144.333, loss=144.333, backward_time=0.122, grad_norm=2.004e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=1.206e-04, optim0_lr1=1.206e-06, train_time=1.284
#     1epoch:train:101-110batch: iter_time=0.754, forward_time=0.130, loss_ctc=130.391, loss=130.391, backward_time=0.113, grad_norm=2.082e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=1.331e-04, optim0_lr1=1.331e-06, train_time=1.144
#     1epoch:train:111-120batch: iter_time=0.820, forward_time=0.134, loss_ctc=128.829, loss=128.829, backward_time=0.121, grad_norm=445.930, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=1.456e-04, optim0_lr1=1.456e-06, train_time=1.219
#     1epoch:train:121-130batch: iter_time=0.849, forward_time=0.137, loss_ctc=121.397, loss=121.397, backward_time=0.118, grad_norm=387.465, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=1.581e-04, optim0_lr1=1.581e-06, train_time=1.257
#     1epoch:train:131-140batch: iter_time=0.888, forward_time=0.159, loss_ctc=125.874, loss=125.874, backward_time=0.138, grad_norm=360.603, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=1.706e-04, optim0_lr1=1.706e-06, train_time=1.359
#     1epoch:train:141-150batch: iter_time=0.881, forward_time=0.153, loss_ctc=122.137, loss=122.137, backward_time=0.133, grad_norm=438.551, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=1.831e-04, optim0_lr1=1.831e-06, train_time=1.335
#     1epoch:train:151-160batch: iter_time=0.738, forward_time=0.121, loss_ctc=111.202, loss=111.202, backward_time=0.108, grad_norm=340.226, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=1.956e-04, optim0_lr1=1.956e-06, train_time=1.106
#     1epoch:train:161-170batch: iter_time=0.791, forward_time=0.138, loss_ctc=107.787, loss=107.787, backward_time=0.121, grad_norm=585.786, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=2.081e-04, optim0_lr1=2.081e-06, train_time=1.205
#     1epoch:train:171-180batch: iter_time=0.850, forward_time=0.158, loss_ctc=104.702, loss=104.702, backward_time=0.136, grad_norm=512.353, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=2.206e-04, optim0_lr1=2.206e-06, train_time=1.317
#     1epoch:train:181-190batch: iter_time=0.831, forward_time=0.145, loss_ctc=101.757, loss=101.757, backward_time=0.126, grad_norm=356.963, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=2.331e-04, optim0_lr1=2.331e-06, train_time=1.263
#     1epoch:train:191-200batch: iter_time=0.837, forward_time=0.138, loss_ctc=96.527, loss=96.527, backward_time=0.121, grad_norm=329.376, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=2.456e-04, optim0_lr1=2.456e-06, train_time=1.251
#     1epoch:train:201-210batch: iter_time=0.762, forward_time=0.116, loss_ctc=91.995, loss=91.995, backward_time=0.103, grad_norm=240.844, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=2.581e-04, optim0_lr1=2.581e-06, train_time=1.114
#     1epoch:train:211-220batch: iter_time=0.827, forward_time=0.141, loss_ctc=97.363, loss=97.363, backward_time=0.121, grad_norm=389.560, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=2.706e-04, optim0_lr1=2.706e-06, train_time=1.248
# /usr/local/lib/python3.12/dist-packages/espnet2/train/trainer.py:856: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(
#     1epoch results: [train] iter_time=0.831, forward_time=0.146, loss_ctc=189.675, loss=189.675, backward_time=0.125, grad_norm=4.880e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=1.394e-04, optim0_lr1=1.394e-06, train_time=1.258, time=4 minutes and 37.15 seconds, total_count=220, gpu_max_cached_mem_GB=16.834, [valid] loss_ctc=103.294, cer_ctc=0.931, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=103.294, time=44.8 seconds, total_count=44, gpu_max_cached_mem_GB=16.834
#     The best model has been updated: valid.cer_ctc
#     2/30epoch started. Estimated time to finish: 2 hours, 37 minutes and 11.44 seconds
#     2epoch:train:1-10batch: iter_time=0.843, forward_time=0.139, loss_ctc=94.635, loss=94.635, backward_time=0.117, grad_norm=260.142, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=2.831e-04optim0_lr1=2.831e-06, train_time=1.262
#     2epoch:train:11-20batch: iter_time=0.861, forward_time=0.139, loss_ctc=99.120, loss=99.120, backward_time=0.117, grad_norm=239.278, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=2.956e-04, optim0_lr1=2.956e-06, train_time=1.278
#     2epoch:train:21-30batch: iter_time=0.831, forward_time=0.138, loss_ctc=90.746, loss=90.746, backward_time=0.117, grad_norm=282.800, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=3.081e-04, optim0_lr1=3.081e-06, train_time=1.247
#     2epoch:train:31-40batch: iter_time=0.896, forward_time=0.157, loss_ctc=98.812, loss=98.812, backward_time=0.132, grad_norm=291.108, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=3.206e-04, optim0_lr1=3.206e-06, train_time=1.362
#     2epoch:train:41-50batch: iter_time=0.880, forward_time=0.146, loss_ctc=96.218, loss=96.218, backward_time=0.122, grad_norm=253.752, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=3.331e-04, optim0_lr1=3.331e-06, train_time=1.317
#     2epoch:train:51-60batch: iter_time=0.789, forward_time=0.131, loss_ctc=93.022, loss=93.022, backward_time=0.111, grad_norm=249.254, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=3.456e-04, optim0_lr1=3.456e-06, train_time=1.183
#     2epoch:train:61-70batch: iter_time=0.833, forward_time=0.138, loss_ctc=91.130, loss=91.130, backward_time=0.117, grad_norm=175.177, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=3.581e-04, optim0_lr1=3.581e-06, train_time=1.247
#     2epoch:train:71-80batch: iter_time=0.810, forward_time=0.134, loss_ctc=90.943, loss=90.943, backward_time=0.112, grad_norm=161.115, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=3.706e-04, optim0_lr1=3.706e-06, train_time=1.214
#     2epoch:train:81-90batch: iter_time=0.914, forward_time=0.168, loss_ctc=93.516, loss=93.516, backward_time=0.141, grad_norm=266.618, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=3.831e-04, optim0_lr1=3.831e-06, train_time=1.410
#     2epoch:train:91-100batch: iter_time=0.738, forward_time=0.121, loss_ctc=79.688, loss=79.688, backward_time=0.103, grad_norm=224.131, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=3.956e-04, optim0_lr1=3.956e-06, train_time=1.106
#     2epoch:train:101-110batch: iter_time=0.842, forward_time=0.155, loss_ctc=92.151, loss=92.151, backward_time=0.129, grad_norm=237.677, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=4.081e-04, optim0_lr1=4.081e-06, train_time=1.304
#     2epoch:train:111-120batch: iter_time=0.832, forward_time=0.133, loss_ctc=95.743, loss=95.743, backward_time=0.112, grad_norm=267.579, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=4.206e-04, optim0_lr1=4.206e-06, train_time=1.235
#     2epoch:train:121-130batch: iter_time=0.776, forward_time=0.133, loss_ctc=90.592, loss=90.592, backward_time=0.112, grad_norm=240.893, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=4.331e-04, optim0_lr1=4.331e-06, train_time=1.177
#     2epoch:train:131-140batch: iter_time=0.804, forward_time=0.132, loss_ctc=83.129, loss=83.129, backward_time=0.113, grad_norm=487.426, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=4.456e-04, optim0_lr1=4.456e-06, train_time=1.203
#     2epoch:train:141-150batch: iter_time=0.805, forward_time=0.132, loss_ctc=87.881, loss=87.881, backward_time=0.113, grad_norm=180.595, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=4.581e-04, optim0_lr1=4.581e-06, train_time=1.205
#     2epoch:train:151-160batch: iter_time=0.842, forward_time=0.149, loss_ctc=91.428, loss=91.428, backward_time=0.124, grad_norm=182.039, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=4.706e-04, optim0_lr1=4.706e-06, train_time=1.284
#     2epoch:train:161-170batch: iter_time=0.842, forward_time=0.129, loss_ctc=88.307, loss=88.307, backward_time=0.111, grad_norm=183.182, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=4.831e-04, optim0_lr1=4.831e-06, train_time=1.232
#     2epoch:train:171-180batch: iter_time=0.814, forward_time=0.151, loss_ctc=91.046, loss=91.046, backward_time=0.127, grad_norm=191.800, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=4.956e-04, optim0_lr1=4.956e-06, train_time=1.264
#     2epoch:train:181-190batch: iter_time=0.823, forward_time=0.135, loss_ctc=91.833, loss=91.833, backward_time=0.115, grad_norm=229.791, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=5.081e-04, optim0_lr1=5.081e-06, train_time=1.229
#     2epoch:train:191-200batch: iter_time=0.777, forward_time=0.138, loss_ctc=87.647, loss=87.647, backward_time=0.116, grad_norm=219.554, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=5.206e-04, optim0_lr1=5.206e-06, train_time=1.192
#     2epoch:train:201-210batch: iter_time=0.831, forward_time=0.137, loss_ctc=87.918, loss=87.918, backward_time=0.115, grad_norm=166.059, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=5.331e-04, optim0_lr1=5.331e-06, train_time=1.242
#     2epoch:train:211-220batch: iter_time=0.784, forward_time=0.132, loss_ctc=86.745, loss=86.745, backward_time=0.112, grad_norm=149.145, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=5.456e-04, optim0_lr1=5.456e-06, train_time=1.182
#     2epoch results: [train] iter_time=0.826, forward_time=0.140, loss_ctc=91.012, loss=91.012, backward_time=0.118, grad_norm=233.596, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=4.144e-04, optim0_lr1=4.144e-06, train_time=1.244, time=4 minutes and 33.85 seconds, total_count=440, gpu_max_cached_mem_GB=20.570, [valid] loss_ctc=99.732, cer_ctc=0.968, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=99.732, time=44.5 seconds, total_count=88, gpu_max_cached_mem_GB=20.570
#     There are no improvements in this epoch
#     3/30epoch started. Estimated time to finish: 2 hours, 30 minutes and 54.77 seconds
#     3epoch:train:1-10batch: iter_time=0.812, forward_time=0.136, loss_ctc=90.710, loss=90.710, backward_time=0.116, grad_norm=209.506, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=5.581e-04optim0_lr1=5.581e-06, train_time=1.223
#     3epoch:train:11-20batch: iter_time=0.833, forward_time=0.162, loss_ctc=87.693, loss=87.693, backward_time=0.136, grad_norm=212.250, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=5.706e-04, optim0_lr1=5.706e-06, train_time=1.312
#     3epoch:train:21-30batch: iter_time=0.863, forward_time=0.148, loss_ctc=90.433, loss=90.433, backward_time=0.123, grad_norm=155.909, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=5.831e-04, optim0_lr1=5.831e-06, train_time=1.305
#     3epoch:train:31-40batch: iter_time=0.874, forward_time=0.135, loss_ctc=95.228, loss=95.228, backward_time=0.113, grad_norm=346.708, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=5.956e-04, optim0_lr1=5.956e-06, train_time=1.280
#     3epoch:train:41-50batch: iter_time=0.793, forward_time=0.122, loss_ctc=86.399, loss=86.399, backward_time=0.104, grad_norm=199.351, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=6.081e-04, optim0_lr1=6.081e-06, train_time=1.165
#     3epoch:train:51-60batch: iter_time=0.820, forward_time=0.140, loss_ctc=89.797, loss=89.797, backward_time=0.117, grad_norm=191.929, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=6.206e-04, optim0_lr1=6.206e-06, train_time=1.239
#     3epoch:train:61-70batch: iter_time=0.809, forward_time=0.131, loss_ctc=85.047, loss=85.047, backward_time=0.110, grad_norm=195.908, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=6.331e-04, optim0_lr1=6.331e-06, train_time=1.204
#     3epoch:train:71-80batch: iter_time=0.796, forward_time=0.135, loss_ctc=82.895, loss=82.895, backward_time=0.113, grad_norm=244.907, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=6.456e-04, optim0_lr1=6.456e-06, train_time=1.201
#     3epoch:train:81-90batch: iter_time=0.898, forward_time=0.177, loss_ctc=86.972, loss=86.972, backward_time=0.130, grad_norm=140.958, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=6.581e-04, optim0_lr1=6.581e-06, train_time=1.381
#     3epoch:train:91-100batch: iter_time=0.902, forward_time=0.163, loss_ctc=92.887, loss=92.887, backward_time=0.135, grad_norm=173.484, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=6.706e-04, optim0_lr1=6.706e-06, train_time=1.384
#     3epoch:train:101-110batch: iter_time=0.847, forward_time=0.141, loss_ctc=87.147, loss=87.147, backward_time=0.118, grad_norm=194.762, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=6.831e-04, optim0_lr1=6.831e-06, train_time=1.269
#     3epoch:train:111-120batch: iter_time=0.842, forward_time=0.116, loss_ctc=89.533, loss=89.533, backward_time=0.100, grad_norm=118.017, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=6.956e-04, optim0_lr1=6.956e-06, train_time=1.198
#     3epoch:train:121-130batch: iter_time=0.792, forward_time=0.109, loss_ctc=84.594, loss=84.594, backward_time=0.093, grad_norm=188.031, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.081e-04, optim0_lr1=7.081e-06, train_time=1.127
#     3epoch:train:131-140batch: iter_time=0.854, forward_time=0.149, loss_ctc=91.058, loss=91.058, backward_time=0.124, grad_norm=193.251, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.206e-04, optim0_lr1=7.206e-06, train_time=1.297
#     3epoch:train:141-150batch: iter_time=0.886, forward_time=0.126, loss_ctc=87.212, loss=87.212, backward_time=0.107, grad_norm=222.418, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.331e-04, optim0_lr1=7.331e-06, train_time=1.270
#     3epoch:train:151-160batch: iter_time=0.885, forward_time=0.156, loss_ctc=86.847, loss=86.847, backward_time=0.130, grad_norm=309.821, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.456e-04, optim0_lr1=7.456e-06, train_time=1.347
#     3epoch:train:161-170batch: iter_time=0.835, forward_time=0.149, loss_ctc=89.154, loss=89.154, backward_time=0.127, grad_norm=282.839, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.581e-04, optim0_lr1=7.581e-06, train_time=1.279
#     3epoch:train:171-180batch: iter_time=0.888, forward_time=0.132, loss_ctc=88.663, loss=88.663, backward_time=0.110, grad_norm=210.140, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.706e-04, optim0_lr1=7.706e-06, train_time=1.284
#     3epoch:train:181-190batch: iter_time=0.783, forward_time=0.128, loss_ctc=88.195, loss=88.195, backward_time=0.108, grad_norm=310.547, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.831e-04, optim0_lr1=7.831e-06, train_time=1.172
#     3epoch:train:191-200batch: iter_time=0.904, forward_time=0.169, loss_ctc=90.074, loss=90.074, backward_time=0.140, grad_norm=214.784, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.956e-04, optim0_lr1=7.956e-06, train_time=1.403
#     3epoch:train:201-210batch: iter_time=0.861, forward_time=0.143, loss_ctc=85.071, loss=85.071, backward_time=0.120, grad_norm=143.050, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.081e-04, optim0_lr1=8.081e-06, train_time=1.291
#     3epoch:train:211-220batch: iter_time=0.818, forward_time=0.126, loss_ctc=79.885, loss=79.885, backward_time=0.110, grad_norm=89.149, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.206e-04, optim0_lr1=8.206e-06, train_time=1.203
#     3epoch results: [train] iter_time=0.845, forward_time=0.141, loss_ctc=87.976, loss=87.976, backward_time=0.117, grad_norm=206.714, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=6.894e-04, optim0_lr1=6.894e-06, train_time=1.265, time=4 minutes and 38.4 seconds, total_count=660, gpu_max_cached_mem_GB=21.734, [valid] loss_ctc=91.426, cer_ctc=0.934, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=91.426, time=46.12 seconds, total_count=132, gpu_max_cached_mem_GB=21.734
#     There are no improvements in this epoch
#     4/30epoch started. Estimated time to finish: 2 hours, 26 minutes and 10.12 seconds
#     4epoch:train:1-10batch: iter_time=0.857, forward_time=0.132, loss_ctc=88.806, loss=88.806, backward_time=0.113, grad_norm=125.730, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.331e-04optim0_lr1=8.331e-06, train_time=1.257
#     4epoch:train:11-20batch: iter_time=0.802, forward_time=0.128, loss_ctc=84.986, loss=84.986, backward_time=0.108, grad_norm=152.058, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.456e-04, optim0_lr1=8.456e-06, train_time=1.190
#     4epoch:train:21-30batch: iter_time=0.914, forward_time=0.163, loss_ctc=90.930, loss=90.930, backward_time=0.136, grad_norm=236.025, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.581e-04, optim0_lr1=8.581e-06, train_time=1.396
#     4epoch:train:31-40batch: iter_time=0.906, forward_time=0.160, loss_ctc=84.260, loss=84.260, backward_time=0.132, grad_norm=130.155, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.706e-04, optim0_lr1=8.706e-06, train_time=1.379
#     4epoch:train:41-50batch: iter_time=0.796, forward_time=0.128, loss_ctc=79.445, loss=79.445, backward_time=0.109, grad_norm=164.188, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.831e-04, optim0_lr1=8.831e-06, train_time=1.185
#     4epoch:train:51-60batch: iter_time=0.921, forward_time=0.175, loss_ctc=86.508, loss=86.508, backward_time=0.144, grad_norm=127.713, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.956e-04, optim0_lr1=8.956e-06, train_time=1.425
#     4epoch:train:61-70batch: iter_time=0.895, forward_time=0.148, loss_ctc=86.678, loss=86.678, backward_time=0.124, grad_norm=212.141, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.081e-04, optim0_lr1=9.081e-06, train_time=1.337
#     4epoch:train:71-80batch: iter_time=0.823, forward_time=0.117, loss_ctc=92.049, loss=92.049, backward_time=0.099, grad_norm=140.964, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.206e-04, optim0_lr1=9.206e-06, train_time=1.180
#     4epoch:train:81-90batch: iter_time=0.765, forward_time=0.122, loss_ctc=87.552, loss=87.552, backward_time=0.106, grad_norm=359.699, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.331e-04, optim0_lr1=9.331e-06, train_time=1.139
#     4epoch:train:91-100batch: iter_time=0.789, forward_time=0.122, loss_ctc=88.790, loss=88.790, backward_time=0.104, grad_norm=209.208, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=9.456e-04, optim0_lr1=9.456e-06, train_time=1.160
#     4epoch:train:101-110batch: iter_time=0.824, forward_time=0.128, loss_ctc=87.462, loss=87.462, backward_time=0.108, grad_norm=138.709, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=9.581e-04, optim0_lr1=9.581e-06, train_time=1.211
#     4epoch:train:111-120batch: iter_time=0.781, forward_time=0.127, loss_ctc=92.578, loss=92.578, backward_time=0.109, grad_norm=174.362, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.706e-04, optim0_lr1=9.706e-06, train_time=1.167
#     4epoch:train:121-130batch: iter_time=0.782, forward_time=0.128, loss_ctc=83.848, loss=83.848, backward_time=0.108, grad_norm=111.996, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.831e-04, optim0_lr1=9.831e-06, train_time=1.170
#     4epoch:train:131-140batch: iter_time=0.834, forward_time=0.131, loss_ctc=89.434, loss=89.434, backward_time=0.112, grad_norm=109.789, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.954e-04, optim0_lr1=9.954e-06, train_time=1.231
#     4epoch:train:141-150batch: iter_time=0.918, forward_time=0.145, loss_ctc=92.026, loss=92.026, backward_time=0.122, grad_norm=404.929, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.960e-04, optim0_lr1=9.960e-06, train_time=1.352
#     4epoch:train:151-160batch: iter_time=0.889, forward_time=0.159, loss_ctc=90.989, loss=90.989, backward_time=0.132, grad_norm=236.294, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.898e-04, optim0_lr1=9.898e-06, train_time=1.360
#     4epoch:train:161-170batch: iter_time=0.861, forward_time=0.130, loss_ctc=89.156, loss=89.156, backward_time=0.110, grad_norm=121.911, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.838e-04, optim0_lr1=9.838e-06, train_time=1.254
#     4epoch:train:171-180batch: iter_time=0.925, forward_time=0.161, loss_ctc=92.596, loss=92.596, backward_time=0.135, grad_norm=181.910, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=9.779e-04, optim0_lr1=9.779e-06, train_time=1.403
#     4epoch:train:181-190batch: iter_time=0.848, forward_time=0.145, loss_ctc=84.554, loss=84.554, backward_time=0.121, grad_norm=166.500, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.722e-04, optim0_lr1=9.722e-06, train_time=1.280
#     4epoch:train:191-200batch: iter_time=0.895, forward_time=0.151, loss_ctc=95.306, loss=95.306, backward_time=0.125, grad_norm=157.617, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=9.665e-04, optim0_lr1=9.665e-06, train_time=1.345
#     4epoch:train:201-210batch: iter_time=0.885, forward_time=0.136, loss_ctc=95.104, loss=95.104, backward_time=0.114, grad_norm=176.115, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=9.609e-04, optim0_lr1=9.609e-06, train_time=1.293
#     4epoch:train:211-220batch: iter_time=0.863, forward_time=0.139, loss_ctc=81.715, loss=81.715, backward_time=0.117, grad_norm=121.422, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.554e-04, optim0_lr1=9.554e-06, train_time=1.281
#     4epoch results: [train] iter_time=0.853, forward_time=0.140, loss_ctc=88.401, loss=88.401, backward_time=0.118, grad_norm=179.974, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.365e-04, optim0_lr1=9.365e-06, train_time=1.272, time=4 minutes and 40 seconds, total_count=880, gpu_max_cached_mem_GB=21.734, [valid] loss_ctc=89.820, cer_ctc=0.873, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=89.820, time=48.28 seconds, total_count=176, gpu_max_cached_mem_GB=21.734
#     The best model has been updated: valid.cer_ctc
#     5/30epoch started. Estimated time to finish: 2 hours, 21 minutes and 29.76 seconds
#     5epoch:train:1-10batch: iter_time=0.793, forward_time=0.140, loss_ctc=81.417, loss=81.417, backward_time=0.117, grad_norm=66.928, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=9.500e-04optim0_lr1=9.500e-06, train_time=1.212
#     5epoch:train:11-20batch: iter_time=0.833, forward_time=0.130, loss_ctc=84.683, loss=84.683, backward_time=0.112, grad_norm=93.898, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.447e-04, optim0_lr1=9.447e-06, train_time=1.226
#     5epoch:train:21-30batch: iter_time=0.752, forward_time=0.113, loss_ctc=79.387, loss=79.387, backward_time=0.096, grad_norm=122.927, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=9.394e-04, optim0_lr1=9.394e-06, train_time=1.098
#     5epoch:train:31-40batch: iter_time=0.855, forward_time=0.142, loss_ctc=87.792, loss=87.792, backward_time=0.119, grad_norm=194.833, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.343e-04, optim0_lr1=9.343e-06, train_time=1.283
#     5epoch:train:41-50batch: iter_time=0.826, forward_time=0.126, loss_ctc=87.496, loss=87.496, backward_time=0.111, grad_norm=153.787, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=9.292e-04, optim0_lr1=9.292e-06, train_time=1.209
#     5epoch:train:51-60batch: iter_time=0.848, forward_time=0.126, loss_ctc=88.036, loss=88.036, backward_time=0.107, grad_norm=197.264, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.243e-04, optim0_lr1=9.243e-06, train_time=1.230
#     5epoch:train:61-70batch: iter_time=0.818, forward_time=0.133, loss_ctc=84.201, loss=84.201, backward_time=0.112, grad_norm=139.445, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.194e-04, optim0_lr1=9.194e-06, train_time=1.219
#     5epoch:train:71-80batch: iter_time=0.856, forward_time=0.134, loss_ctc=84.971, loss=84.971, backward_time=0.114, grad_norm=137.679, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.145e-04, optim0_lr1=9.145e-06, train_time=1.261
#     5epoch:train:81-90batch: iter_time=0.829, forward_time=0.137, loss_ctc=82.436, loss=82.436, backward_time=0.115, grad_norm=101.487, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.098e-04, optim0_lr1=9.098e-06, train_time=1.241
#     5epoch:train:91-100batch: iter_time=0.879, forward_time=0.162, loss_ctc=89.560, loss=89.560, backward_time=0.134, grad_norm=133.726, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.051e-04, optim0_lr1=9.051e-06, train_time=1.358
#     5epoch:train:101-110batch: iter_time=0.848, forward_time=0.154, loss_ctc=86.484, loss=86.484, backward_time=0.127, grad_norm=85.764, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=9.005e-04, optim0_lr1=9.005e-06, train_time=1.304
#     5epoch:train:111-120batch: iter_time=0.950, forward_time=0.185, loss_ctc=90.078, loss=90.078, backward_time=0.153, grad_norm=109.551, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.960e-04, optim0_lr1=8.960e-06, train_time=1.492
#     5epoch:train:121-130batch: iter_time=0.884, forward_time=0.151, loss_ctc=82.889, loss=82.889, backward_time=0.126, grad_norm=74.455, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.915e-04, optim0_lr1=8.915e-06, train_time=1.335
#     5epoch:train:131-140batch: iter_time=0.859, forward_time=0.135, loss_ctc=82.974, loss=82.974, backward_time=0.114, grad_norm=98.341, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.871e-04, optim0_lr1=8.871e-06, train_time=1.266
#     5epoch:train:141-150batch: iter_time=0.811, forward_time=0.118, loss_ctc=81.482, loss=81.482, backward_time=0.101, grad_norm=75.504, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.828e-04, optim0_lr1=8.828e-06, train_time=1.174
#     5epoch:train:151-160batch: iter_time=0.859, forward_time=0.145, loss_ctc=86.439, loss=86.439, backward_time=0.121, grad_norm=125.221, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=8.785e-04, optim0_lr1=8.785e-06, train_time=1.292
#     5epoch:train:161-170batch: iter_time=0.910, forward_time=0.142, loss_ctc=87.659, loss=87.659, backward_time=0.119, grad_norm=92.897, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.743e-04, optim0_lr1=8.743e-06, train_time=1.337
#     5epoch:train:171-180batch: iter_time=0.919, forward_time=0.146, loss_ctc=84.901, loss=84.901, backward_time=0.122, grad_norm=116.223, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=8.702e-04, optim0_lr1=8.702e-06, train_time=1.385
#     5epoch:train:181-190batch: iter_time=0.961, forward_time=0.146, loss_ctc=85.780, loss=85.780, backward_time=0.123, grad_norm=96.546, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=8.661e-04, optim0_lr1=8.661e-06, train_time=1.397
#     5epoch:train:191-200batch: iter_time=0.847, forward_time=0.124, loss_ctc=84.255, loss=84.255, backward_time=0.105, grad_norm=128.139, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=8.621e-04, optim0_lr1=8.621e-06, train_time=1.225
#     5epoch:train:201-210batch: iter_time=0.907, forward_time=0.155, loss_ctc=87.062, loss=87.062, backward_time=0.130, grad_norm=93.200, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=8.581e-04, optim0_lr1=8.581e-06, train_time=1.368
#     5epoch:train:211-220batch: iter_time=0.853, forward_time=0.124, loss_ctc=84.752, loss=84.752, backward_time=0.107, grad_norm=93.454, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=8.542e-04, optim0_lr1=8.542e-06, train_time=1.231
#     5epoch results: [train] iter_time=0.859, forward_time=0.140, loss_ctc=85.217, loss=85.217, backward_time=0.117, grad_norm=115.058, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.996e-04, optim0_lr1=8.996e-06, train_time=1.279, time=4 minutes and 41.49 seconds, total_count=1100, gpu_max_cached_mem_GB=21.734, [valid] loss_ctc=89.645, cer_ctc=0.875, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=89.645, time=45.88 seconds, total_count=220, gpu_max_cached_mem_GB=21.734
#     There are no improvements in this epoch
#     6/30epoch started. Estimated time to finish: 2 hours, 16 minutes and 23.92 seconds
#     6epoch:train:1-10batch: iter_time=0.785, forward_time=0.116, loss_ctc=81.248, loss=81.248, backward_time=0.100, grad_norm=110.319, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=8.503e-04optim0_lr1=8.503e-06, train_time=1.140
#     6epoch:train:11-20batch: iter_time=0.850, forward_time=0.146, loss_ctc=87.292, loss=87.292, backward_time=0.121, grad_norm=100.360, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.465e-04, optim0_lr1=8.465e-06, train_time=1.285
#     6epoch:train:21-30batch: iter_time=0.793, forward_time=0.117, loss_ctc=81.936, loss=81.936, backward_time=0.102, grad_norm=100.452, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=8.427e-04, optim0_lr1=8.427e-06, train_time=1.152
#     6epoch:train:31-40batch: iter_time=0.833, forward_time=0.161, loss_ctc=83.144, loss=83.144, backward_time=0.134, grad_norm=86.837, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.390e-04, optim0_lr1=8.390e-06, train_time=1.311
#     6epoch:train:41-50batch: iter_time=0.848, forward_time=0.144, loss_ctc=85.159, loss=85.159, backward_time=0.125, grad_norm=89.363, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.353e-04, optim0_lr1=8.353e-06, train_time=1.281
#     6epoch:train:51-60batch: iter_time=0.893, forward_time=0.146, loss_ctc=88.413, loss=88.413, backward_time=0.122, grad_norm=125.370, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.317e-04, optim0_lr1=8.317e-06, train_time=1.330
#     6epoch:train:61-70batch: iter_time=0.869, forward_time=0.149, loss_ctc=89.135, loss=89.135, backward_time=0.125, grad_norm=156.646, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.281e-04, optim0_lr1=8.281e-06, train_time=1.313
#     6epoch:train:71-80batch: iter_time=0.871, forward_time=0.140, loss_ctc=85.779, loss=85.779, backward_time=0.117, grad_norm=94.633, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=8.246e-04, optim0_lr1=8.246e-06, train_time=1.291
#     6epoch:train:81-90batch: iter_time=0.766, forward_time=0.113, loss_ctc=82.787, loss=82.787, backward_time=0.096, grad_norm=79.771, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.211e-04, optim0_lr1=8.211e-06, train_time=1.112
#     6epoch:train:91-100batch: iter_time=0.860, forward_time=0.155, loss_ctc=82.472, loss=82.472, backward_time=0.130, grad_norm=95.042, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.177e-04, optim0_lr1=8.177e-06, train_time=1.319
#     6epoch:train:101-110batch: iter_time=0.882, forward_time=0.152, loss_ctc=86.695, loss=86.695, backward_time=0.126, grad_norm=122.437, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.143e-04, optim0_lr1=8.143e-06, train_time=1.334
#     6epoch:train:111-120batch: iter_time=0.771, forward_time=0.124, loss_ctc=80.234, loss=80.234, backward_time=0.104, grad_norm=95.042, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.109e-04, optim0_lr1=8.109e-06, train_time=1.147
#     6epoch:train:121-130batch: iter_time=0.836, forward_time=0.136, loss_ctc=79.538, loss=79.538, backward_time=0.114, grad_norm=87.357, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.076e-04, optim0_lr1=8.076e-06, train_time=1.245
#     6epoch:train:131-140batch: iter_time=0.839, forward_time=0.138, loss_ctc=81.875, loss=81.875, backward_time=0.117, grad_norm=114.056, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.044e-04, optim0_lr1=8.044e-06, train_time=1.253
#     6epoch:train:141-150batch: iter_time=0.834, forward_time=0.140, loss_ctc=85.567, loss=85.567, backward_time=0.117, grad_norm=124.846, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.011e-04, optim0_lr1=8.011e-06, train_time=1.253
#     6epoch:train:151-160batch: iter_time=0.786, forward_time=0.132, loss_ctc=81.995, loss=81.995, backward_time=0.111, grad_norm=96.716, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.979e-04, optim0_lr1=7.979e-06, train_time=1.184
#     6epoch:train:161-170batch: iter_time=0.887, forward_time=0.160, loss_ctc=83.583, loss=83.583, backward_time=0.133, grad_norm=78.457, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.948e-04, optim0_lr1=7.948e-06, train_time=1.361
#     6epoch:train:171-180batch: iter_time=0.765, forward_time=0.127, loss_ctc=80.032, loss=80.032, backward_time=0.108, grad_norm=71.400, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.917e-04, optim0_lr1=7.917e-06, train_time=1.151
#     6epoch:train:181-190batch: iter_time=0.794, forward_time=0.123, loss_ctc=82.215, loss=82.215, backward_time=0.106, grad_norm=85.930, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.886e-04, optim0_lr1=7.886e-06, train_time=1.169
#     6epoch:train:191-200batch: iter_time=0.855, forward_time=0.165, loss_ctc=81.869, loss=81.869, backward_time=0.133, grad_norm=105.393, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.855e-04, optim0_lr1=7.855e-06, train_time=1.333
#     6epoch:train:201-210batch: iter_time=0.788, forward_time=0.129, loss_ctc=83.864, loss=83.864, backward_time=0.108, grad_norm=117.097, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.825e-04, optim0_lr1=7.825e-06, train_time=1.177
#     6epoch:train:211-220batch: iter_time=0.889, forward_time=0.162, loss_ctc=83.633, loss=83.633, backward_time=0.133, grad_norm=83.369, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.795e-04, optim0_lr1=7.795e-06, train_time=1.367
#     6epoch results: [train] iter_time=0.832, forward_time=0.140, loss_ctc=83.567, loss=83.567, backward_time=0.117, grad_norm=100.950, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=8.135e-04, optim0_lr1=8.135e-06, train_time=1.250, time=4 minutes and 35.14 seconds, total_count=1320, gpu_max_cached_mem_GB=21.748, [valid] loss_ctc=86.520, cer_ctc=0.880, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=86.520, time=44.69 seconds, total_count=264, gpu_max_cached_mem_GB=21.748
#     There are no improvements in this epoch
#     7/30epoch started. Estimated time to finish: 2 hours, 10 minutes and 39.97 seconds
#     7epoch:train:1-10batch: iter_time=0.910, forward_time=0.169, loss_ctc=88.918, loss=88.918, backward_time=0.141, grad_norm=97.199, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=7.766e-04optim0_lr1=7.766e-06, train_time=1.407
#     7epoch:train:11-20batch: iter_time=0.797, forward_time=0.124, loss_ctc=82.966, loss=82.966, backward_time=0.106, grad_norm=111.227, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.737e-04, optim0_lr1=7.737e-06, train_time=1.171
#     7epoch:train:21-30batch: iter_time=0.753, forward_time=0.112, loss_ctc=75.141, loss=75.141, backward_time=0.096, grad_norm=84.302, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.708e-04, optim0_lr1=7.708e-06, train_time=1.097
#     7epoch:train:31-40batch: iter_time=0.803, forward_time=0.146, loss_ctc=82.911, loss=82.911, backward_time=0.124, grad_norm=145.058, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=7.680e-04, optim0_lr1=7.680e-06, train_time=1.240
#     7epoch:train:41-50batch: iter_time=0.887, forward_time=0.166, loss_ctc=86.267, loss=86.267, backward_time=0.137, grad_norm=110.701, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.651e-04, optim0_lr1=7.651e-06, train_time=1.378
#     7epoch:train:51-60batch: iter_time=0.750, forward_time=0.119, loss_ctc=79.303, loss=79.303, backward_time=0.102, grad_norm=109.308, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.624e-04, optim0_lr1=7.624e-06, train_time=1.113
#     7epoch:train:61-70batch: iter_time=0.854, forward_time=0.149, loss_ctc=82.825, loss=82.825, backward_time=0.124, grad_norm=96.534, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.596e-04, optim0_lr1=7.596e-06, train_time=1.299
#     7epoch:train:71-80batch: iter_time=0.862, forward_time=0.141, loss_ctc=79.810, loss=79.810, backward_time=0.118, grad_norm=93.199, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=7.569e-04, optim0_lr1=7.569e-06, train_time=1.285
#     7epoch:train:81-90batch: iter_time=0.789, forward_time=0.115, loss_ctc=82.515, loss=82.515, backward_time=0.098, grad_norm=110.770, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.542e-04, optim0_lr1=7.542e-06, train_time=1.143
#     7epoch:train:91-100batch: iter_time=0.875, forward_time=0.130, loss_ctc=86.017, loss=86.017, backward_time=0.112, grad_norm=80.635, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.515e-04, optim0_lr1=7.515e-06, train_time=1.269
#     7epoch:train:101-110batch: iter_time=0.825, forward_time=0.132, loss_ctc=83.212, loss=83.212, backward_time=0.111, grad_norm=76.575, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.489e-04, optim0_lr1=7.489e-06, train_time=1.223
#     7epoch:train:111-120batch: iter_time=0.878, forward_time=0.152, loss_ctc=85.030, loss=85.030, backward_time=0.126, grad_norm=120.435, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=7.463e-04, optim0_lr1=7.463e-06, train_time=1.330
#     7epoch:train:121-130batch: iter_time=0.847, forward_time=0.155, loss_ctc=81.452, loss=81.452, backward_time=0.129, grad_norm=82.519, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.437e-04, optim0_lr1=7.437e-06, train_time=1.310
#     7epoch:train:131-140batch: iter_time=0.832, forward_time=0.153, loss_ctc=82.318, loss=82.318, backward_time=0.127, grad_norm=99.563, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.411e-04, optim0_lr1=7.411e-06, train_time=1.288
#     7epoch:train:141-150batch: iter_time=0.800, forward_time=0.129, loss_ctc=80.626, loss=80.626, backward_time=0.108, grad_norm=73.991, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=7.386e-04, optim0_lr1=7.386e-06, train_time=1.189
#     7epoch:train:151-160batch: iter_time=0.870, forward_time=0.147, loss_ctc=82.785, loss=82.785, backward_time=0.123, grad_norm=121.938, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.361e-04, optim0_lr1=7.361e-06, train_time=1.308
#     7epoch:train:161-170batch: iter_time=0.843, forward_time=0.121, loss_ctc=85.380, loss=85.380, backward_time=0.105, grad_norm=155.703, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.336e-04, optim0_lr1=7.336e-06, train_time=1.213
#     7epoch:train:171-180batch: iter_time=0.844, forward_time=0.114, loss_ctc=80.775, loss=80.775, backward_time=0.097, grad_norm=77.941, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=7.312e-04, optim0_lr1=7.312e-06, train_time=1.193
#     7epoch:train:181-190batch: iter_time=0.884, forward_time=0.171, loss_ctc=82.104, loss=82.104, backward_time=0.142, grad_norm=80.435, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=7.287e-04, optim0_lr1=7.287e-06, train_time=1.388
#     7epoch:train:191-200batch: iter_time=0.863, forward_time=0.137, loss_ctc=84.437, loss=84.437, backward_time=0.115, grad_norm=87.966, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=7.263e-04, optim0_lr1=7.263e-06, train_time=1.276
#     7epoch:train:201-210batch: iter_time=0.869, forward_time=0.159, loss_ctc=83.111, loss=83.111, backward_time=0.132, grad_norm=79.049, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.239e-04, optim0_lr1=7.239e-06, train_time=1.341
#     7epoch:train:211-220batch: iter_time=0.859, forward_time=0.128, loss_ctc=85.552, loss=85.552, backward_time=0.108, grad_norm=111.549, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.216e-04, optim0_lr1=7.216e-06, train_time=1.246
#     7epoch results: [train] iter_time=0.841, forward_time=0.140, loss_ctc=82.886, loss=82.886, backward_time=0.117, grad_norm=100.300, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.008, optim0_lr0=7.481e-04, optim0_lr1=7.481e-06, train_time=1.259, time=4 minutes and 37.11 seconds, total_count=1540, gpu_max_cached_mem_GB=21.748, [valid] loss_ctc=85.278, cer_ctc=0.875, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=85.278, time=45.92 seconds, total_count=308, gpu_max_cached_mem_GB=21.748
#     There are no improvements in this epoch
#     8/30epoch started. Estimated time to finish: 2 hours, 5 minutes and 12.75 seconds
#     8epoch:train:1-10batch: iter_time=0.861, forward_time=0.138, loss_ctc=78.477, loss=78.477, backward_time=0.117, grad_norm=71.834, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.009, optim0_lr0=7.192e-04optim0_lr1=7.192e-06, train_time=1.274
# ...
#     28epoch:train:161-170batch: iter_time=0.849, forward_time=0.147, loss_ctc=77.640, loss=77.640, backward_time=0.123, grad_norm=159.872, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.620e-04, optim0_lr1=3.620e-06, train_time=1.287
#     28epoch:train:171-180batch: iter_time=0.915, forward_time=0.158, loss_ctc=78.662, loss=78.662, backward_time=0.132, grad_norm=340.611, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.617e-04, optim0_lr1=3.617e-06, train_time=1.382
#     28epoch:train:181-190batch: iter_time=0.835, forward_time=0.129, loss_ctc=79.490, loss=79.490, backward_time=0.111, grad_norm=421.118, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.614e-04, optim0_lr1=3.614e-06, train_time=1.223
#     28epoch:train:191-200batch: iter_time=0.837, forward_time=0.127, loss_ctc=76.087, loss=76.087, backward_time=0.108, grad_norm=175.946, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.611e-04, optim0_lr1=3.611e-06, train_time=1.221
#     28epoch:train:201-210batch: iter_time=0.822, forward_time=0.149, loss_ctc=76.584, loss=76.584, backward_time=0.125, grad_norm=166.056, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.608e-04, optim0_lr1=3.608e-06, train_time=1.266
#     28epoch:train:211-220batch: iter_time=0.900, forward_time=0.155, loss_ctc=78.478, loss=78.478, backward_time=0.129, grad_norm=165.995, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.605e-04, optim0_lr1=3.605e-06, train_time=1.359
#     28epoch results: [train] iter_time=0.853, forward_time=0.136, loss_ctc=78.465, loss=78.465, backward_time=0.115, grad_norm=281.040, clip=100.000, loss_scale=4.528e+05, optim_step_time=0.009, optim0_lr0=3.636e-04, optim0_lr1=3.636e-06, train_time=1.262, time=4 minutes and 37.69 seconds, total_count=6160, gpu_max_cached_mem_GB=21.775, [valid] loss_ctc=81.805, cer_ctc=0.870, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=81.805, time=45.28 seconds, total_count=1232, gpu_max_cached_mem_GB=21.775
#     There are no improvements in this epoch
#     29/30epoch started. Estimated time to finish: 10 minutes and 54.87 seconds
#     29epoch:train:1-10batch: iter_time=0.830, forward_time=0.122, loss_ctc=77.344, loss=77.344, backward_time=0.105, grad_norm=196.277, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.602e-04optim0_lr1=3.602e-06, train_time=1.200
#     29epoch:train:11-20batch: iter_time=0.822, forward_time=0.128, loss_ctc=73.988, loss=73.988, backward_time=0.108, grad_norm=225.403, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.599e-04, optim0_lr1=3.599e-06, train_time=1.209
#     29epoch:train:21-30batch: iter_time=0.790, forward_time=0.122, loss_ctc=79.609, loss=79.609, backward_time=0.104, grad_norm=269.737, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.596e-04, optim0_lr1=3.596e-06, train_time=1.161
#     29epoch:train:31-40batch: iter_time=0.876, forward_time=0.161, loss_ctc=80.709, loss=80.709, backward_time=0.134, grad_norm=160.463, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.593e-04, optim0_lr1=3.593e-06, train_time=1.353
#     29epoch:train:41-50batch: iter_time=0.781, forward_time=0.122, loss_ctc=73.986, loss=73.986, backward_time=0.103, grad_norm=233.684, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.590e-04, optim0_lr1=3.590e-06, train_time=1.149
#     29epoch:train:51-60batch: iter_time=0.755, forward_time=0.129, loss_ctc=72.683, loss=72.683, backward_time=0.110, grad_norm=425.572, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.587e-04, optim0_lr1=3.587e-06, train_time=1.142
#     29epoch:train:61-70batch: iter_time=0.886, forward_time=0.137, loss_ctc=80.422, loss=80.422, backward_time=0.116, grad_norm=250.549, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.584e-04, optim0_lr1=3.584e-06, train_time=1.295
#     29epoch:train:71-80batch: iter_time=0.781, forward_time=0.113, loss_ctc=77.959, loss=77.959, backward_time=0.096, grad_norm=298.592, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.582e-04, optim0_lr1=3.582e-06, train_time=1.125
#     29epoch:train:81-90batch: iter_time=0.854, forward_time=0.124, loss_ctc=78.047, loss=78.047, backward_time=0.106, grad_norm=262.332, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.579e-04, optim0_lr1=3.579e-06, train_time=1.227
#     29epoch:train:91-100batch: iter_time=0.859, forward_time=0.123, loss_ctc=76.937, loss=76.937, backward_time=0.106, grad_norm=173.393, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.576e-04, optim0_lr1=3.576e-06, train_time=1.231
#     29epoch:train:101-110batch: iter_time=0.784, forward_time=0.128, loss_ctc=80.966, loss=80.966, backward_time=0.108, grad_norm=346.437, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.573e-04, optim0_lr1=3.573e-06, train_time=1.171
#     29epoch:train:111-120batch: iter_time=0.790, forward_time=0.131, loss_ctc=77.469, loss=77.469, backward_time=0.110, grad_norm=1.125e+03, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.570e-04, optim0_lr1=3.570e-06, train_time=1.185
#     29epoch:train:121-130batch: iter_time=0.904, forward_time=0.149, loss_ctc=79.334, loss=79.334, backward_time=0.125, grad_norm=187.072, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.567e-04, optim0_lr1=3.567e-06, train_time=1.348
#     29epoch:train:131-140batch: iter_time=0.871, forward_time=0.148, loss_ctc=79.173, loss=79.173, backward_time=0.123, grad_norm=241.502, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.564e-04, optim0_lr1=3.564e-06, train_time=1.312
#     29epoch:train:141-150batch: iter_time=0.846, forward_time=0.127, loss_ctc=72.696, loss=72.696, backward_time=0.107, grad_norm=247.547, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.562e-04, optim0_lr1=3.562e-06, train_time=1.229
#     29epoch:train:151-160batch: iter_time=0.828, forward_time=0.136, loss_ctc=80.309, loss=80.309, backward_time=0.114, grad_norm=406.633, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.559e-04, optim0_lr1=3.559e-06, train_time=1.235
#     29epoch:train:161-170batch: iter_time=0.976, forward_time=0.180, loss_ctc=84.738, loss=84.738, backward_time=0.150, grad_norm=231.972, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.556e-04, optim0_lr1=3.556e-06, train_time=1.503
#     29epoch:train:171-180batch: iter_time=0.874, forward_time=0.114, loss_ctc=82.160, loss=82.160, backward_time=0.099, grad_norm=247.549, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.553e-04, optim0_lr1=3.553e-06, train_time=1.222
#     29epoch:train:181-190batch: iter_time=0.920, forward_time=0.157, loss_ctc=81.495, loss=81.495, backward_time=0.130, grad_norm=309.028, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.550e-04, optim0_lr1=3.550e-06, train_time=1.385
#     29epoch:train:191-200batch: iter_time=0.882, forward_time=0.141, loss_ctc=77.775, loss=77.775, backward_time=0.118, grad_norm=134.028, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.548e-04, optim0_lr1=3.548e-06, train_time=1.303
#     29epoch:train:201-210batch: iter_time=0.847, forward_time=0.142, loss_ctc=77.382, loss=77.382, backward_time=0.120, grad_norm=201.204, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.545e-04, optim0_lr1=3.545e-06, train_time=1.269
#     29epoch:train:211-220batch: iter_time=0.902, forward_time=0.149, loss_ctc=80.010, loss=80.010, backward_time=0.125, grad_norm=214.276, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.542e-04, optim0_lr1=3.542e-06, train_time=1.344
#     29epoch results: [train] iter_time=0.848, forward_time=0.136, loss_ctc=78.418, loss=78.418, backward_time=0.114, grad_norm=290.385, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.572e-04, optim0_lr1=3.572e-06, train_time=1.254, time=4 minutes and 36.06 seconds, total_count=6380, gpu_max_cached_mem_GB=21.775, [valid] loss_ctc=82.073, cer_ctc=0.893, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=82.073, time=45.84 seconds, total_count=1276, gpu_max_cached_mem_GB=21.775
#     There are no improvements in this epoch
#     30/30epoch started. Estimated time to finish: 5 minutes and 27.36 seconds
#     30epoch:train:1-10batch: iter_time=0.878, forward_time=0.126, loss_ctc=74.597, loss=74.597, backward_time=0.107, grad_norm=243.342, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.539e-04optim0_lr1=3.539e-06, train_time=1.259
#     30epoch:train:11-20batch: iter_time=0.932, forward_time=0.149, loss_ctc=79.422, loss=79.422, backward_time=0.124, grad_norm=178.591, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.537e-04, optim0_lr1=3.537e-06, train_time=1.374
#     30epoch:train:21-30batch: iter_time=0.864, forward_time=0.131, loss_ctc=79.252, loss=79.252, backward_time=0.110, grad_norm=846.430, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.534e-04, optim0_lr1=3.534e-06, train_time=1.257
#     30epoch:train:31-40batch: iter_time=0.877, forward_time=0.128, loss_ctc=75.604, loss=75.604, backward_time=0.109, grad_norm=217.028, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.531e-04, optim0_lr1=3.531e-06, train_time=1.262
#     30epoch:train:41-50batch: iter_time=0.931, forward_time=0.135, loss_ctc=78.685, loss=78.685, backward_time=0.114, grad_norm=154.794, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.528e-04, optim0_lr1=3.528e-06, train_time=1.336
#     30epoch:train:51-60batch: iter_time=0.826, forward_time=0.133, loss_ctc=77.383, loss=77.383, backward_time=0.112, grad_norm=164.853, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.525e-04, optim0_lr1=3.525e-06, train_time=1.225
#     30epoch:train:61-70batch: iter_time=0.893, forward_time=0.152, loss_ctc=81.144, loss=81.144, backward_time=0.127, grad_norm=222.120, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.523e-04, optim0_lr1=3.523e-06, train_time=1.343
#     30epoch:train:71-80batch: iter_time=0.871, forward_time=0.124, loss_ctc=85.719, loss=85.719, backward_time=0.104, grad_norm=182.719, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.520e-04, optim0_lr1=3.520e-06, train_time=1.244
#     30epoch:train:81-90batch: iter_time=0.874, forward_time=0.124, loss_ctc=74.389, loss=74.389, backward_time=0.106, grad_norm=208.182, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.517e-04, optim0_lr1=3.517e-06, train_time=1.248
#     30epoch:train:91-100batch: iter_time=0.814, forward_time=0.111, loss_ctc=73.042, loss=73.042, backward_time=0.097, grad_norm=358.948, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.515e-04, optim0_lr1=3.515e-06, train_time=1.153
#     30epoch:train:101-110batch: iter_time=0.916, forward_time=0.140, loss_ctc=82.031, loss=82.031, backward_time=0.119, grad_norm=342.428, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.512e-04, optim0_lr1=3.512e-06, train_time=1.334
#     30epoch:train:111-120batch: iter_time=0.839, forward_time=0.118, loss_ctc=76.437, loss=76.437, backward_time=0.100, grad_norm=716.441, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.509e-04, optim0_lr1=3.509e-06, train_time=1.197
#     30epoch:train:121-130batch: iter_time=0.911, forward_time=0.150, loss_ctc=80.523, loss=80.523, backward_time=0.126, grad_norm=190.034, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.506e-04, optim0_lr1=3.506e-06, train_time=1.355
#     30epoch:train:131-140batch: iter_time=0.977, forward_time=0.160, loss_ctc=86.585, loss=86.585, backward_time=0.142, grad_norm=359.995, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.504e-04, optim0_lr1=3.504e-06, train_time=1.458
#     30epoch:train:141-150batch: iter_time=0.929, forward_time=0.128, loss_ctc=76.483, loss=76.483, backward_time=0.108, grad_norm=647.361, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.501e-04, optim0_lr1=3.501e-06, train_time=1.314
#     30epoch:train:151-160batch: iter_time=0.898, forward_time=0.144, loss_ctc=79.175, loss=79.175, backward_time=0.122, grad_norm=289.296, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.498e-04, optim0_lr1=3.498e-06, train_time=1.328
#     30epoch:train:161-170batch: iter_time=0.885, forward_time=0.144, loss_ctc=73.215, loss=73.215, backward_time=0.121, grad_norm=259.294, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.496e-04, optim0_lr1=3.496e-06, train_time=1.315
#     30epoch:train:171-180batch: iter_time=0.923, forward_time=0.162, loss_ctc=78.727, loss=78.727, backward_time=0.135, grad_norm=213.776, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.493e-04, optim0_lr1=3.493e-06, train_time=1.402
#     30epoch:train:181-190batch: iter_time=0.918, forward_time=0.145, loss_ctc=78.534, loss=78.534, backward_time=0.121, grad_norm=192.636, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.490e-04, optim0_lr1=3.490e-06, train_time=1.350
#     30epoch:train:191-200batch: iter_time=0.851, forward_time=0.118, loss_ctc=76.888, loss=76.888, backward_time=0.100, grad_norm=484.592, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.488e-04, optim0_lr1=3.488e-06, train_time=1.208
#     30epoch:train:201-210batch: iter_time=0.879, forward_time=0.129, loss_ctc=82.469, loss=82.469, backward_time=0.109, grad_norm=235.925, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.485e-04, optim0_lr1=3.485e-06, train_time=1.269
#     30epoch:train:211-220batch: iter_time=0.845, forward_time=0.136, loss_ctc=76.416, loss=76.416, backward_time=0.115, grad_norm=173.473, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.482e-04, optim0_lr1=3.482e-06, train_time=1.252
#     30epoch results: [train] iter_time=0.888, forward_time=0.136, loss_ctc=78.485, loss=78.485, backward_time=0.115, grad_norm=312.830, clip=100.000, loss_scale=5.243e+05, optim_step_time=0.009, optim0_lr0=3.511e-04, optim0_lr1=3.511e-06, train_time=1.295, time=4 minutes and 44.92 seconds, total_count=6600, gpu_max_cached_mem_GB=21.775, [valid] loss_ctc=82.151, cer_ctc=0.874, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=82.151, time=46.19 seconds, total_count=1320, gpu_max_cached_mem_GB=21.775
#     There are no improvements in this epoch
#     The training was finished at 30 epochs
# INFO:root:Vocabulary size: 50002
# INFO:root:Gradient checkpoint layers: []
# INFO:root:Gradient checkpoint layers: []
# WARNING:root:Set decoder to none as ctc_weight==1.0
#   evaluando con CTC greedy...
# /usr/local/lib/python3.12/dist-packages/espnet2/s2t/espnet_model.py:338: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(False):
#     [ctc] REF: you can see the code at this point as well
#     [ctc] HYP: i a o o o o o o oe
#     [ctc] REF: and it also helps when they were winning
#     [ctc] HYP: i  a ae  o o o
#     [ctc] REF: i have a gold one
#     [ctc] HYP: i a o o oe
#     por trial: mediana=0.750 p10=0.679 p90=0.812 · 0% por debajo de 0.2
#   [CTC greedy] cer_ctc(micro, comparable con el log)=0.748 · CER texto=0.746 · WER texto=1.108
#   (objetivo char: la cabeza CTC y el decoder usan vocabularios distintos, el beam search hibrido no aplica)
#   hecho en 163.8 min (~4.67 compute units)
#
# ==============================================================================
# BARRIDO COMPLETO en 345 min (~9.8 compute units)
# Resultados en: /content/drive/MyDrive/TFG/resultados/resultados.csv

# %% [markdown]
# ## 13. Resultados y curvas
#
# Tabla comparativa para la memoria y curvas de entrenamiento de cada experimento.

# %%
import matplotlib.pyplot as plt

df = pd.read_csv(CSV_RESULTADOS)
cols = ["nombre", "frontend", "capa_sesion", "norm", "unfreeze_encoder", "lr", "enc_lr_scale",
        "ctc_weight", "n_train", "best_epoch", "best_valid_loss", "best_valid_acc",
        "best_valid_cer_ctc", "cer_ctc_greedy", "wer_ctc_greedy", "cer_beam", "wer_beam",
        "minutos", "compute_units"]
cols = [c for c in cols if c in df.columns]
resumen = df[cols].sort_values("best_valid_loss" if "best_valid_loss" in df else "nombre")
display(resumen)

resumen.to_csv(f"{RESULTS_DIR}/tabla_resumen.csv", index=False)
print("Tabla guardada en", f"{RESULTS_DIR}/tabla_resumen.csv")
print("\nLaTeX para la memoria:\n")
print(resumen.to_latex(index=False, float_format="%.3f"))
# Out:
#          nombre frontend capa_sesion   norm  unfreeze_encoder     lr  \
# 8       overfit   linear       False  trial              True  0.001
# 12  charOverfit   linear       False  trial              True  0.001
# 14  charOverfit   linear       False  trial              True  0.001
# 0        sanity   linear         NaN    NaN              True  0.001
# 3        linear   linear         NaN    NaN              True  0.001
# 9     sinSesion   linear       False  trial              True  0.001
# 10    conSesion   linear        True  trial              True  0.001
# 4        conv1d   conv1d         NaN    NaN              True  0.001
# 11         gen1   linear       False  trial              True  0.001
# 19        lrdif   linear        True  trial              True  0.001
# 18          c1d   conv1d        True  trial              True  0.001
# 16      fullCon   linear        True  trial              True  0.001
# 17     fullCon2   linear        True  trial              True  0.001
# 15     charGen1   linear       False  trial              True  0.001
# 1          base   conv2d         NaN    NaN              True  0.001
# 2         lrdif   conv2d         NaN    NaN              True  0.001
# 5        frozen   conv2d         NaN    NaN             False  0.001
# 6         ctc00   conv2d         NaN    NaN              True  0.001
# 7         ctc05   conv2d         NaN    NaN              True  0.001
# 13     charGen1   linear       False  trial              True  0.001
#
#     enc_lr_scale  ctc_weight  n_train  best_epoch  best_valid_loss  \
# 8           1.00         1.0      348       199.0            1.724
# 12          1.00         1.0      348        75.0            3.679
# 14          1.00         1.0      348        50.0           13.976
# 0           1.00         0.3      545        14.0           28.731
# 3           1.00         0.3     2296         5.0           36.759
# 9           0.01         0.3     2296         4.0           36.913
# 10          0.01         0.3     2296         5.0           37.102
# 4           1.00         0.3     2296         1.0           37.523
# 11          1.00         1.0      348         1.0           48.928
# 19          0.01         1.0     7051        28.0           81.805
# 18          0.01         1.0     7051        11.0           83.916
# 16          1.00         1.0     7051        23.0           84.117
# 17          1.00         1.0     7051        62.0           84.351
# 15          1.00         1.0      348        19.0           87.430
# 1           1.00         0.3     2296         NaN              NaN
# 2           0.01         0.3     2296         NaN              NaN
# 5           1.00         0.3     2296         NaN              NaN
# 6           1.00         0.0     2296         NaN              NaN
# 7           1.00         0.5     2296         NaN              NaN
# 13          1.00         1.0      348         NaN              NaN
#
#     best_valid_acc  best_valid_cer_ctc  cer_ctc_greedy  wer_ctc_greedy  \
# 8              NaN               0.117        0.581225        0.684772
# 12             NaN               0.052        0.450994        0.779190
# 14             NaN               0.231        0.537149        0.886817
# 0            0.605               0.868             NaN             NaN
# 3            0.564               0.924             NaN             NaN
# 9            0.559               0.952        0.986814        0.987778
# 10           0.553               0.989        0.995862        0.997778
# 4            0.558               1.000             NaN             NaN
# 11             NaN               1.000        0.795170        0.969841
# 19             NaN               0.870        0.745797        1.108095
# 18             NaN               0.826        0.714165        1.204857
# 16             NaN               0.875        0.721311        1.193896
# 17             NaN               0.882        0.837675        1.000000
# 15             NaN               0.939        0.734234        0.972857
# 1              NaN                 NaN             NaN             NaN
# 2              NaN                 NaN             NaN             NaN
# 5              NaN                 NaN             NaN             NaN
# 6              NaN                 NaN             NaN             NaN
# 7              NaN                 NaN             NaN             NaN
# 13             NaN                 NaN             NaN             NaN
#
#     cer_beam  wer_beam  minutos  compute_units
# 8        NaN       NaN     82.5           2.35
# 12       NaN       NaN     25.7           0.73
# 14       NaN       NaN     17.3           0.49
# 0   0.749266  1.056681     17.3           0.34
# 3   0.795415  1.069532    101.7           2.02
# 9   0.862936  1.397937     59.2           1.69
# 10  0.796121  1.128944     59.4           1.69
# 4   0.842685  1.235167    104.0           2.06
# 11       NaN       NaN     51.0           1.45
# 19       NaN       NaN    163.8           4.67
# 18       NaN       NaN    168.9           4.81
# 16       NaN       NaN    133.1           3.79
# 17       NaN       NaN    521.0          14.85
# 15       NaN       NaN     34.8           0.99
# 1        NaN       NaN      0.1           0.00
# 2        NaN       NaN      0.1           0.00
# 5        NaN       NaN      0.1           0.00
# 6        NaN       NaN      0.0           0.00
# 7        NaN       NaN      0.1           0.00
# 13       NaN       NaN      0.1           0.00
# Tabla guardada en /content/drive/MyDrive/TFG/resultados/tabla_resumen.csv
#
# LaTeX para la memoria:
#
# \begin{tabular}{llllrrrrrrrrrrrrrrr}
# \toprule
# nombre & frontend & capa_sesion & norm & unfreeze_encoder & lr & enc_lr_scale & ctc_weight & n_train & best_epoch & best_valid_loss & best_valid_acc & best_valid_cer_ctc & cer_ctc_greedy & wer_ctc_greedy & cer_beam & wer_beam & minutos & compute_units \\
# \midrule
# overfit & linear & False & trial & True & 0.001 & 1.000 & 1.000 & 348 & 199.000 & 1.724 & NaN & 0.117 & 0.581 & 0.685 & NaN & NaN & 82.500 & 2.350 \\
# charOverfit & linear & False & trial & True & 0.001 & 1.000 & 1.000 & 348 & 75.000 & 3.679 & NaN & 0.052 & 0.451 & 0.779 & NaN & NaN & 25.700 & 0.730 \\
# charOverfit & linear & False & trial & True & 0.001 & 1.000 & 1.000 & 348 & 50.000 & 13.976 & NaN & 0.231 & 0.537 & 0.887 & NaN & NaN & 17.300 & 0.490 \\
# sanity & linear & NaN & NaN & True & 0.001 & 1.000 & 0.300 & 545 & 14.000 & 28.731 & 0.605 & 0.868 & NaN & NaN & 0.749 & 1.057 & 17.300 & 0.340 \\
# linear & linear & NaN & NaN & True & 0.001 & 1.000 & 0.300 & 2296 & 5.000 & 36.759 & 0.564 & 0.924 & NaN & NaN & 0.795 & 1.070 & 101.700 & 2.020 \\
# sinSesion & linear & False & trial & True & 0.001 & 0.010 & 0.300 & 2296 & 4.000 & 36.913 & 0.559 & 0.952 & 0.987 & 0.988 & 0.863 & 1.398 & 59.200 & 1.690 \\
# conSesion & linear & True & trial & True & 0.001 & 0.010 & 0.300 & 2296 & 5.000 & 37.102 & 0.553 & 0.989 & 0.996 & 0.998 & 0.796 & 1.129 & 59.400 & 1.690 \\
# conv1d & conv1d & NaN & NaN & True & 0.001 & 1.000 & 0.300 & 2296 & 1.000 & 37.523 & 0.558 & 1.000 & NaN & NaN & 0.843 & 1.235 & 104.000 & 2.060 \\
# gen1 & linear & False & trial & True & 0.001 & 1.000 & 1.000 & 348 & 1.000 & 48.928 & NaN & 1.000 & 0.795 & 0.970 & NaN & NaN & 51.000 & 1.450 \\
# lrdif & linear & True & trial & True & 0.001 & 0.010 & 1.000 & 7051 & 28.000 & 81.805 & NaN & 0.870 & 0.746 & 1.108 & NaN & NaN & 163.800 & 4.670 \\
# c1d & conv1d & True & trial & True & 0.001 & 0.010 & 1.000 & 7051 & 11.000 & 83.916 & NaN & 0.826 & 0.714 & 1.205 & NaN & NaN & 168.900 & 4.810 \\
# fullCon & linear & True & trial & True & 0.001 & 1.000 & 1.000 & 7051 & 23.000 & 84.117 & NaN & 0.875 & 0.721 & 1.194 & NaN & NaN & 133.100 & 3.790 \\
# fullCon2 & linear & True & trial & True & 0.001 & 1.000 & 1.000 & 7051 & 62.000 & 84.351 & NaN & 0.882 & 0.838 & 1.000 & NaN & NaN & 521.000 & 14.850 \\
# charGen1 & linear & False & trial & True & 0.001 & 1.000 & 1.000 & 348 & 19.000 & 87.430 & NaN & 0.939 & 0.734 & 0.973 & NaN & NaN & 34.800 & 0.990 \\
# base & conv2d & NaN & NaN & True & 0.001 & 1.000 & 0.300 & 2296 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & 0.100 & 0.000 \\
# lrdif & conv2d & NaN & NaN & True & 0.001 & 0.010 & 0.300 & 2296 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & 0.100 & 0.000 \\
# frozen & conv2d & NaN & NaN & False & 0.001 & 1.000 & 0.300 & 2296 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & 0.100 & 0.000 \\
# ctc00 & conv2d & NaN & NaN & True & 0.001 & 1.000 & 0.000 & 2296 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & 0.000 & 0.000 \\
# ctc05 & conv2d & NaN & NaN & True & 0.001 & 1.000 & 0.500 & 2296 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & 0.100 & 0.000 \\
# charGen1 & linear & False & trial & True & 0.001 & 1.000 & 1.000 & 348 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & 0.100 & 0.000 \\
# \bottomrule
# \end{tabular}

# %%
# Curvas de todos los experimentos con epocas.csv
fig, axes = plt.subplots(1, 3, figsize=(16, 4.2))
for tag in df["exp_tag"]:
    p = f"{RESULTS_DIR}/{tag}/epocas.csv"
    if not os.path.exists(p):
        continue
    e = pd.read_csv(p)
    etiqueta = tag.split("_")[0]
    if "train_loss" in e: axes[0].plot(e["epoch"], e["train_loss"], label=etiqueta)
    if "valid_loss" in e: axes[1].plot(e["epoch"], e["valid_loss"], label=etiqueta)
    if "valid_cer"  in e: axes[2].plot(e["epoch"], e["valid_cer"],  label=etiqueta)

for ax, t in zip(axes, ["Loss (train)", "Loss (valid)", "CER (valid)"]):
    ax.set_title(t); ax.set_xlabel("epoca"); ax.grid(alpha=0.3)
axes[0].legend(fontsize=8)
plt.tight_layout()
plt.savefig(f"{RESULTS_DIR}/curvas.png", dpi=150, bbox_inches="tight")
plt.show()
print("Figura guardada en", f"{RESULTS_DIR}/curvas.png")
# Out:
# Figura guardada en /content/drive/MyDrive/TFG/resultados/curvas.png

# %% [markdown]
# ---
#
# ## Cómo leer `gen1`
#
# Es el mismo experimento que el `overfit` (que llegó a `cer_ctc` = 0.117) con **una sola** variable cambiada: la validación es ahora un split real en vez de `val = train`.
#
# | `min_valid_cer_ctc` | Lectura | Siguiente paso |
# |---|---|---|
# | < 0.5 | Generaliza dentro de un día. El cuello de botella es multi-sesión. | Rama A: la ablación de la capa por sesión, ya sobre algo que aprende. |
# | 0.7 – 0.9 | Generaliza un poco. Falta señal o faltan datos. | Rama B: las 45 sesiones. |
# | ≈ 0.9 y `pendiente_cer_ctc` ≈ 0 | No generaliza ni con un día, sin deriva ni confusión entre sesiones. | Rama B + cambiar la cabeza CTC (ver abajo). |
#
# Mira siempre `pendiente_cer_ctc` (ajuste lineal sobre las últimas 10 épocas). En `sinSesion` valía −0.0008/época — plano. En el `overfit` a la misma altura valía −0.014/época — despegando. Es lo que distingue "va lento" de "está atascado".
#
# ## El problema de las 50.002 clases
#
# Si `gen1` sale plano, este es el cambio estructural que toca. Los pipelines de referencia de B2T'25 no predicen BPE: su capa final tiene **41 clases** (39 fonemas + blank + espacio), y las palabras salen después con un n-grama o un LLM. Tú le estás pidiendo a la cabeza CTC que aprenda un mapeo neuronal → 50.002 tokens con 2.296 frases.
#
# Dos versiones, de menos a más trabajo:
#
# 1. **Caracteres (~30 clases).** No hace falta ninguna dependencia nueva: tokenizas `text_ctc` letra a letra y sustituyes `model.ctc.ctc_lo` por un `nn.Linear(384, 30)`. Captura casi toda la reducción de clases.
# 2. **Fonemas (41 clases).** Lo que hace la literatura, con `g2p_en`. Comparable con los números publicados del benchmark, que es lo que quieres para la memoria.
#
# En los dos casos `cer_ctc` deja de ser comparable con las tablas anteriores (pasa a ser CER de caracteres o PER), así que conviene documentarlo como una fase aparte.
#
# ## Ajustes de rendimiento
#
# - Si la GPU va a menos del 70 % (mira `!nvidia-smi` desde el Terminal), sube `batch_size` o pasa a `batch_type="numel"` con `batch_bins` (agrupa por número de elementos, mucho mejor con longitudes de 138 a 1966 frames).
# - `num_workers=0` es lo seguro con HDF5. Súbelo solo si ves la GPU esperando.
# - El reintento automático por OOM baja el batch a la mitad y luego a un cuarto antes de rendirse, así que un experimento mal dimensionado ya no tumba el barrido entero.
