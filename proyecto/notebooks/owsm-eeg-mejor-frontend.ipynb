# %% [markdown]
# # OWSM + sEEG (B2T'25) — versión Google Colab con barrido de experimentos
#
# Adaptación del notebook local para Colab. Cambios principales respecto a la versión local:
#
# ## Novedades de esta versión (v5)
#
# Tres cambios, cada uno respondiendo a algo que los resultados anteriores dejaron claro.
#
# **1. Frontend `deep`.** El `linear` que se usó en casi todos los experimentos tenía 197 K parámetros y, peor, **descartaba 3 de cada 4 frames** por decimación (`x[:, ::4, :]`). El frontend original de OWSM tiene ~20 M. El nuevo `deep` es:
#
# ```
# capa por sesión → Linear(512→d) + LayerNorm + GELU     ← mezcla espacial de electrodos
#                 → [Conv1d stride 2 → n bloques residuales] × 2   ← temporal, sin descartar frames
#                 → Linear(d→384) + codificación posicional
# ```
#
# Con `deep_dim=512, deep_bloques=2` son **8,3 M** de parámetros (más 11,8 M de la capa por sesión con 45 sesiones). La mezcla de electrodos es todos-con-todos, no convolucional: el orden de los electrodos es arbitrario, así que convolucionar sobre ese eje (lo que hace `conv2d`, heredado de tratarlo como eje de frecuencias) no tiene sentido físico aquí.
#
# **2. InterCTC.** Pérdidas CTC auxiliares en las capas 2 y 4 del encoder, compartiendo la misma cabeza. Es la receta estándar de ESPnet contra el subajuste en encoders profundos: da señal de gradiente directa a las capas de abajo en vez de que tenga que propagarse desde el final. Se activa con `interctc_weight=0.3`.
#
# **3. Las 45 sesiones.** `SOLO_SESIONES_COMPLETAS` pasa a `False`. Antes se usaban 41 porque 4 sesiones no tienen `data_val.hdf5` y el filtro las descartaba enteras; ahora aportan datos de entrenamiento y simplemente no entran en validación. (De paso, el nombre de `stats_dir` ahora lleva el número real de sesiones, porque con el filtro activado o no `n_sessions=45` producía dos conjuntos de datos distintos con la misma carpeta de estadísticas.)
#
# ## Cómo usarlo
#
# 1. **Entorno de ejecución → Cambiar tipo de entorno de ejecución → GPU L4**. Marca *High RAM* solo si vas a usar `n_sessions >= 30` con `PRELOAD_RAM = True`.
# 2. Comprueba que `DRIVE_DATA` (celda 1) apunta a tu carpeta `hdf5_data_final` en Drive.
# 3. Ejecuta las celdas 0 a 10 en orden. Reinicia el entorno cuando te lo pida la celda de instalación.
# 4. Edita la lista `BARRIDO` (celda 11) y lanza la celda 12.
#
# Los resultados se van acumulando en `resultados.csv` en tu Drive: si Colab te desconecta, vuelves a lanzar y se salta los experimentos ya hechos.

# %% [markdown]
# ## 0. Instalación
#
# Ejecuta esta celda, **reinicia el entorno** (`Entorno de ejecución → Reiniciar sesión`) y continúa desde la celda 1. Si no reinicias, numpy se queda cargado en la versión antigua y aparecen errores de tipos difíciles de diagnosticar.

# %%
# !nvidia-smi

# Instalación (~3 min la primera vez).
# Truco para sesiones siguientes: descarga las ruedas a Drive una sola vez con
#   !pip download -q espnet espnet_model_zoo loralib h5py -d /content/drive/MyDrive/TFG/wheels
# y luego instala offline en ~20 s con
#   !pip install -q --no-index --find-links=/content/drive/MyDrive/TFG/wheels espnet espnet_model_zoo loralib h5py
# !pip install -q espnet espnet_model_zoo loralib h5py

import torch
print("PyTorch:", torch.__version__, "| CUDA disponible:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("SIN GPU: revisa Entorno de ejecucion > Cambiar tipo de entorno de ejecucion")
print("\n>>> REINICIA EL ENTORNO AHORA y sigue desde la celda 1 <<<")
# Out:
# Sat Aug  1 10:18:56 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   48C    P8             17W /   72W |       3MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# PyTorch: 2.11.0+cu128 | CUDA disponible: True
# GPU: NVIDIA L4
#
# >>> REINICIA EL ENTORNO AHORA y sigue desde la celda 1 <<<

# %% [markdown]
# ## 1. Panel de control
#
# Todo lo configurable vive aquí. `DEFAULTS` son los valores base de un experimento; en el barrido (celda 11) solo indicas lo que cambia respecto a estos.

# %%
# ══ RUTAS ══════════════════════════════════════════════════════════
DRIVE_ROOT  = "/content/drive/MyDrive/TFG"                       # <<< tu carpeta en Drive
DRIVE_DATA  = f"{DRIVE_ROOT}/DatosEEG_crudos/hdf5_data_final"    # <<< donde estan los HDF5
DATA_ROOT   = "/content/data/hdf5_data_final"    # cache en el disco local de la VM
OUTPUT_DIR  = "/content/exp"                     # checkpoints en local, NO en Drive
RESULTS_DIR = f"{DRIVE_ROOT}/resultados"         # solo lo que quieres conservar

# ══ MODELO ═════════════════════════════════════════════════════════
FINETUNE_MODEL = "espnet/owsm_v3.1_ebf_base"       # ~101M params
LANGUAGE       = "eng"
LORA_TARGET    = ["w_1", "w_2", "merge_proj", "linear_q", "linear_k", "linear_v", "linear_out"]

# ══ DATOS ══════════════════════════════════════════════════════════
PRELOAD_RAM   = False   # False = lectura perezosa del HDF5 (seguro con 45 sesiones)
                        # True  = todo en RAM (~1.6 MB/trial; necesita High RAM si n_sessions>25)
SOLO_SESIONES_COMPLETAS = False  # False = usar las 45 sesiones. Las 4 que no tienen
                                 # data_val.hdf5 aportan datos de entrenamiento y no
                                 # entran en validacion. True = solo las 41 completas.

# ══ EVALUACION ═════════════════════════════════════════════════════
EVAL_N    = 200   # trials de validacion sobre los que calcular CER/WER al final de cada run
BEAM_SIZE = 5
EVAL_GREEDY_CTC = True   # ademas del beam search, decodificacion CTC greedy (metrica honesta:
                         # no pasa por el decoder, asi que no puede "hacer trampa" con el
                         # prior del ingles preentrenado)

# ══ CONTROL DEL BARRIDO ════════════════════════════════════════════
SKIP_IF_DONE = True    # no repetir experimentos ya presentes en resultados.csv
GUARDAR_CKPT = False   # copiar el mejor .pth a Drive (~470 MB por experimento)

# ══ VALORES POR DEFECTO DE UN EXPERIMENTO ══════════════════════════
DEFAULTS = dict(
    nombre        = "base",     # etiqueta legible para las tablas de la memoria
    n_sessions    = 10,         # 45 disponibles
    max_epoch     = 30,
    warmup        = 100,
    val_igual_train = False,    # True = test de sobreajuste (val == train)

    frontend      = "conv2d",   # "conv2d" | "linear" | "conv1d" | "deep"
    deep_dim      = 512,        # (frontend deep) anchura interna
    deep_bloques  = 2,          # (deep) bloques residuales por etapa de submuestreo
    deep_kernel   = 5,          # (deep) tamano del kernel temporal
    deep_dropout  = 0.1,        # (deep) dropout
    subsample     = 4,          # (deep) submuestreo total: 1, 2, 4 u 8.
                                #        Con bins de 20 ms: 4 -> frames de 80 ms,
                                #        2 -> 40 ms (mas resolucion, 2x de coste)
    aug           = False,      # aumento de datos sobre la senal sEEG (solo en train)
    aug_n_tiempo  = 2,          # cuantas bandas temporales se ponen a cero
    aug_max_tiempo = 0.05,      # anchura maxima de cada banda, como fraccion de T
    aug_n_canales = 2,          # cuantas bandas de electrodos se ponen a cero
    aug_max_canales = 40,       # anchura maxima de cada banda, en canales
    aug_ruido     = 0.0,        # desviacion del ruido gaussiano anadido (0 = nada)
    interctc_weight = 0.0,      # >0 anade perdidas CTC en capas intermedias del
                                # encoder. 0.3 es el valor habitual en ESPnet.
    interctc_layers = (2, 4),   # el encoder tiene 6 bloques: validos 1..5
    objetivo_ctc  = "bpe",      # "bpe"  = tokens BPE de OWSM (50.002 clases; el original)
                                # "char" = caracteres (~32 clases). Cambia SOLO el objetivo
                                #          del CTC; el decoder de atencion sigue en BPE.
    capa_sesion   = False,      # True = transformada afin por sesion + softsign delante del
                                # frontend (es LA caracteristica del baseline de B2T'25: la
                                # senal del mismo fonema cambia de un dia a otro por deriva
                                # de los electrodos, y 45 sesiones abarcan 20 meses)
    norm          = "trial",    # "trial"  = z-score por trial y canal (lo que hacias)
                                # "ninguna"= usar los HDF5 tal cual (ya vienen z-scoreados
                                #            por bloque; los trabajos publicados no renormalizan)
    unfreeze_encoder = True,
    unfreeze_n_layers = None,   # None = encoder entero; int = solo las N primeras capas
    usar_lora     = True,

    batch_type    = "sorted",   # "sorted" (batch_size) | "numel" (batch_bins)
    batch_size    = 16,
    batch_bins    = 6_000_000,
    accum_grad    = 1,

    lr            = 1e-3,
    enc_lr_scale  = 1.0,        # <1.0 = LR menor para el encoder preentrenado (p.ej. 0.01)
    optim         = "adamw",    # "adam" | "adamw". Con weight_decay > 0 hay que usar adamw:
                                # en adam el decay se suma al gradiente y lo reescala el
                                # denominador adaptativo, asi que casi no regulariza.
    weight_decay  = 1e-2,       # 1e-6 (el valor anterior) es basicamente cero. Con adamw,
                                # 1e-2 es el valor estandar y regulariza de forma suave,
                                # sin destrozar la senal como hace el dropout alto.
    grad_clip     = 25.0,       # OJO: con grad_clip=5 y grad_norm~200, el log mostraba
                                # clip=100.000, o sea que el 100% de los pasos se recortaba
                                # y se tiraba 40x de magnitud del gradiente en cada uno.
    ctc_weight    = 0.3,        # ahora SI afecta al loss de entrenamiento
    ctc_weight_decode = None,   # None = mismo que ctc_weight
    seed          = 2024,
    criterio      = "cer_ctc",  # metrica con la que se elige el mejor checkpoint.
                                # "cer_ctc" = la del sEEG. "loss" = la total, que con
                                # ctc_weight bajo es sobre todo perdida de atencion y
                                # toca fondo en 4-5 epocas por el prior del ingles.
    num_workers   = 0,          # 0 = sin fork. Con HDF5 es lo mas seguro y no cuesta
                                # nada: el modelo es compute-bound y los datos estan en
                                # disco local. Sube a 2 solo si ves la GPU esperando.
)

print("Panel cargado.")
# Out:
# Panel cargado.

# %% [markdown]
# ## 2. Drive y datos
#
# Tus HDF5 ya están en Drive, así que solo hay que montarlo. Lo que **no** conviene es entrenar leyendo directamente de `/content/drive`: Drive limita las operaciones de E/S por fichero y acaba dando `OSError: [Errno 5] Input/output error` a mitad de una época.
#
# La solución es una caché: las sesiones se copian de Drive al disco local de la VM **solo cuando un experimento las necesita**. Si el barrido empieza con 2 sesiones, se copian 2 (unos segundos) y no las 45.
#
# Esta celda solo monta Drive y comprueba qué hay. La copia ocurre sola más adelante.

# %%
import os, time, shutil, glob

from google.colab import drive
drive.mount("/content/drive")

os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(DATA_ROOT, exist_ok=True)

# Localizar la carpeta de datos aunque este en otro sitio dentro de DRIVE_ROOT
if not os.path.isdir(DRIVE_DATA):
    print(f"No esta en {DRIVE_DATA}; buscando 'hdf5_data_final' bajo {DRIVE_ROOT} ...")
    cands = glob.glob(f"{DRIVE_ROOT}/**/hdf5_data_final", recursive=True)
    if cands:
        DRIVE_DATA = cands[0]
        print("Encontrada:", DRIVE_DATA)
    else:
        raise FileNotFoundError(
            f"No encuentro la carpeta hdf5_data_final dentro de {DRIVE_ROOT}.\n"
            f"Ajusta DRIVE_ROOT / DRIVE_DATA en el panel de control."
        )

# Inventario: que sesiones hay y cuales tienen train Y val
inventario, sin_val, bytes_tot = [], [], 0
for s in sorted(os.listdir(DRIVE_DATA)):
    d = os.path.join(DRIVE_DATA, s)
    if not os.path.isdir(d):
        continue
    tr = os.path.join(d, "data_train.hdf5")
    va = os.path.join(d, "data_val.hdf5")
    if not os.path.exists(tr):
        continue
    inventario.append(s)
    if not os.path.exists(va):
        sin_val.append(s)
    bytes_tot += os.path.getsize(tr) + (os.path.getsize(va) if os.path.exists(va) else 0)

print(f"\n{len(inventario)} sesiones con data_train.hdf5 · {bytes_tot/1e9:.1f} GB (train+val)")
if sin_val:
    print(f"{len(sin_val)} sin data_val.hdf5: {sin_val}")
    print("  -> con SOLO_SESIONES_COMPLETAS=True se ignoran (evita que train y val no cuadren)")
print("\nPrimeras sesiones:", inventario[:5])
print("Disco libre en la VM:")
os.system("df -h /content | tail -1")
# Out:
# Mounted at /content/drive
#
# 45 sesiones con data_train.hdf5 · 11.2 GB (train+val)
# 4 sin data_val.hdf5: ['t15.2023.08.11', 't15.2024.03.03', 't15.2024.04.25', 't15.2024.04.28']
#   -> con SOLO_SESIONES_COMPLETAS=True se ignoran (evita que train y val no cuadren)
#
# Primeras sesiones: ['t15.2023.08.11', 't15.2023.08.13', 't15.2023.08.18', 't15.2023.08.20', 't15.2023.08.25']
# Disco libre en la VM:
# 0

# %% [markdown]
# ## 3. Imports, dispositivo y utilidades

# %%
import string, re, glob, argparse, logging, gc, copy, json, math
import h5py
import numpy as np
import pandas as pd
import torch
import loralib

import espnetez as ez
from espnet2.bin.s2t_inference import Speech2Text
from espnet2.layers.create_adapter_fn import create_lora_adapter
from espnet.nets.pytorch_backend.transformer.subsampling import Conv2dSubsampling

os.environ["HF_HUB_DOWNLOAD_TIMEOUT"] = "120"

DEVICE  = "cuda" if torch.cuda.is_available() else "cpu"
NGPU    = 1 if torch.cuda.is_available() else 0
USE_AMP = torch.cuda.is_available()

GPU_NAME = torch.cuda.get_device_name(0) if NGPU else "CPU"

# Tarifas aproximadas de compute units/hora (medidas en marzo de 2026; pueden variar)
TARIFAS = {"T4": 1.19, "L4": 1.71, "A100-SXM4-40GB": 5.40, "A100-SXM4-80GB": 7.52,
           "RTX PRO 6000": 8.71, "H100": 9.0}
def units_por_hora(nombre_gpu):
    for k, v in TARIFAS.items():
        if k.lower().replace("-", " ") in nombre_gpu.lower().replace("-", " "):
            return v
    return float("nan")
CU_H = units_por_hora(GPU_NAME)

print(f"Dispositivo: {DEVICE} · {GPU_NAME} · AMP: {USE_AMP}")
print(f"Coste estimado: {CU_H} compute units/hora (~${CU_H*0.10:.2f}/h)")


def normaliza(x, modo="trial"):
    """Normalizacion de la senal sEEG antes de entrar al modelo.

    Los HDF5 de B2T'25 ya vienen binneados a 20 ms y z-scoreados por bloque, asi que
    "ninguna" reproduce lo que hacen los trabajos publicados; "trial" vuelve a normalizar
    por trial y canal (util para comparar, pero borra la amplitud relativa entre trials).
    """
    x = x.astype(np.float32)
    if modo == "ninguna":
        return x
    return (x - x.mean(axis=0, keepdims=True)) / (x.std(axis=0, keepdims=True) + 1e-8)

def remove_punctuation(text):
    return text.translate(str.maketrans("", "", string.punctuation))

def decode_transcription(arr):
    arr = np.asarray(arr).ravel()
    return "".join(chr(int(x)) for x in arr if int(x) != 0)
# Out:
# Failed to import Flash Attention, using ESPnet default: No module named 'flash_attn'
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# /usr/local/lib/python3.12/dist-packages/espnet2/enh/encoder/stft_encoder.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /usr/local/lib/python3.12/dist-packages/espnet2/enh/layers/uses2_swin.py:329: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# Dispositivo: cuda · NVIDIA L4 · AMP: True
# Coste estimado: 1.71 compute units/hora (~$0.17/h)

# %% [markdown]
# ## 4. Datasets (carga perezosa)
#
# `SeeGDataset` guarda solo un **índice** `(fichero, clave)` y lee cada trial del HDF5 cuando hace falta. Así las 45 sesiones (~17 GB en float32) no tienen que caber en RAM. El handle de h5py se reabre por proceso para que funcione con `num_workers > 0`.
#
# Con `PRELOAD_RAM = True` vuelve al comportamiento local (todo en memoria), que es algo más rápido si tienes RAM de sobra.

# %%
class SeeGDataset(torch.utils.data.Dataset):
    """Lee trials del HDF5 bajo demanda. Si preload=True los cachea todos en RAM."""

    def __init__(self, index, preload=False):
        self.index = index          # [(ruta_hdf5, clave), ...]
        self.preload = preload
        self._files = {}
        self._pid = os.getpid()
        self._cache = None
        if preload:
            self._cache = [self._leer(i) for i in range(len(index))]
            self.cerrar()

    def _handle(self, path):
        if os.getpid() != self._pid:      # tras un fork, los handles del padre no valen
            self._files, self._pid = {}, os.getpid()
        if path not in self._files:
            self._files[path] = h5py.File(path, "r")
        return self._files[path]

    def cerrar(self):
        """Cierra los handles. IMPRESCINDIBLE antes de que el DataLoader haga fork:
        la libreria HDF5 no es fork-safe y heredar handles abiertos puede colgar el proceso."""
        for f in self._files.values():
            try: f.close()
            except Exception: pass
        self._files = {}

    def _leer(self, idx):
        path, key, sid = self.index[idx]
        t = self._handle(path)[key]
        return {"input_features": t["input_features"][:],
                "text_raw": decode_transcription(t["transcription"][()]),
                "session_idx": sid}

    def __len__(self):
        return len(self.index)

    def __getitem__(self, idx):
        d = self._cache[idx] if self._cache is not None else self._leer(idx)
        text_lower = d["text_raw"].lower()
        return {
            "input_features": d["input_features"],
            "session_idx": d["session_idx"],
            "text":      f"<{LANGUAGE}><asr><notimestamps> {text_lower}",
            "text_prev": "<na>",
            "text_ctc":  remove_punctuation(text_lower),
            "text_raw":  d["text_raw"],
        }


def construir_indice(sesiones, split):
    """Recorre las claves de cada HDF5 sin leer los datos.

    Cada entrada es (ruta, clave, indice_de_sesion). El indice es la posicion en la
    lista `sesiones`, la misma para train y val, y es lo que consume la capa por sesion.
    """
    index = []
    for sid, s in enumerate(sesiones):
        path = os.path.join(DATA_ROOT, s, f"data_{split}.hdf5")
        if not os.path.exists(path):
            print(f"  [aviso] no encontrado: {path}")
            continue
        with h5py.File(path, "r") as f:
            index.extend((path, k, sid) for k in sorted(f.keys()))
    return index


def sesiones_disponibles():
    """Sesiones utilizables, listadas desde Drive (la fuente de la verdad).

    Con SOLO_SESIONES_COMPLETAS=False se incluyen tambien las sesiones que solo
    tienen data_train.hdf5: aportan datos de entrenamiento y simplemente no
    contribuyen a la validacion.
    """
    out = []
    for s in sorted(os.listdir(DRIVE_DATA)):
        d = os.path.join(DRIVE_DATA, s)
        if not os.path.isdir(d) or not os.path.exists(os.path.join(d, "data_train.hdf5")):
            continue
        if SOLO_SESIONES_COMPLETAS and not os.path.exists(os.path.join(d, "data_val.hdf5")):
            continue
        out.append(s)
    return out


def copiar_sesion(sesion):
    """Trae data_train/data_val de esa sesion al disco local de la VM (solo la primera vez)."""
    src = os.path.join(DRIVE_DATA, sesion)
    dst = os.path.join(DATA_ROOT, sesion)
    os.makedirs(dst, exist_ok=True)
    for split in ("train", "val"):
        f_src = os.path.join(src, f"data_{split}.hdf5")
        f_dst = os.path.join(dst, f"data_{split}.hdf5")
        if os.path.exists(f_src) and not os.path.exists(f_dst):
            shutil.copy(f_src, f_dst)      # data_test.hdf5 no se copia: no tiene etiquetas
    return dst


def elegir_sesiones(n_sessions):
    ses = sesiones_disponibles()[:n_sessions]
    faltan = [s for s in ses
              if not os.path.exists(os.path.join(DATA_ROOT, s, "data_train.hdf5"))]
    if faltan:
        print(f"Copiando {len(faltan)} sesion(es) de Drive al disco local de la VM...")
        t0 = time.time()
        for i, s in enumerate(faltan, 1):
            copiar_sesion(s)
            print(f"  [{i}/{len(faltan)}] {s}")
        print(f"  copiadas en {time.time()-t0:.0f}s")
    return ses


_CACHE_DATOS = {}

def get_datos(cfg):
    """Devuelve (train_raw, val_raw, stats_dir, n_sesiones_reales).

    La clave de cache incluye todo lo que cambia la FORMA del tensor de entrada
    (capa_sesion anade un canal: 512 -> 513), porque los shape files de ESPnet
    dejan de valer si eso cambia.
    """
    n_sessions      = cfg["n_sessions"]
    val_igual_train = cfg["val_igual_train"]
    clave = (n_sessions, val_igual_train, PRELOAD_RAM, cfg["capa_sesion"],
             cfg["objetivo_ctc"], SOLO_SESIONES_COMPLETAS)
    if clave in _CACHE_DATOS:
        return _CACHE_DATOS[clave]

    sesiones = elegir_sesiones(n_sessions)
    print(f"Sesiones ({len(sesiones)}): {sesiones[:3]}{' ...' if len(sesiones) > 3 else ''}")
    idx_train = construir_indice(sesiones, "train")
    idx_val   = idx_train if val_igual_train else construir_indice(sesiones, "val")

    train_raw = SeeGDataset(idx_train, preload=PRELOAD_RAM)
    val_raw   = train_raw if val_igual_train else SeeGDataset(idx_val, preload=PRELOAD_RAM)

    stats_dir = (f"{OUTPUT_DIR}/stats_s{len(sesiones)}"
                 f"{'_vt' if val_igual_train else ''}"
                 f"{'_sess' if cfg['capa_sesion'] else ''}"
                 f"{'_char' if cfg['objetivo_ctc'] == 'char' else ''}")
    print(f"Train: {len(idx_train)} trials · Val: {len(idx_val)} trials")

    _CACHE_DATOS[clave] = (train_raw, val_raw, stats_dir, len(sesiones))
    return _CACHE_DATOS[clave]


# Comprobacion rapida: copia UNA sesion y lee un trial
_ses = sesiones_disponibles()[:1]
assert _ses, "No hay sesiones utilizables; revisa DRIVE_DATA y SOLO_SESIONES_COMPLETAS"
copiar_sesion(_ses[0])
_ds = SeeGDataset(construir_indice(_ses, "train"))
_it = _ds[0]
_x  = _it["input_features"]
print(f"\nSesion de prueba: {_ses[0]} ({len(_ds)} trials)")
print("text    :", _it["text"])
print("text_ctc:", _it["text_ctc"])
print("features:", _x.shape, _x.dtype)
# Los HDF5 de B2T'25 ya vienen z-scoreados por bloque: si esto ya esta cerca de (0, 1),
# volver a normalizar por trial (norm="trial") borra la amplitud relativa entre trials.
print(f"estadisticas del HDF5 crudo: media={_x.mean():+.3f} std={_x.std():.3f} "
      f"min={_x.min():+.2f} max={_x.max():+.2f}")
# Out:
# Sesion de prueba: t15.2023.08.11 (288 trials)
# text    : <eng><asr><notimestamps> bring it closer.
# text_ctc: bring it closer
# features: (321, 512) float32
# estadisticas del HDF5 crudo: media=-0.000 std=0.999 min=-2.41 max=+10.00

# %% [markdown]
# ## 5. Tokenizador y configuración base de OWSM
#
# Se carga el modelo preentrenado **una sola vez** por sesión: de él salen el tokenizador, la config base y una copia de los pesos que reutilizan todos los experimentos.

# %%
pretrained = Speech2Text.from_pretrained(FINETUNE_MODEL, lang_sym=f"<{LANGUAGE}>", beam_size=5)
pretrain_config = vars(pretrained.s2t_train_args)
tokenizer = pretrained.tokenizer
converter = pretrained.converter
_pretrained_state_dict = {k: v.cpu().clone() for k, v in pretrained.s2t_model.state_dict().items()}
del pretrained
gc.collect()

def tokenize(text):
    return np.array(converter.tokens2ids(tokenizer.text2tokens(text)), dtype=np.int64)

BLANK_ID = converter.token_list.index("<blank>") if "<blank>" in converter.token_list else 0

# ── Vocabulario de caracteres para el objetivo CTC alternativo ──────────────
# Solo lo que aparece en las transcripciones de B2T'25 (ingles en minusculas, sin
# puntuacion). El indice 0 se reserva para el blank de CTC.
_CHARS = list("abcdefghijklmnopqrstuvwxyz'") + [" "]
CHAR_BLANK_ID = 0
_CHAR2ID = {c: i + 1 for i, c in enumerate(_CHARS)}      # 0 = blank
_ID2CHAR = {i + 1: c for i, c in enumerate(_CHARS)}
CHAR_VOCAB = len(_CHARS) + 1                              # +1 por el blank

def tokenize_char(text):
    """Trocea en caracteres. Ignora cualquier simbolo fuera del vocabulario."""
    return np.array([_CHAR2ID[c] for c in text.lower() if c in _CHAR2ID], dtype=np.int64)

def destok_char(ids):
    """De ids de caracteres a texto (ya sin blanks; el colapso CTC se hace fuera)."""
    return "".join(_ID2CHAR[i] for i in ids if i in _ID2CHAR)


def objetivo_info(cfg):
    """Devuelve (funcion_tokenizar, id_del_blank, tam_vocab, destok) segun el objetivo."""
    if cfg["objetivo_ctc"] == "char":
        return tokenize_char, CHAR_BLANK_ID, CHAR_VOCAB, destok_char
    return tokenize, BLANK_ID, len(converter.token_list), \
           (lambda ids: tokenizer.tokens2text(converter.ids2tokens(list(ids))))


def enmascarar(x, cfg, rng):
    """Aumento tipo SpecAugment adaptado a sEEG: bandas de tiempo y de canales a cero.

    OJO: se aplica AQUI y no con el specaug de ESPnet a proposito. El specaug de
    ESPnet actua sobre el tensor de entrada completo, que con capa_sesion incluye
    el canal extra con el indice de sesion; enmascararlo lo pondria a 0 y el
    modelo creeria que todos los trials son de la sesion 0. Aqui se enmascaran
    solo los 512 canales de senal, antes de anadir el de sesion.
    """
    T = x.shape[0]
    for _ in range(cfg["aug_n_tiempo"]):                 # bandas temporales
        w = rng.integers(0, max(1, int(cfg["aug_max_tiempo"] * T)) + 1)
        if w > 0 and T > w:
            t0 = rng.integers(0, T - w)
            x[t0:t0 + w, :] = 0.0
    # Electrodos: subconjunto ALEATORIO, no una banda contigua. El orden de los
    # electrodos es arbitrario (por eso tampoco se convoluciona sobre ese eje),
    # asi que borrar c0:c0+w no tiene el sentido fisico que si tiene en audio,
    # donde la banda de frecuencias contigua es una unidad real.
    n_c = int(cfg["aug_n_canales"] * cfg["aug_max_canales"])
    if n_c > 0:
        x[:, rng.choice(512, size=min(n_c, 512), replace=False)] = 0.0
    if cfg["aug_ruido"] > 0:
        x += rng.normal(0, cfg["aug_ruido"], x.shape).astype(np.float32)
    return x


def preparar_speech(d, cfg, aug=False, rng=None):
    """Tensor de entrada al modelo: (T, 512) o (T, 513) si hay capa por sesion.

    El indice de sesion viaja como un canal extra constante. Es la forma menos invasiva
    de meterlo: el pipeline de ESPnet solo transporta 'speech', y el padding va al final
    (con ceros), asi que el frame 0 siempre es dato real y de ahi lo lee el frontend.
    """
    x = normaliza(d["input_features"], cfg["norm"])
    if aug:
        x = enmascarar(x, cfg, rng)
    if cfg["capa_sesion"]:
        sid = np.full((x.shape[0], 1), float(d["session_idx"]), dtype=np.float32)
        x = np.concatenate([x, sid], axis=1)
    return x


def make_data_info(cfg, aug=False):
    # text y text_prev SIEMPRE en BPE: alimentan el decoder de atencion de OWSM.
    # text_ctc usa el tokenizador del objetivo elegido (BPE o caracteres).
    tok_ctc, _, _, _ = objetivo_info(cfg)
    aug = aug and cfg["aug"]
    rng = np.random.default_rng(cfg["seed"]) if aug else None
    return {
        "speech":    lambda d: preparar_speech(d, cfg, aug, rng),
        "text":      lambda d: tokenize(d["text"]),
        "text_prev": lambda d: tokenize(d["text_prev"]),
        "text_ctc":  lambda d: tok_ctc(d["text_ctc"]),
    }

print("Tokenizador y config base cargados")
print("  ctc_weight original de OWSM:", pretrain_config.get("model_conf", {}).get("ctc_weight"))
print(f"  BPE: {len(converter.token_list)} clases (blank id {BLANK_ID}) · "
      f"caracteres: {CHAR_VOCAB} clases (blank id {CHAR_BLANK_ID})")
# Out:
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 29 files:   0%|          | 0/29 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Tokenizador y config base cargados
#   ctc_weight original de OWSM: 0.3
#   BPE: 50002 clases (blank id 0) · caracteres: 29 clases (blank id 0)

# %% [markdown]
# ## 6. Construcción del modelo
#
# Tres arreglos respecto a la versión local:
#
# 1. **`ctc_weight` se inyecta en `model_conf`.** Antes el modelo se construía desde `pretrain_config`, así que el peso del CTC en el loss era siempre el 0.3 de OWSM, dijeras lo que dijeras en el panel. (Se veía en los logs: `0.3·loss_ctc + 0.7·loss_att = loss`.)
# 2. **`usar_lora` es opcional**, para poder comparar con/sin adaptadores.
# 3. **`enc_lr_scale`** parchea `build_optimizers` para poner el encoder preentrenado en un grupo de parámetros con LR más bajo. Con Adam no vale escalar gradientes (es invariante a escala), hace falta grupos de verdad.
#
# **Nota sobre los frontends `linear`/`conv1d`:** heredan de `Conv2dSubsampling` aunque no usen su `__init__`. Es necesario porque el encoder de ESPnet decide si pasarle la máscara de padding al frontend mirando `isinstance(self.embed, Conv2dSubsampling)`; si la clase no hereda de ahí, ESPnet asume que es un embedding que no cambia la longitud de la secuencia (como un `nn.Embedding` de texto) y lo llama sin máscara, lo que revienta con `TypeError: forward() missing 1 required positional argument: 'x_mask'`.

# %%
def count_trainable(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable

def freeze_all(model):
    for p in model.parameters():
        p.requires_grad = False


def _subsample_mask(x_mask, subsample, target_len):
    """Recorta/rellena la mascara para que case EXACTAMENTE con la longitud de x tras el submuestreo."""
    if x_mask is None:
        return None
    m = x_mask[:, :, ::subsample]
    if m.size(2) > target_len:
        m = m[:, :, :target_len]
    elif m.size(2) < target_len:
        m = torch.nn.functional.pad(m, (0, target_len - m.size(2)), value=False)
    return m


class CapaSesion(torch.nn.Module):
    """Transformada afin por sesion + softsign (capa 'day-specific' del baseline de B2T'25).

    Por que hace falta: los 45 dias de grabacion abarcan 20 meses y la senal que produce
    un mismo fonema cambia de un dia a otro (deriva de los electrodos, micromovimientos
    del array). Un unico frontend compartido tiene que aprender N mapeos senal->fonema
    contradictorios a la vez y ademas adivinar de que dia es cada trial. Con una matriz
    por sesion, cada dia se alinea a un espacio comun y el resto del modelo ve un unico
    problema coherente.

    Se inicializa a la identidad, asi que al empezar solo aplica el softsign.
    Coste: n_sesiones x 512 x 512 parametros (~2.6 M con 10 sesiones, ~12 M con 45).
    """

    def __init__(self, n_sesiones, dim=512):
        super().__init__()
        self.n_sesiones = n_sesiones
        self.W = torch.nn.Parameter(torch.eye(dim).unsqueeze(0).repeat(n_sesiones, 1, 1))
        self.b = torch.nn.Parameter(torch.zeros(n_sesiones, dim))

    def forward(self, x):
        # x: (B, T, dim+1). El ultimo canal es el indice de sesion, constante en el tiempo.
        sid = x[:, 0, -1].round().long().clamp_(0, self.n_sesiones - 1)
        x = x[:, :, :-1]
        # baddbmm: b[sid] + x @ W[sid], por muestra del batch
        x = torch.baddbmm(self.b[sid].unsqueeze(1), x, self.W[sid])
        return torch.nn.functional.softsign(x)


def build_frontend(kind, pos_enc, capa_sesion=None, cfg=None):
    """Frontend (encoder.embed) que reemplaza al Conv2dSubsampling original de mel.

    IMPORTANTE: heredan de Conv2dSubsampling (aunque no usen su __init__) porque el
    encoder de ESPnet decide si pasar la mascara al embed mirando
    `isinstance(self.embed, Conv2dSubsampling)`. Si no se hereda de ahi, ESPnet llama
    a embed(x) SIN mascara (asumiendo que es un embedding de texto que no submuestrea)
    y revienta con "forward() missing 1 required positional argument: 'x_mask'".
    """
    import torch.nn as nn

    if kind == "conv2d":
        class Conv2dFrontend(Conv2dSubsampling):
            # OJO: ~66 GFLOP/muestra, el 85-90% del coste del modelo.
            def __init__(self):
                super().__init__(512, 384, dropout_rate=0.0, pos_enc=pos_enc)
                self.sesion = capa_sesion
            def forward(self, x, x_mask):
                if self.sesion is not None:
                    x = self.sesion(x)
                return super().forward(x, x_mask)
        return Conv2dFrontend()

    elif kind == "linear":
        class LinearFrontend(Conv2dSubsampling):
            def __init__(self, in_dim=512, out_dim=384, subsample=4):
                torch.nn.Module.__init__(self)   # NO llamar a Conv2dSubsampling.__init__
                self.sesion = capa_sesion
                self.proj = nn.Linear(in_dim, out_dim)
                self.subsample = subsample
                self.pos_enc = pos_enc
            def forward(self, x, x_mask):
                if self.sesion is not None:
                    x = self.sesion(x)
                x = self.proj(x)
                x = x[:, ::self.subsample, :]
                x = self.pos_enc(x)
                x_mask = _subsample_mask(x_mask, self.subsample, x.size(1))
                return x, x_mask
        return LinearFrontend()

    elif kind == "conv1d":
        class Conv1dFrontend(Conv2dSubsampling):
            def __init__(self, in_dim=512, out_dim=384):
                torch.nn.Module.__init__(self)   # NO llamar a Conv2dSubsampling.__init__
                self.sesion = capa_sesion
                self.conv = nn.Sequential(
                    nn.Conv1d(in_dim, out_dim, kernel_size=3, stride=2, padding=1), nn.ReLU(),
                    nn.Conv1d(out_dim, out_dim, kernel_size=3, stride=2, padding=1), nn.ReLU(),
                )
                self.pos_enc = pos_enc
            def forward(self, x, x_mask):
                if self.sesion is not None:
                    x = self.sesion(x)
                x = self.conv(x.transpose(1, 2)).transpose(1, 2)
                x = self.pos_enc(x)
                x_mask = _subsample_mask(x_mask, 4, x.size(1))
                return x, x_mask
        return Conv1dFrontend()

    elif kind == "deep":
        # Frontend convolucional profundo, pensado para sEEG (no para audio).
        #   1. proyeccion ESPACIAL: Linear(512 -> d) que mezcla los 256 electrodos.
        #      A diferencia de conv2d, que convoluciona a lo largo del eje de
        #      electrodos como si fuera un eje de frecuencias, aqui la mezcla es
        #      todos-con-todos, que es lo correcto cuando el orden de los
        #      electrodos es arbitrario.
        #   2. bloques TEMPORALES Conv1d con LayerNorm + GELU y conexiones
        #      residuales. Las convoluciones ven todos los frames (nada de
        #      decimacion), y el submuestreo se hace con stride.
        #   3. proyeccion final a 384 + codificacion posicional de OWSM.
        d        = (cfg or {}).get("deep_dim", 512)
        n_res    = (cfg or {}).get("deep_bloques", 2)   # bloques residuales por etapa
        kernel   = (cfg or {}).get("deep_kernel", 5)
        dropout  = (cfg or {}).get("deep_dropout", 0.1)
        subsample = (cfg or {}).get("subsample", 4)     # 4 = dos etapas de stride 2

        class BloqueTemporal(nn.Module):
            def __init__(self, dim, k, stride):
                super().__init__()
                self.conv = nn.Conv1d(dim, dim, k, stride=stride, padding=k // 2)
                self.norm = nn.LayerNorm(dim)
                self.act = nn.GELU()
                self.drop = nn.Dropout(dropout)
                self.residual = (stride == 1)
            def forward(self, x):                        # x: (B, T, dim)
                y = self.conv(x.transpose(1, 2)).transpose(1, 2)
                y = self.drop(self.act(self.norm(y)))
                return x + y if self.residual else y

        class FrontendProfundo(Conv2dSubsampling):
            def __init__(self):
                torch.nn.Module.__init__(self)
                self.sesion = capa_sesion
                self.subsample = subsample
                self.espacial = nn.Sequential(
                    nn.Linear(512, d), nn.LayerNorm(d), nn.GELU(), nn.Dropout(dropout))
                bloques = []
                n_etapas = {1: 0, 2: 1, 4: 2, 8: 3}[subsample]
                for _ in range(n_etapas):
                    bloques.append(BloqueTemporal(d, kernel, stride=2))
                    bloques += [BloqueTemporal(d, kernel, 1) for _ in range(n_res)]
                if n_etapas == 0:
                    bloques += [BloqueTemporal(d, kernel, 1) for _ in range(n_res)]
                self.bloques = nn.ModuleList(bloques)
                self.salida = nn.Linear(d, 384)
                self.pos_enc = pos_enc

            def forward(self, x, x_mask):
                if self.sesion is not None:
                    x = self.sesion(x)
                x = self.espacial(x)
                # Anular el padding: tras la capa espacial (con sesgo) los frames
                # de relleno dejan de ser cero y se colarian en las convoluciones.
                if x_mask is not None:
                    x = x * x_mask.transpose(1, 2).to(x.dtype)
                for b in self.bloques:
                    x = b(x)
                x = self.salida(x)
                x = self.pos_enc(x)
                x_mask = _subsample_mask(x_mask, self.subsample, x.size(1))
                return x, x_mask

        return FrontendProfundo()

    raise ValueError(f"Frontend desconocido: {kind}")


def make_build_model_fn(cfg, n_sesiones=1, verbose=True):
    """Devuelve el build_model_fn que ESPnet-EZ usara para ESTE experimento."""
    def build_model_fn(args):
        from espnet2.tasks.s2t import S2TTask

        # ── ARREGLO: el ctc_weight del panel tiene que llegar al modelo ──
        conf = dict(pretrain_config)
        conf["model_conf"] = {**conf.get("model_conf", {}), "ctc_weight": cfg["ctc_weight"]}

        # ── InterCTC: perdidas CTC auxiliares en capas intermedias del encoder ──
        # Da senal de gradiente directa a las capas de abajo en vez de que tenga
        # que propagarse desde el final. Es la receta estandar contra el
        # subajuste en encoders profundos entrenados con CTC.
        if cfg["interctc_weight"] > 0:
            conf["encoder_conf"] = {**conf.get("encoder_conf", {}),
                                    "interctc_layer_idx": list(cfg["interctc_layers"])}
            conf["model_conf"]["interctc_weight"] = cfg["interctc_weight"]

        model = S2TTask.build_model(argparse.Namespace(**conf))
        model.load_state_dict(_pretrained_state_dict, strict=False)

        # sEEG entra directa: fuera frontend mel y normalizacion global
        model.frontend = None
        model.normalize = None

        pos_enc = model.encoder.embed.out[1]
        sesion = CapaSesion(n_sesiones) if cfg["capa_sesion"] else None
        model.encoder.embed = build_frontend(cfg["frontend"], pos_enc, sesion, cfg)

        # ── objetivo CTC de caracteres: nueva cabeza + error_calculator coherente ──
        if cfg["objetivo_ctc"] == "char" and model.ctc is not None:
            from espnet2.asr.ctc import CTC
            from espnet.nets.pytorch_backend.transformer.subsampling import Conv2dSubsampling  # noqa
            from espnet.nets.e2e_asr_common import ErrorCalculator
            enc_dim = model.ctc.ctc_lo.in_features
            # ctc_lo pasa de (enc_dim -> 50002) a (enc_dim -> ~32). Se entrena desde cero.
            model.ctc = CTC(odim=CHAR_VOCAB, encoder_output_size=enc_dim, zero_infinity=True)
            # El cer_ctc del train.log lo calcula el error_calculator con SU token_list;
            # hay que darle el de caracteres o las cifras del log no querran decir nada.
            char_list = ["<blank>"] + _CHARS
            model.error_calculator = ErrorCalculator(
                char_list, " ", "<blank>", report_cer=True, report_wer=True)
            model.token_list = char_list

        model.train()
        freeze_all(model)
        # LoRA solo tiene sentido con la base CONGELADA: aprende un delta de rango bajo
        # sobre pesos fijos. Si el encoder tambien se entrena, W y BA se solapan y solo
        # se anaden parametros y ciclos de merge/unmerge sin ganar nada.
        if cfg["usar_lora"] and cfg["unfreeze_encoder"] and cfg["unfreeze_n_layers"] is None:
            if verbose:
                print("  [nota] usar_lora=True con el encoder entero descongelado no aporta: "
                      "se desactiva LoRA")
        elif cfg["usar_lora"]:
            create_lora_adapter(model, target_modules=LORA_TARGET)

        for p in model.encoder.embed.parameters():   # frontend nuevo (incl. capa de sesion)
            p.requires_grad = True
        if model.ctc is not None:                    # ESPnet lo pone a None si ctc_weight==0
            for p in model.ctc.parameters():
                p.requires_grad = True

        if cfg["unfreeze_encoder"]:
            if cfg["unfreeze_n_layers"] is None:
                for p in model.encoder.parameters():
                    p.requires_grad = True
            else:
                for layer in model.encoder.encoders[:cfg["unfreeze_n_layers"]]:
                    for p in layer.parameters():
                        p.requires_grad = True

        if verbose:
            total, trainable = count_trainable(model)
            extra = f" + capa_sesion({n_sesiones})" if cfg["capa_sesion"] else ""
            obj = (f"char({CHAR_VOCAB} clases)" if cfg["objetivo_ctc"] == "char"
                   else f"bpe({len(converter.token_list)} clases)")
            print(f"  frontend={cfg['frontend']}{extra} · objetivo_ctc={obj} · "
                  f"lora={cfg['usar_lora']} · "
                  f"encoder={'descongelado' if cfg['unfreeze_encoder'] else 'congelado'} · "
                  f"ctc_weight={cfg['ctc_weight']} · norm={cfg['norm']}")
            print(f"  {trainable:,} entrenables / {total:,} totales ({trainable/total*100:.2f}%)")
            if model.ctc is None:
                print("  [nota] ctc_weight=0 -> ESPnet desactiva la cabeza CTC")
            if getattr(model, "decoder", None) is None:
                print("  [nota] ctc_weight=1 -> ESPnet desactiva el decoder "
                      "(solo CTC; la evaluacion sera greedy)")
        return model

    return build_model_fn


# ── LR diferencial: grupos de parametros en el optimizador ────────────
def set_encoder_lr_scale(scale):
    """scale<1.0 -> el encoder preentrenado entrena con lr*scale; el frontend nuevo, CTC y LoRA con lr."""
    from espnet2.tasks.s2t import S2TTask

    if scale is None or scale == 1.0:
        if "build_optimizers" in S2TTask.__dict__:
            del S2TTask.build_optimizers      # restaura la implementacion original
        return

    OPTIMS = {"adam": torch.optim.Adam, "adamw": torch.optim.AdamW, "sgd": torch.optim.SGD}

    def build_optimizers(cls, args, model):
        if args.optim not in OPTIMS:
            raise ValueError(f"enc_lr_scale no soportado con optim={args.optim}")
        base_lr = args.optim_conf.get("lr", 1e-3)
        conf = {k: v for k, v in args.optim_conf.items() if k != "lr"}
        nuevos, preentrenados = [], []
        for name, p in model.named_parameters():
            if not p.requires_grad:
                continue
            es_nuevo = (name.startswith("encoder.embed") or name.startswith("ctc.")
                        or "lora_" in name)
            (nuevos if es_nuevo else preentrenados).append(p)
        grupos = [{"params": nuevos, "lr": base_lr},
                  {"params": preentrenados, "lr": base_lr * scale}]
        print(f"  LR diferencial: {len(nuevos)} tensores a {base_lr:g} · "
              f"{len(preentrenados)} a {base_lr*scale:g}")
        return [OPTIMS[args.optim](grupos, lr=base_lr, **conf)]

    S2TTask.build_optimizers = classmethod(build_optimizers)

print("Constructores de modelo listos.")
# Out:
# Constructores de modelo listos.

# %% [markdown]
# ## 7. Configuración de entrenamiento
#
# Además de lo que ya inyectabas en local, aquí van los ajustes específicos de GPU: `use_amp`, `cudnn_benchmark`, `cudnn_deterministic=False` (el valor por defecto `True` cuesta un 20-30 %), `keep_nbest_models=1` para no llenar el disco y `resume=True` para sobrevivir a las desconexiones de Colab.

# %%
YAML_BASE = """
use_lora: true

rir_scp: null
noise_scp: null
speech_volume_normalize: null
non_linguistic_symbols: null

preprocessor_conf:
  speech_name: speech
  text_name: text

seed: 2024
num_workers: 0
ngpu: 1
batch_type: sorted
batch_size: 8
accum_grad: 1
max_epoch: 1
patience: null
init: null
best_model_criterion:
- [valid, loss, min]
keep_nbest_models: 1
use_amp: true

optim: adam
optim_conf:
    lr: 0.001
    weight_decay: 0.000001
scheduler: warmuplr
scheduler_conf:
    warmup_steps: 20

specaug: null
ctc_weight: 0.0
grad_clip: 5.0
"""

with open("/content/finetune_b2t25.yaml", "w") as f:
    f.write(YAML_BASE)


def build_finetune_config(cfg, stats_dir):
    ft = ez.config.update_finetune_config(
        "s2t", copy.deepcopy(pretrain_config), "/content/finetune_b2t25.yaml")

    # ── entorno ──
    ft["ngpu"] = NGPU
    ft["use_amp"] = USE_AMP
    ft["num_workers"] = cfg["num_workers"]
    # cudnn_benchmark=True es CONTRAPRODUCENTE aqui: con batch_type sorted cada batch
    # tiene una longitud distinta, y cudnn vuelve a buscar el mejor algoritmo para cada
    # forma nueva (143 busquedas exhaustivas en la primera epoca).
    ft["cudnn_benchmark"] = False
    ft["cudnn_deterministic"] = False
    ft["multiple_iterator"] = False
    ft["iterator_type"] = "sequence"
    ft["log_interval"] = 10
    ft["num_iters_per_epoch"] = None
    ft["seed"] = cfg["seed"]
    ft["resume"] = True
    ft["keep_nbest_models"] = 1

    # ── criterio para elegir el mejor checkpoint ──
    # ARREGLO: con ctc_weight bajo, 'valid loss' es sobre todo perdida de atencion y
    # toca fondo hacia la epoca 4, cuando el cer_ctc todavia esta bajando. Seleccionar
    # por cer_ctc guarda el modelo que de verdad es mejor en la tarea.
    if cfg["criterio"] == "cer_ctc" and cfg["ctc_weight"] > 0:
        ft["best_model_criterion"] = [["valid", "cer_ctc", "min"]]
    else:
        ft["best_model_criterion"] = [["valid", "loss", "min"]]

    # ── batching ──
    ft["batch_type"] = cfg["batch_type"]
    if cfg["batch_type"] == "numel":
        ft["batch_bins"] = cfg["batch_bins"]
    else:
        ft["batch_size"] = cfg["batch_size"]
    ft["accum_grad"] = cfg["accum_grad"]

    # ── optimizacion ──
    ft["max_epoch"] = cfg["max_epoch"]
    ft["scheduler_conf"]["warmup_steps"] = cfg["warmup"]
    ft["optim"] = cfg["optim"]
    ft["optim_conf"]["lr"] = cfg["lr"]
    ft["optim_conf"]["weight_decay"] = cfg["weight_decay"]
    ft["grad_clip"] = cfg["grad_clip"]
    ft["ctc_weight"] = cfg["ctc_weight"]          # informativo, el que manda es model_conf
    ft["model_conf"] = {**ft.get("model_conf", {}), "ctc_weight": cfg["ctc_weight"]}

    # ── shape files ──
    nombres = ["speech_shape", "text_shape", "text_prev_shape", "text_ctc_shape"]
    ft["train_shape_file"] = [f"{stats_dir}/train/{n}" for n in nombres]
    ft["valid_shape_file"] = [f"{stats_dir}/valid/{n}" for n in nombres]
    return ft


def shape_files(stats_dir):
    nombres = ["speech_shape", "text_shape", "text_prev_shape", "text_ctc_shape"]
    return ([f"{stats_dir}/train/{n}" for n in nombres]
            + [f"{stats_dir}/valid/{n}" for n in nombres])

print("Constructor de config listo.")
# Out:
# Constructor de config listo.

# %% [markdown]
# ## 8. Logs y métricas por época
#
# ESPnet no escribe `train.log` por sí solo cuando se lanza desde un notebook (en las recetas sale de una redirección de shell). Aquí se captura el logger raíz a un fichero por experimento y solo se muestran en pantalla las líneas de resumen de época, así el notebook no se llena de miles de líneas.
#
# `parse_train_log` convierte ese log en un CSV con una fila por época: justo lo que necesitas para las curvas de la memoria.

# %%
class CapturaLog:
    """Redirige el logging de ESPnet a un fichero; en pantalla, solo el resumen por epoca."""

    CLAVES = ("batch:", "epoch results", "epoch started", "Saving", "best",
              "There are no improvements", "Stop training", "The training was finished")

    def __init__(self, path):
        self.path = path
        self.previos = None

    def __enter__(self):
        root = logging.getLogger()
        self.previos = (root.handlers[:], root.level)
        root.handlers = []
        root.setLevel(logging.INFO)

        fh = logging.FileHandler(self.path, mode="a", encoding="utf-8")
        fh.setFormatter(logging.Formatter("%(asctime)s %(levelname)s: %(message)s"))
        root.addHandler(fh)

        claves = self.CLAVES
        class Resumen(logging.Filter):
            def filter(self, record):
                return any(c in record.getMessage() for c in claves)
        sh = logging.StreamHandler()
        sh.addFilter(Resumen())
        sh.setFormatter(logging.Formatter("    %(message)s"))
        root.addHandler(sh)
        return self

    def __exit__(self, *exc):
        root = logging.getLogger()
        for h in root.handlers:
            try: h.close()
            except Exception: pass
        root.handlers, root.level = self.previos
        return False


PAR = re.compile(r"([a-zA-Z_][a-zA-Z_0-9]*)=(-?[\d.]+(?:[eE][-+]?\d+)?)")

def parse_train_log(path):
    """Extrae una fila por epoca del train.log de ESPnet."""
    filas = []
    if not os.path.exists(path):
        return pd.DataFrame()
    with open(path, encoding="utf-8", errors="ignore") as f:
        for linea in f:
            m = re.search(r"(\d+)epoch results:(.*)", linea)
            if not m:
                continue
            epoca, resto = int(m.group(1)), m.group(2)
            fila = {"epoch": epoca}
            partes = re.split(r"\[valid\]", resto)
            for prefijo, trozo in zip(["train_", "valid_"], partes):
                trozo = trozo.replace("[train]", "")
                for k, v in PAR.findall(trozo):
                    if k in ("time", "total_count"):
                        continue
                    fila[prefijo + k] = float(v)
            filas.append(fila)
    df = pd.DataFrame(filas)
    if len(df):
        df = df.drop_duplicates(subset="epoch", keep="last").sort_values("epoch")
    return df

print("Utilidades de log listas.")
# Out:
# Utilidades de log listas.

# %% [markdown]
# ## 9. Inferencia y CER/WER
#
# Igual que en local (beam search de OWSM reconectado al modelo fine-tuneado), pero el objeto `Speech2Text` se construye **una sola vez** y se reutiliza en todos los experimentos, y los pesos de decodificación (`ctc_weight`) se ajustan sobre la marcha.

# %%
_S2T = None

def get_s2t():
    global _S2T
    if _S2T is None:
        _S2T = Speech2Text.from_pretrained(
            FINETUNE_MODEL, lang_sym=f"<{LANGUAGE}>", task_sym="<asr>",
            beam_size=BEAM_SIZE, ctc_weight=0.3, device=DEVICE, nbest=1)
    return _S2T


def rebind_beam_search(s2t, model, ctc_weight):
    """Repunta decoder y CTC del beam search hacia el modelo fine-tuneado."""
    s2t.s2t_model = model
    bs = s2t.beam_search
    for d in (getattr(bs, "scorers", {}), getattr(bs, "full_scorers", {}),
              getattr(bs, "part_scorers", {})):
        if "decoder" in d:
            d["decoder"] = model.decoder
        if "ctc" in d and hasattr(d["ctc"], "ctc"):
            d["ctc"].ctc = model.ctc
    if hasattr(bs, "nn_dict") and "decoder" in bs.nn_dict:
        bs.nn_dict["decoder"] = model.decoder
    if hasattr(bs, "weights") and ctc_weight is not None:
        bs.weights["ctc"] = ctc_weight
        bs.weights["decoder"] = 1.0 - ctc_weight
    bs.to(device=DEVICE).eval()


def _norm(t):
    t = t.lower().replace("\x00", "")
    t = re.sub(r"<[^>]+>", " ", t)
    t = t.translate(str.maketrans("", "", string.punctuation))
    return re.sub(r"\s+", " ", t).strip()

def _lev(a, b):
    dp = list(range(len(b) + 1))
    for i, ca in enumerate(a, 1):
        prev, dp[0] = dp[0], i
        for j, cb in enumerate(b, 1):
            old = dp[j]
            dp[j] = min(dp[j] + 1, dp[j - 1] + 1, prev + (ca != cb))
            prev = old
    return dp[-1]

def cer(ref, hyp):
    r, h = _norm(ref), _norm(hyp)
    return 0.0 if len(r) == 0 else _lev(list(r), list(h)) / len(r)

def wer(ref, hyp):
    r, h = _norm(ref).split(), _norm(hyp).split()
    return 0.0 if len(r) == 0 else _lev(r, h) / len(r)


def find_best_checkpoint(exp_dir):
    for name in ["valid.cer_ctc.best.pth", "valid.loss.best.pth",
                 "valid.acc.best.pth", "train.loss.best.pth"]:
        p = os.path.join(exp_dir, name)
        if os.path.exists(p):
            return p
    cands = sorted(glob.glob(os.path.join(exp_dir, "*epoch.pth")), key=os.path.getmtime)
    if not cands:
        raise FileNotFoundError(f"No hay checkpoints en {exp_dir}")
    return cands[-1]


def cargar_modelo_entrenado(cfg, exp_dir, n_sesiones):
    ckpt = find_best_checkpoint(exp_dir)
    modelo = make_build_model_fn(cfg, n_sesiones, verbose=False)(None).to(DEVICE)
    try:
        state = torch.load(ckpt, map_location=DEVICE, weights_only=True)
    except Exception:
        state = torch.load(ckpt, map_location=DEVICE, weights_only=False)
    faltan = modelo.load_state_dict(state, strict=False)
    if faltan.missing_keys:
        print(f"    [aviso] {len(faltan.missing_keys)} tensores sin cargar del checkpoint, "
              f"p.ej. {faltan.missing_keys[0]}")
    return modelo.eval()


@torch.no_grad()
def evaluar_ctc_greedy(cfg, modelo, val_raw, n=EVAL_N, mostrar=3):
    """Decodificacion CTC greedy: argmax por frame, colapsar repeticiones, quitar blanks.
    No pasa por el decoder, asi que mide SOLO lo que el encoder extrae del sEEG.

    Devuelve DOS cifras, porque no son la misma:
      - cer_ctc_micro: exactamente como lo calcula ESPnet en el train.log (cadena de
        tokens BPE concatenados, sum(errores)/sum(longitudes)). Es la unica comparable
        con la columna cer_ctc de las curvas.
      - cer_texto: sobre el texto detokenizado y normalizado, media por trial. Es la
        que se parece a un CER "de verdad", pero la hunden los trials cortos que fallan.
    """
    from itertools import groupby
    tok_ctc, blank, _, destok = objetivo_info(cfg)
    n = min(n, len(val_raw))
    idxs = np.linspace(0, len(val_raw) - 1, n).astype(int)   # repartidos, no los n primeros

    err_bpe = ref_bpe = 0
    cers_txt, wers_txt, ejemplos = [], [], []
    for i in idxs:
        d = val_raw[int(i)]
        x = preparar_speech(d, cfg)
        speech = torch.tensor(x, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        lens = torch.tensor([speech.shape[1]], dtype=torch.long, device=DEVICE)
        enc, _ = modelo.encode(speech, lens)
        if isinstance(enc, tuple):
            enc = enc[0]
        ids = modelo.ctc.ctc_lo(enc).argmax(-1)[0].tolist()
        hyp_ids = [k for k, _ in groupby(ids) if k != blank]   # colapso CTC estandar
        ref_ids = tok_ctc(d["text_ctc"]).tolist()

        # cer_ctc(micro): identico a como lo calcula ESPnet, sobre la unidad del objetivo
        h = destok(hyp_ids)
        r = destok(ref_ids)
        err_bpe += _lev(list(h), list(r)); ref_bpe += len(r)

        hip = destok(hyp_ids)
        cers_txt.append(cer(d["text_raw"], hip))
        wers_txt.append(wer(d["text_raw"], hip))
        if len(ejemplos) < mostrar:
            ejemplos.append((_norm(d["text_raw"]), hip))

    for ref, hip in ejemplos:
        print(f"    [ctc] REF: {ref}\n    [ctc] HYP: {hip}")
    c = np.array(cers_txt)
    print(f"    por trial: mediana={np.median(c):.3f} p10={np.percentile(c,10):.3f} "
          f"p90={np.percentile(c,90):.3f} · {(c<0.2).mean()*100:.0f}% por debajo de 0.2")
    return err_bpe / max(1, ref_bpe), float(c.mean()), float(np.mean(wers_txt))


@torch.no_grad()
def evaluar(cfg, modelo, val_raw, n=EVAL_N, mostrar=3):
    """CER/WER con el beam search de OWSM (decoder + CTC)."""
    w_dec = cfg["ctc_weight_decode"]
    w_dec = cfg["ctc_weight"] if w_dec is None else w_dec
    s2t = get_s2t()
    rebind_beam_search(s2t, modelo, w_dec)

    lang_id   = s2t.converter.token2id[f"<{LANGUAGE}>"]
    task_id   = s2t.converter.token2id["<asr>"]
    notime_id = s2t.converter.token2id[s2t.preprocessor_conf["notime_symbol"]]

    nivel = logging.getLogger().level
    logging.getLogger().setLevel(logging.WARNING)   # el beam search es MUY verboso
    cers, wers, ejemplos = [], [], []
    try:
        n = min(n, len(val_raw))
        for i in range(n):
            d = val_raw[i]
            x = preparar_speech(d, cfg)
            speech = torch.tensor(x, dtype=torch.float32, device=DEVICE).unsqueeze(0)
            lens = torch.tensor([speech.shape[1]], dtype=torch.long, device=DEVICE)
            enc, _ = modelo.encode(speech, lens)
            if isinstance(enc, tuple):
                enc = enc[0]
            s2t.beam_search.set_hyp_primer([modelo.sos, lang_id, task_id, notime_id])
            res = s2t._decode_single_sample(enc[0])
            text, token, token_int, text_nospecial, hyp = res[0]
            hipotesis = (text_nospecial or text or "").strip()
            cers.append(cer(d["text_raw"], hipotesis))
            wers.append(wer(d["text_raw"], hipotesis))
            if i < mostrar:
                ejemplos.append((_norm(d["text_raw"]), hipotesis))
    finally:
        logging.getLogger().setLevel(nivel)

    for ref, hip in ejemplos:
        print(f"    REF: {ref}\n    HYP: {hip}")
    # Un modelo que ignora la senal sEEG produce siempre la misma frase generica:
    if ejemplos and len({h for _, h in ejemplos}) == 1:
        print("    [aviso] hipotesis identicas: el modelo esta ignorando la entrada")

    return float(np.mean(cers)), float(np.mean(wers)), n

print("Evaluacion lista.")
# Out:
# Evaluacion lista.

# %% [markdown]
# ## 10. `run_experiment`
#
# Une todo: datos → stats (cacheadas) → entrenamiento → métricas → guardado. Cada llamada deja en Drive una fila en `resultados.csv`, el `train.log` y un `epocas.csv` con la curva completa.

# %%
CSV_RESULTADOS = f"{RESULTS_DIR}/resultados.csv"

def hacer_tag(cfg):
    extra = ""
    if cfg["frontend"] == "deep":
        extra += f"d{cfg['deep_dim']}b{cfg['deep_bloques']}s{cfg['subsample']}"
    if cfg["interctc_weight"] > 0:
        extra += f"_ic{cfg['interctc_weight']:g}"
    if cfg["aug"]:
        extra += "_aug"
    if cfg["weight_decay"] >= 1e-4:
        extra += f"_wd{cfg['weight_decay']:g}"
    return (f"{cfg['nombre']}_n{cfg['n_sessions']}_{cfg['frontend']}{extra}"
            f"{'_sess' if cfg['capa_sesion'] else ''}"
            f"{'_char' if cfg['objetivo_ctc'] == 'char' else ''}"
            f"_unf{int(cfg['unfreeze_encoder'])}_lora{int(cfg['usar_lora'])}"
            f"_lr{cfg['lr']:g}_els{cfg['enc_lr_scale']:g}_ctc{cfg['ctc_weight']:g}"
            f"_bs{cfg['batch_size']}_ep{cfg['max_epoch']}")

def experimentos_hechos():
    if not os.path.exists(CSV_RESULTADOS):
        return set()
    try:
        return set(pd.read_csv(CSV_RESULTADOS)["exp_tag"].astype(str))
    except Exception:
        return set()

def guardar_resultado(fila):
    df_nueva = pd.DataFrame([fila])
    if os.path.exists(CSV_RESULTADOS):
        df = pd.concat([pd.read_csv(CSV_RESULTADOS), df_nueva], ignore_index=True)
    else:
        df = df_nueva
    df.to_csv(CSV_RESULTADOS, index=False)


def asegurar_stats(trainer, stats_dir):
    faltan = [p for p in shape_files(stats_dir)
              if not os.path.exists(p) or os.path.getsize(p) == 0]
    if not faltan:
        print("  shape files ya existen, se salta collect_stats")
        return
    print("  recopilando estadisticas (solo la primera vez por configuracion de datos)...")
    nivel = logging.getLogger().level
    logging.getLogger().setLevel(logging.WARNING)
    try:
        trainer.collect_stats()
    finally:
        logging.getLogger().setLevel(nivel)
    print("  collect_stats OK")


def run_experiment(cambios):
    cfg = {**DEFAULTS, **cambios}
    tag = hacer_tag(cfg)

    if SKIP_IF_DONE and tag in experimentos_hechos():
        print(f"[SALTADO] {tag}\n")
        return None

    print("=" * 78)
    print(f"[EXPERIMENTO] {tag}")
    print("=" * 78)

    exp_dir = f"{OUTPUT_DIR}/{tag}"
    os.makedirs(exp_dir, exist_ok=True)
    drive_dir = f"{RESULTS_DIR}/{tag}"
    os.makedirs(drive_dir, exist_ok=True)

    train_raw, val_raw, stats_dir, n_ses = get_datos(cfg)
    os.makedirs(stats_dir, exist_ok=True)

    data_info = make_data_info(cfg, aug=False)          # validacion: nunca aumentada
    train_ds = ez.dataset.ESPnetEZDataset(train_raw, data_info=make_data_info(cfg, aug=True))
    valid_ds = ez.dataset.ESPnetEZDataset(val_raw,   data_info=data_info)

    set_encoder_lr_scale(cfg["enc_lr_scale"])
    log_path = f"{exp_dir}/train.log"

    def entrenar(batch_size):
        """Un intento de entrenamiento con el batch dado."""
        c = {**cfg, "batch_size": batch_size}
        ft = build_finetune_config(c, stats_dir)
        pasos = max(1, len(train_raw) // max(1, batch_size))
        print(f"  batch={batch_size} · ~{pasos} pasos/epoca · warmup {c['warmup']} "
              f"(~{c['warmup']/pasos:.1f} epocas)")
        trainer = ez.Trainer(
            task="s2t", train_config=ft,
            train_dataset=train_ds, valid_dataset=valid_ds,
            build_model_fn=make_build_model_fn(c, n_ses), data_info=data_info,
            output_dir=exp_dir, stats_dir=stats_dir, ngpu=NGPU,
        )
        asegurar_stats(trainer, stats_dir)
        train_raw.cerrar(); val_raw.cerrar()   # antes del fork (HDF5 no es fork-safe)
        with CapturaLog(log_path):
            trainer.train()
        del trainer

    t0 = time.time()
    error, bs_usado = "", cfg["batch_size"]
    for intento, bs in enumerate([cfg["batch_size"], max(1, cfg["batch_size"] // 2),
                                  max(1, cfg["batch_size"] // 4)]):
        try:
            bs_usado = bs
            entrenar(bs)
            error = ""
            break
        except torch.cuda.OutOfMemoryError as e:
            gc.collect(); torch.cuda.empty_cache()
            error = f"OutOfMemoryError (batch={bs})"
            if intento < 2:
                print(f"  [OOM con batch={bs}] reintentando con batch={max(1, bs // 2)}...")
            else:
                print(f"  [ERROR] OOM incluso con batch={bs}. Usa una GPU con mas VRAM.")
        except KeyboardInterrupt:
            error = "interrumpido"
            print("  [interrumpido por el usuario]")
            break
        except Exception as e:
            error = f"{type(e).__name__}: {e}"
            print(f"  [ERROR] {error}")
            break
    minutos = (time.time() - t0) / 60

    # ── metricas por epoca ──
    df_ep = parse_train_log(log_path)
    mejores = {}
    if len(df_ep):
        df_ep.insert(0, "exp_tag", tag)
        df_ep.to_csv(f"{drive_dir}/epocas.csv", index=False)
        mejores["epocas_hechas"] = int(df_ep["epoch"].max())
        # El minimo de cer_ctc SOBRE TODAS LAS EPOCAS. Es lo que hay que mirar: el
        # cer_ctc "en la epoca de menor loss" puede ser mucho peor si la loss esta
        # dominada por la perdida de atencion.
        if "valid_cer_ctc" in df_ep.columns and df_ep["valid_cer_ctc"].notna().any():
            j = df_ep["valid_cer_ctc"].idxmin()
            mejores["min_valid_cer_ctc"] = float(df_ep.loc[j, "valid_cer_ctc"])
            mejores["epoch_min_cer_ctc"] = int(df_ep.loc[j, "epoch"])
            ult = df_ep.tail(10)
            if len(ult) >= 5:   # ¿sigue bajando o esta plano?
                mejores["pendiente_cer_ctc"] = float(
                    np.polyfit(ult["epoch"], ult["valid_cer_ctc"], 1)[0])
        if "valid_loss" in df_ep.columns and df_ep["valid_loss"].notna().any():
            mejor = df_ep.loc[df_ep["valid_loss"].idxmin()]
            for k in df_ep.columns:
                if k.startswith("valid_") and pd.notna(mejor[k]):
                    mejores[f"best_{k}"] = float(mejor[k])
            mejores["best_epoch"] = int(mejor["epoch"])

    # ── CER/WER: greedy CTC (honesto) y beam search (con decoder) ──
    cer_m = wer_m = cer_g = wer_g = cer_micro = float("nan")
    if not error or "interrumpido" in error:
        modelo = None
        try:
            modelo = cargar_modelo_entrenado(cfg, exp_dir, n_ses)

            if EVAL_GREEDY_CTC and modelo.ctc is not None:
                print("  evaluando con CTC greedy...")
                cer_micro, cer_g, wer_g = evaluar_ctc_greedy(cfg, modelo, val_raw)
                print(f"  [CTC greedy] cer_ctc(micro, comparable con el log)={cer_micro:.3f} · "
                      f"CER texto={cer_g:.3f} · WER texto={wer_g:.3f}")

            if getattr(modelo, "decoder", None) is not None and cfg["objetivo_ctc"] == "bpe":
                print("  evaluando con beam search...")
                cer_m, wer_m, n_ev = evaluar(cfg, modelo, val_raw)
                print(f"  [beam]       CER={cer_m:.3f} · WER={wer_m:.3f} ({n_ev} trials)")
            elif cfg["objetivo_ctc"] == "char":
                print("  (objetivo char: la cabeza CTC y el decoder usan vocabularios "
                      "distintos, el beam search hibrido no aplica)")
            else:
                print("  (sin decoder: ctc_weight=1, se omite el beam search)")
        except Exception as e:
            print(f"  [evaluacion fallida] {type(e).__name__}: {e}")
        finally:
            del modelo
            gc.collect(); torch.cuda.empty_cache()

    # ── guardado ──
    for artefacto in ["train.log", "config.yaml"]:
        origen = f"{exp_dir}/{artefacto}"
        if os.path.exists(origen):
            shutil.copy(origen, f"{drive_dir}/{artefacto}")
    ckpt_tmp = f"{exp_dir}/checkpoint.pth"          # modelo+optimizador, ~1.4 GB
    if GUARDAR_CKPT:
        try:
            shutil.copy(find_best_checkpoint(exp_dir), f"{drive_dir}/valid.loss.best.pth")
        except Exception as e:
            print("  [aviso] no se pudo copiar el checkpoint:", e)
    if os.path.exists(ckpt_tmp) and not error:
        os.remove(ckpt_tmp)                          # libera disco de la VM

    fila = {"exp_tag": tag, "gpu": GPU_NAME, "minutos": round(minutos, 1),
            "compute_units": round(CU_H * minutos / 60, 2),
            "n_train": len(train_raw), "n_val": len(val_raw), "n_sesiones": n_ses,
            "batch_usado": bs_usado,
            "cer_ctc_micro": cer_micro,
            "cer_ctc_greedy": cer_g, "wer_ctc_greedy": wer_g,
            "cer_beam": cer_m, "wer_beam": wer_m, "error": error,
            **{k: v for k, v in cfg.items()}, **mejores}
    guardar_resultado(fila)

    del train_ds, valid_ds
    gc.collect(); torch.cuda.empty_cache()

    print(f"  hecho en {minutos:.1f} min (~{CU_H*minutos/60:.2f} compute units)\n")
    return fila

print("run_experiment listo.")
# Out:
# run_experiment listo.

# %% [markdown]
# ## 11. El barrido
#
# Cada entrada es solo lo que **cambia** respecto a `DEFAULTS`. El barrido está por fases: **lanza la fase 1 sola** y mira el resultado antes de seguir.
#
# ### Por qué el diagnóstico va primero
#
# Lo que dijo tu primera tanda, en una línea: `acc` empieza en 0.557 y acaba en 0.578 tras 30 épocas. Esa `acc` es la del decoder **con teacher forcing** — se le dan los tokens correctos anteriores y se mide si acierta el siguiente. Un ~57 % es lo que saca OWSM usando solo estadística del inglés, sin mirar la entrada. Que arranque ahí y no se mueva significa que el encoder no aporta nada. Y `wer=1.000` con `cer=0.34` lo confirma desde el otro lado: escribe inglés bien formado y no acierta ni una palabra.
#
# El `overfit` de la fase 1 elimina todas las salidas de escape a la vez: una sesión (sin deriva entre días), val = train (sin generalización que valga), `ctc_weight=1.0` (ESPnet desactiva el decoder, así que no hay prior lingüístico donde esconderse) y 200 épocas. Lo que quede es la capacidad del encoder de mapear sEEG → fonemas. Son ~10 min y 0.3 unidades.
#
# ### Por qué la capa por sesión
#
# Es *la* característica de este dataset: 45 sesiones repartidas en 20 meses, y la señal que produce un mismo fonema cambia de un día a otro por deriva de los electrodos. El algoritmo de referencia de B2T'25 pasa las características por una capa lineal específica del día seguida de un `softsign` antes de nada más, y los trabajos cross-subject recientes usan transformadas afines por día para alinear todo a un espacio común.
#
# Tú tenías un único frontend compartido para 10 sesiones: el modelo recibía diez mapeos señal→fonema contradictorios y tenía que deducir de qué día venía cada trial. `CapaSesion` aprende una matriz 512×512 más un sesgo por sesión, inicializados a la identidad, y aplica `softsign` después. El índice de sesión viaja hasta el frontend como un canal extra del tensor de entrada (512 → 513).
#
# ### Otros cambios respecto a la tanda anterior
#
# - **`enc_lr_scale=0.01`** en los dos runs de la fase 2: el encoder preentrenado a 1e-5 y el frontend nuevo a 1e-3. Con todo a 1e-3 lo más probable es que el warmup estuviera destruyendo los pesos de OWSM.
# - **`cer_ctc_greedy`** es la métrica a mirar en la tabla, no `cer_beam`. Sale de decodificar el `argmax` de la cabeza CTC colapsando repeticiones: sin decoder, sin beam, sin prior. Es la que no se puede falsear.

# %%
BARRIDO = [
    # ══ Referencia a batir: el run "deep" -> cer_ctc 0.517 · CER greedy 0.431 ══
    # El run "aug" fallo por exceso de regularizacion: train_loss_ctc congelado
    # en ~75 desde la epoca 12 (el bueno bajaba a 14.8). Aqui se vuelve a esa
    # configuracion y se cambian solo cosas con evidencia detras.
    #
    # CAMBIOS respecto al run "deep", con su motivo:
    #  1. grad_clip 5 -> 25 . En el log, clip=100.000 significa que el 100% de
    #     los pasos se recortaba: con grad_norm~200 y umbral 5, cada paso perdia
    #     40x de magnitud. Es el cambio con mas potencial de todos.
    #  2. adamw + weight_decay 1e-2 (antes adam + 1e-6, o sea sin regularizar).
    #     Regulariza de forma suave, sin apagar activaciones como el dropout.
    #  3. subsample 4 -> 2 . Frames de 40 ms en vez de 80. Un fonema dura 50-100 ms;
    #     /4 estaba borrando la escala en la que vive la informacion.
    #  4. InterCTC solo en la capa 2 . En el run bueno, cer_interctc_layer4=0.757
    #     frente a layer2=0.558 y final=0.517: la capa 4 estorbaba.
    #  5. usar_lora=False . Con el encoder entero descongelado, LoRA no aportaba
    #     nada (el run "deep" tenia el 100% de parametros entrenables igualmente).
    #  6. norm="ninguna" . NUNCA se ha probado, y los HDF5 de B2T ya vienen
    #     z-scoreados por bloque: renormalizar por trial borra la amplitud
    #     relativa entre trials, y los trabajos publicados no lo hacen.
    #
    # COSTE: subsample=2 duplica el coste por epoca (~13 min) y obliga a bajar el
    # batch. 45 epocas ~ 10 h ~ 17 unidades. Si prefieres ir sobre seguro y barato,
    # deja subsample=4 y batch_size=32: seria ~5 h y aisla los cambios 1, 2, 4, 5, 6.
    dict(nombre="v2", n_sessions=45, max_epoch=45, warmup=1500,
         frontend="deep", deep_dim=512, deep_bloques=2, subsample=2,
         interctc_weight=0.3, interctc_layers=(2,),
         objetivo_ctc="char", ctc_weight=1.0, capa_sesion=True,
         norm="ninguna", usar_lora=False,
         batch_size=16, accum_grad=2,          # batch efectivo 32, como el run bueno
         lr=1e-3, enc_lr_scale=0.05,
         optim="adamw", weight_decay=1e-2, grad_clip=25.0),
]

# Referencia medida en L4: n=10, 30 epocas, frontend linear -> 59 min (2 min/epoca).
def estimar_min(cfg):
    c = {**DEFAULTS, **cfg}
    factor = 1.0 if "L4" in GPU_NAME else (2.0 if "T4" in GPU_NAME else 0.5)
    por_epoca = 2.0 * (c["n_sessions"] / 10) * (0.8 if c["ctc_weight"] == 1.0 else 1.0)
    return c["max_epoch"] * por_epoca * factor

total_min = sum(estimar_min(e) for e in BARRIDO)
print(f"GPU: {GPU_NAME} ({CU_H} unidades/h)")
print(f"{len(BARRIDO)} experimentos · ~{total_min/60:.1f} h · "
      f"~{CU_H*total_min/60:.1f} compute units (~${CU_H*total_min/60*0.10:.2f})\n")
for e in BARRIDO:
    print(f"  ~{estimar_min(e)/60:4.1f} h · {hacer_tag({**DEFAULTS, **e})}")
# Out:
# GPU: NVIDIA L4 (1.71 unidades/h)
# 1 experimentos · ~5.4 h · ~9.2 compute units (~$0.92)
#
#   ~ 5.4 h · v2_n45_deepd512b2s2_ic0.3_wd0.01_sess_char_unf1_lora0_lr0.001_els0.05_ctc1_bs16_ep45

# %% [markdown]
# ## 12. Ejecutar
#
# Con Colab Pro+ puedes activar la ejecución en segundo plano y cerrar el navegador. Si te desconectan a mitad, vuelve a lanzar esta celda: los experimentos terminados se saltan y el que estuviera a medias reanuda desde su `checkpoint.pth`.

# %%
inicio = time.time()
for cambios in BARRIDO:
    run_experiment(cambios)

print("=" * 78)
print(f"BARRIDO COMPLETO en {(time.time()-inicio)/60:.0f} min "
      f"(~{CU_H*(time.time()-inicio)/3600:.1f} compute units)")
print("Resultados en:", CSV_RESULTADOS)
# Out:
# ==============================================================================
# [EXPERIMENTO] v2_n45_deepd512b2s2_ic0.3_wd0.01_sess_char_unf1_lora0_lr0.001_els0.05_ctc1_bs16_ep45
# ==============================================================================
# Copiando 44 sesion(es) de Drive al disco local de la VM...
#   [1/44] t15.2023.08.13
#   [2/44] t15.2023.08.18
#   [3/44] t15.2023.08.20
#   [4/44] t15.2023.08.25
#   [5/44] t15.2023.08.27
#   [6/44] t15.2023.09.01
#   [7/44] t15.2023.09.03
#   [8/44] t15.2023.09.24
#   [9/44] t15.2023.09.29
#   [10/44] t15.2023.10.01
#   [11/44] t15.2023.10.06
#   [12/44] t15.2023.10.08
#   [13/44] t15.2023.10.13
#   [14/44] t15.2023.10.15
#   [15/44] t15.2023.10.20
#   [16/44] t15.2023.10.22
#   [17/44] t15.2023.11.03
#   [18/44] t15.2023.11.04
#   [19/44] t15.2023.11.17
#   [20/44] t15.2023.11.19
#   [21/44] t15.2023.11.26
#   [22/44] t15.2023.12.03
#   [23/44] t15.2023.12.08
#   [24/44] t15.2023.12.10
#   [25/44] t15.2023.12.17
#   [26/44] t15.2023.12.29
#   [27/44] t15.2024.02.25
#   [28/44] t15.2024.03.03
#   [29/44] t15.2024.03.08
#   [30/44] t15.2024.03.15
#   [31/44] t15.2024.03.17
#   [32/44] t15.2024.04.25
#   [33/44] t15.2024.04.28
#   [34/44] t15.2024.05.10
#   [35/44] t15.2024.06.14
#   [36/44] t15.2024.07.19
#   [37/44] t15.2024.07.21
#   [38/44] t15.2024.07.28
#   [39/44] t15.2025.01.10
#   [40/44] t15.2025.01.12
#   [41/44] t15.2025.03.14
#   [42/44] t15.2025.03.16
#   [43/44] t15.2025.03.30
#   [44/44] t15.2025.04.13
#   copiadas en 800s
# Sesiones (45): ['t15.2023.08.11', 't15.2023.08.13', 't15.2023.08.18'] ...
#   [aviso] no encontrado: /content/data/hdf5_data_final/t15.2023.08.11/data_val.hdf5
#   [aviso] no encontrado: /content/data/hdf5_data_final/t15.2024.03.03/data_val.hdf5
#   [aviso] no encontrado: /content/data/hdf5_data_final/t15.2024.04.25/data_val.hdf5
#   [aviso] no encontrado: /content/data/hdf5_data_final/t15.2024.04.28/data_val.hdf5
# Train: 8072 trials · Val: 1426 trials
#   batch=16 · ~504 pasos/epoca · warmup 1500 (~3.0 epocas)
#   recopilando estadisticas (solo la primera vez por configuracion de datos)...
# /usr/bin/python3 /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-ec29dd12-2baa-4a24-affd-b200ecdbb144.json
# WARNING:root:Set decoder to none as ctc_weight==1.0
#   frontend=deep + capa_sesion(45) · objetivo_ctc=char(29 clases) · lora=False · encoder=descongelado · ctc_weight=1.0 · norm=ninguna
#   41,374,749 entrenables / 41,374,749 totales (100.00%)
#   [nota] ctc_weight=1 -> ESPnet desactiva el decoder (solo CTC; la evaluacion sera greedy)
#   LR diferencial: 22 tensores a 0.001 · 230 a 5e-05
#   collect_stats OK
# /usr/bin/python3 /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-ec29dd12-2baa-4a24-affd-b200ecdbb144.json
#     Saving the configuration in /content/exp/v2_n45_deepd512b2s2_ic0.3_wd0.01_sess_char_unf1_lora0_lr0.001_els0.05_ctc1_bs16_ep45/config.yaml
#   frontend=deep + capa_sesion(45) · objetivo_ctc=char(29 clases) · lora=False · encoder=descongelado · ctc_weight=1.0 · norm=ninguna
#   41,374,749 entrenables / 41,374,749 totales (100.00%)
#   [nota] ctc_weight=1 -> ESPnet desactiva el decoder (solo CTC; la evaluacion sera greedy)
#   LR diferencial: 22 tensores a 0.001 · 230 a 5e-05
# /usr/local/lib/python3.12/dist-packages/espnet2/train/trainer.py:219: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
#     1/45epoch started
# /usr/local/lib/python3.12/dist-packages/espnet2/train/trainer.py:638: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(
# /usr/local/lib/python3.12/dist-packages/espnet2/s2t/espnet_model.py:338: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(False):
#     1epoch:train:1-10batch: iter_time=0.405, forward_time=0.323, loss_ctc=692.170, loss_interctc_layer2=1.206e+03, loss=423.223, backward_time=0.125, grad_norm=2.787e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.026optim0_lr0=2.667e-06, optim0_lr1=1.333e-07, train_time=1.976
#     1epoch:train:11-20batch: iter_time=0.387, forward_time=0.173, loss_ctc=778.206, loss_interctc_layer2=1.240e+03, loss=458.384, backward_time=0.071, grad_norm=4.057e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=6.000e-06, optim0_lr1=3.000e-07, train_time=1.515
#     1epoch:train:21-30batch: iter_time=0.330, forward_time=0.103, loss_ctc=633.180, loss_interctc_layer2=996.691, loss=371.117, backward_time=0.045, grad_norm=2.011e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=9.333e-06, optim0_lr1=4.667e-07, train_time=1.068
#     1epoch:train:31-40batch: iter_time=0.339, forward_time=0.121, loss_ctc=581.559, loss_interctc_layer2=967.696, loss=348.700, backward_time=0.056, grad_norm=2.508e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.267e-05, optim0_lr1=6.333e-07, train_time=1.213
#     1epoch:train:41-50batch: iter_time=0.364, forward_time=0.142, loss_ctc=567.806, loss_interctc_layer2=1.071e+03, loss=359.398, backward_time=0.055, grad_norm=2.272e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.600e-05, optim0_lr1=8.000e-07, train_time=1.304
#     1epoch:train:51-60batch: iter_time=0.343, forward_time=0.165, loss_ctc=541.466, loss_interctc_layer2=1.031e+03, loss=344.227, backward_time=0.057, grad_norm=2.726e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.933e-05, optim0_lr1=9.667e-07, train_time=1.343
#     1epoch:train:61-70batch: iter_time=0.363, forward_time=0.140, loss_ctc=471.878, loss_interctc_layer2=1.002e+03, loss=315.504, backward_time=0.051, grad_norm=2.381e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.267e-05, optim0_lr1=1.133e-06, train_time=1.286
#     1epoch:train:71-80batch: iter_time=0.370, forward_time=0.166, loss_ctc=477.414, loss_interctc_layer2=1.062e+03, loss=326.402, backward_time=0.058, grad_norm=1.875e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.600e-05, optim0_lr1=1.300e-06, train_time=1.408
#     1epoch:train:81-90batch: iter_time=0.361, forward_time=0.136, loss_ctc=389.376, loss_interctc_layer2=938.882, loss=277.114, backward_time=0.057, grad_norm=1.987e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.933e-05, optim0_lr1=1.467e-06, train_time=1.295
#     1epoch:train:91-100batch: iter_time=0.398, forward_time=0.162, loss_ctc=424.700, loss_interctc_layer2=1.012e+03, loss=300.466, backward_time=0.059, grad_norm=2.265e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.267e-05, optim0_lr1=1.633e-06, train_time=1.451
#     1epoch:train:101-110batch: iter_time=0.324, forward_time=0.104, loss_ctc=333.860, loss_interctc_layer2=802.418, loss=237.214, backward_time=0.046, grad_norm=8.803e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.600e-05, optim0_lr1=1.800e-06, train_time=1.088
#     1epoch:train:111-120batch: iter_time=0.345, forward_time=0.153, loss_ctc=289.270, loss_interctc_layer2=828.993, loss=225.593, backward_time=0.062, grad_norm=6.650e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.933e-05, optim0_lr1=1.967e-06, train_time=1.337
#     1epoch:train:121-130batch: iter_time=0.322, forward_time=0.133, loss_ctc=412.309, loss_interctc_layer2=712.104, loss=251.124, backward_time=0.052, grad_norm=7.616e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.267e-05, optim0_lr1=2.133e-06, train_time=1.191
#     1epoch:train:131-140batch: iter_time=0.354, forward_time=0.146, loss_ctc=410.726, loss_interctc_layer2=783.810, loss=261.326, backward_time=0.058, grad_norm=3.400e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.600e-05, optim0_lr1=2.300e-06, train_time=1.308
#     1epoch:train:141-150batch: iter_time=0.370, forward_time=0.143, loss_ctc=295.225, loss_interctc_layer2=711.292, loss=210.023, backward_time=0.057, grad_norm=1.587e+04, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.933e-05, optim0_lr1=2.467e-06, train_time=1.340
#     1epoch:train:151-160batch: iter_time=0.358, forward_time=0.133, loss_ctc=282.560, loss_interctc_layer2=672.701, loss=199.801, backward_time=0.052, grad_norm=3.299e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=5.267e-05, optim0_lr1=2.633e-06, train_time=1.247
#     1epoch:train:161-170batch: iter_time=0.340, forward_time=0.141, loss_ctc=370.690, loss_interctc_layer2=573.930, loss=215.831, backward_time=0.052, grad_norm=4.787e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=5.600e-05, optim0_lr1=2.800e-06, train_time=1.267
#     1epoch:train:171-180batch: iter_time=0.368, forward_time=0.153, loss_ctc=279.377, loss_interctc_layer2=624.747, loss=191.494, backward_time=0.056, grad_norm=3.760e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=5.933e-05, optim0_lr1=2.967e-06, train_time=1.344
#     1epoch:train:181-190batch: iter_time=0.355, forward_time=0.151, loss_ctc=243.444, loss_interctc_layer2=604.522, loss=175.884, backward_time=0.057, grad_norm=2.348e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=6.267e-05, optim0_lr1=3.133e-06, train_time=1.322
#     1epoch:train:191-200batch: iter_time=0.330, forward_time=0.138, loss_ctc=256.488, loss_interctc_layer2=546.694, loss=171.775, backward_time=0.050, grad_norm=3.645e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=6.600e-05, optim0_lr1=3.300e-06, train_time=1.205
#     1epoch:train:201-210batch: iter_time=0.392, forward_time=0.169, loss_ctc=240.854, loss_interctc_layer2=664.787, loss=184.017, backward_time=0.065, grad_norm=5.751e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=6.933e-05, optim0_lr1=3.467e-06, train_time=1.488
#     1epoch:train:211-220batch: iter_time=0.361, forward_time=0.141, loss_ctc=243.012, loss_interctc_layer2=592.528, loss=173.933, backward_time=0.061, grad_norm=3.004e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=7.267e-05, optim0_lr1=3.633e-06, train_time=1.328
#     1epoch:train:221-230batch: iter_time=0.386, forward_time=0.164, loss_ctc=257.869, loss_interctc_layer2=610.447, loss=181.821, backward_time=0.061, grad_norm=1.714e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=7.600e-05, optim0_lr1=3.800e-06, train_time=1.437
#     1epoch:train:231-240batch: iter_time=0.426, forward_time=0.200, loss_ctc=265.389, loss_interctc_layer2=734.760, loss=203.100, backward_time=0.069, grad_norm=3.603e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=7.933e-05, optim0_lr1=3.967e-06, train_time=1.631
#     1epoch:train:241-250batch: iter_time=0.368, forward_time=0.148, loss_ctc=282.074, loss_interctc_layer2=590.010, loss=187.227, backward_time=0.060, grad_norm=2.682e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=8.267e-05, optim0_lr1=4.133e-06, train_time=1.359
#     1epoch:train:251-260batch: iter_time=0.360, forward_time=0.152, loss_ctc=244.188, loss_interctc_layer2=533.002, loss=165.416, backward_time=0.061, grad_norm=1.719e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=8.600e-05, optim0_lr1=4.300e-06, train_time=1.357
#     1epoch:train:261-270batch: iter_time=0.382, forward_time=0.155, loss_ctc=230.782, loss_interctc_layer2=595.174, loss=170.050, backward_time=0.055, grad_norm=2.070e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=8.933e-05, optim0_lr1=4.467e-06, train_time=1.364
#     1epoch:train:271-280batch: iter_time=0.372, forward_time=0.127, loss_ctc=262.990, loss_interctc_layer2=584.752, loss=179.760, backward_time=0.053, grad_norm=2.703e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=9.267e-05, optim0_lr1=4.633e-06, train_time=1.273
#     1epoch:train:281-290batch: iter_time=0.370, forward_time=0.147, loss_ctc=256.384, loss_interctc_layer2=560.171, loss=173.760, backward_time=0.057, grad_norm=3.225e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=9.600e-05, optim0_lr1=4.800e-06, train_time=1.337
#     1epoch:train:291-300batch: iter_time=0.338, forward_time=0.122, loss_ctc=316.567, loss_interctc_layer2=527.039, loss=189.854, backward_time=0.050, grad_norm=4.010e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=9.933e-05, optim0_lr1=4.967e-06, train_time=1.182
#     1epoch:train:301-310batch: iter_time=0.318, forward_time=0.112, loss_ctc=243.660, loss_interctc_layer2=486.826, loss=158.305, backward_time=0.046, grad_norm=2.183e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.027e-04, optim0_lr1=5.133e-06, train_time=1.093
#     1epoch:train:311-320batch: iter_time=0.362, forward_time=0.134, loss_ctc=224.415, loss_interctc_layer2=574.855, loss=164.773, backward_time=0.052, grad_norm=2.660e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.060e-04, optim0_lr1=5.300e-06, train_time=1.268
#     1epoch:train:321-330batch: iter_time=0.345, forward_time=0.128, loss_ctc=228.708, loss_interctc_layer2=527.820, loss=159.221, backward_time=0.053, grad_norm=1.800e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.093e-04, optim0_lr1=5.467e-06, train_time=1.232
#     1epoch:train:331-340batch: iter_time=0.369, forward_time=0.158, loss_ctc=263.367, loss_interctc_layer2=561.738, loss=176.439, backward_time=0.062, grad_norm=2.616e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.127e-04, optim0_lr1=5.633e-06, train_time=1.399
#     1epoch:train:341-350batch: iter_time=0.381, forward_time=0.163, loss_ctc=267.768, loss_interctc_layer2=567.341, loss=178.820, backward_time=0.063, grad_norm=2.515e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.160e-04, optim0_lr1=5.800e-06, train_time=1.431
#     1epoch:train:351-360batch: iter_time=0.383, forward_time=0.147, loss_ctc=254.062, loss_interctc_layer2=575.519, loss=175.249, backward_time=0.055, grad_norm=3.045e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.193e-04, optim0_lr1=5.967e-06, train_time=1.352
#     1epoch:train:361-370batch: iter_time=0.358, forward_time=0.125, loss_ctc=254.551, loss_interctc_layer2=501.841, loss=164.369, backward_time=0.050, grad_norm=2.595e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.227e-04, optim0_lr1=6.133e-06, train_time=1.233
#     1epoch:train:371-380batch: iter_time=0.329, forward_time=0.124, loss_ctc=291.137, loss_interctc_layer2=495.988, loss=176.296, backward_time=0.055, grad_norm=3.639e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.260e-04, optim0_lr1=6.300e-06, train_time=1.193
#     1epoch:train:381-390batch: iter_time=0.346, forward_time=0.164, loss_ctc=238.404, loss_interctc_layer2=502.539, loss=158.822, backward_time=0.056, grad_norm=1.868e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.293e-04, optim0_lr1=6.467e-06, train_time=1.337
#     1epoch:train:391-400batch: iter_time=0.336, forward_time=0.117, loss_ctc=248.846, loss_interctc_layer2=513.550, loss=164.129, backward_time=0.049, grad_norm=2.040e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.327e-04, optim0_lr1=6.633e-06, train_time=1.151
#     1epoch:train:401-410batch: iter_time=0.366, forward_time=0.150, loss_ctc=230.192, loss_interctc_layer2=547.035, loss=162.622, backward_time=0.058, grad_norm=2.398e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.360e-04, optim0_lr1=6.800e-06, train_time=1.355
#     1epoch:train:411-420batch: iter_time=0.348, forward_time=0.137, loss_ctc=256.632, loss_interctc_layer2=520.525, loss=167.900, backward_time=0.047, grad_norm=2.806e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.393e-04, optim0_lr1=6.967e-06, train_time=1.211
#     1epoch:train:421-430batch: iter_time=0.354, forward_time=0.131, loss_ctc=248.980, loss_interctc_layer2=503.975, loss=162.739, backward_time=0.055, grad_norm=3.523e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.427e-04, optim0_lr1=7.133e-06, train_time=1.259
#     1epoch:train:431-440batch: iter_time=0.363, forward_time=0.126, loss_ctc=217.820, loss_interctc_layer2=466.612, loss=146.229, backward_time=0.048, grad_norm=2.925e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.460e-04, optim0_lr1=7.300e-06, train_time=1.240
#     1epoch:train:441-450batch: iter_time=0.370, forward_time=0.154, loss_ctc=274.745, loss_interctc_layer2=496.469, loss=170.631, backward_time=0.059, grad_norm=3.329e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.493e-04, optim0_lr1=7.467e-06, train_time=1.376
#     1epoch:train:451-460batch: iter_time=0.330, forward_time=0.116, loss_ctc=246.402, loss_interctc_layer2=492.631, loss=160.135, backward_time=0.048, grad_norm=3.557e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.527e-04, optim0_lr1=7.633e-06, train_time=1.135
#     1epoch:train:461-470batch: iter_time=0.395, forward_time=0.181, loss_ctc=285.325, loss_interctc_layer2=433.973, loss=164.960, backward_time=0.070, grad_norm=2.205e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.560e-04, optim0_lr1=7.800e-06, train_time=1.551
#     1epoch:train:471-480batch: iter_time=0.382, forward_time=0.151, loss_ctc=254.091, loss_interctc_layer2=442.291, loss=155.275, backward_time=0.063, grad_norm=3.215e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.593e-04, optim0_lr1=7.967e-06, train_time=1.416
#     1epoch:train:481-490batch: iter_time=0.361, forward_time=0.161, loss_ctc=242.794, loss_interctc_layer2=397.997, loss=144.678, backward_time=0.067, grad_norm=2.292e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.627e-04, optim0_lr1=8.133e-06, train_time=1.427
#     1epoch:train:491-500batch: iter_time=0.336, forward_time=0.142, loss_ctc=229.406, loss_interctc_layer2=393.733, loss=139.352, backward_time=0.058, grad_norm=3.126e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.660e-04, optim0_lr1=8.300e-06, train_time=1.257
# /usr/local/lib/python3.12/dist-packages/espnet2/train/trainer.py:856: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(
#     1epoch results: [train] iter_time=0.360, forward_time=0.148, loss_ctc=325.430, loss_interctc_layer2=665.982, loss=213.798, backward_time=0.058, grad_norm=8.433e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=8.500e-05, optim0_lr1=4.250e-06, train_time=1.324, time=5 minutes and 33.79 seconds, total_count=504, gpu_max_cached_mem_GB=21.758, [valid] loss_ctc=288.430, cer_ctc=0.877, loss_interctc_layer2=535.318, cer_interctc_layer2=2.484, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=362.496, time=53.62 seconds, total_count=89, gpu_max_cached_mem_GB=21.758
#     The best model has been updated: valid.cer_ctc
#     2/45epoch started. Estimated time to finish: 4 hours, 46 minutes and 36.17 seconds
#     2epoch:train:1-10batch: iter_time=0.350, forward_time=0.143, loss_ctc=188.036, loss_interctc_layer2=390.467, loss=124.383, backward_time=0.053, grad_norm=1.906e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005optim0_lr0=1.707e-04, optim0_lr1=8.533e-06, train_time=1.273
#     2epoch:train:11-20batch: iter_time=0.410, forward_time=0.190, loss_ctc=302.308, loss_interctc_layer2=447.082, loss=172.870, backward_time=0.061, grad_norm=3.933e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.740e-04, optim0_lr1=8.700e-06, train_time=1.564
#     2epoch:train:21-30batch: iter_time=0.380, forward_time=0.148, loss_ctc=234.964, loss_interctc_layer2=411.646, loss=143.984, backward_time=0.059, grad_norm=2.348e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.773e-04, optim0_lr1=8.867e-06, train_time=1.388
#     2epoch:train:31-40batch: iter_time=0.343, forward_time=0.145, loss_ctc=216.308, loss_interctc_layer2=357.682, loss=129.360, backward_time=0.059, grad_norm=1.616e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.807e-04, optim0_lr1=9.033e-06, train_time=1.306
#     2epoch:train:41-50batch: iter_time=0.345, forward_time=0.132, loss_ctc=215.683, loss_interctc_layer2=347.308, loss=127.585, backward_time=0.055, grad_norm=2.091e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.840e-04, optim0_lr1=9.200e-06, train_time=1.261
#     2epoch:train:51-60batch: iter_time=0.391, forward_time=0.165, loss_ctc=242.768, loss_interctc_layer2=343.638, loss=136.514, backward_time=0.062, grad_norm=3.322e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.873e-04, optim0_lr1=9.367e-06, train_time=1.471
#     2epoch:train:61-70batch: iter_time=0.341, forward_time=0.138, loss_ctc=231.804, loss_interctc_layer2=378.608, loss=137.923, backward_time=0.051, grad_norm=3.058e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.907e-04, optim0_lr1=9.533e-06, train_time=1.229
#     2epoch:train:71-80batch: iter_time=0.363, forward_time=0.138, loss_ctc=152.630, loss_interctc_layer2=365.731, loss=108.280, backward_time=0.058, grad_norm=2.012e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.940e-04, optim0_lr1=9.700e-06, train_time=1.326
#     2epoch:train:81-90batch: iter_time=0.329, forward_time=0.135, loss_ctc=212.927, loss_interctc_layer2=349.869, loss=127.005, backward_time=0.047, grad_norm=3.030e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=1.973e-04, optim0_lr1=9.867e-06, train_time=1.196
#     2epoch:train:91-100batch: iter_time=0.379, forward_time=0.139, loss_ctc=244.794, loss_interctc_layer2=342.464, loss=137.047, backward_time=0.058, grad_norm=2.946e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.007e-04, optim0_lr1=1.003e-05, train_time=1.357
#     2epoch:train:101-110batch: iter_time=0.347, forward_time=0.134, loss_ctc=209.460, loss_interctc_layer2=349.165, loss=125.686, backward_time=0.061, grad_norm=2.362e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.040e-04, optim0_lr1=1.020e-05, train_time=1.304
#     2epoch:train:111-120batch: iter_time=0.369, forward_time=0.152, loss_ctc=216.016, loss_interctc_layer2=421.029, loss=138.760, backward_time=0.054, grad_norm=1.833e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.073e-04, optim0_lr1=1.037e-05, train_time=1.346
#     2epoch:train:121-130batch: iter_time=0.340, forward_time=0.117, loss_ctc=227.542, loss_interctc_layer2=314.726, loss=126.849, backward_time=0.049, grad_norm=3.653e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.107e-04, optim0_lr1=1.053e-05, train_time=1.179
#     2epoch:train:131-140batch: iter_time=0.386, forward_time=0.158, loss_ctc=213.892, loss_interctc_layer2=175.991, loss=101.261, backward_time=0.050, grad_norm=3.487e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.140e-04, optim0_lr1=1.070e-05, train_time=1.384
#     2epoch:train:141-150batch: iter_time=0.358, forward_time=0.145, loss_ctc=201.941, loss_interctc_layer2=135.442, loss=90.996, backward_time=0.056, grad_norm=2.599e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.173e-04, optim0_lr1=1.087e-05, train_time=1.313
#     2epoch:train:151-160batch: iter_time=0.333, forward_time=0.140, loss_ctc=143.918, loss_interctc_layer2=157.471, loss=73.992, backward_time=0.057, grad_norm=1.813e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.207e-04, optim0_lr1=1.103e-05, train_time=1.254
#     2epoch:train:161-170batch: iter_time=0.380, forward_time=0.147, loss_ctc=151.203, loss_interctc_layer2=137.800, loss=73.591, backward_time=0.057, grad_norm=2.151e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.240e-04, optim0_lr1=1.120e-05, train_time=1.371
#     2epoch:train:171-180batch: iter_time=0.383, forward_time=0.189, loss_ctc=199.008, loss_interctc_layer2=143.008, loss=91.104, backward_time=0.066, grad_norm=1.953e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.273e-04, optim0_lr1=1.137e-05, train_time=1.521
#     2epoch:train:181-190batch: iter_time=0.339, forward_time=0.130, loss_ctc=154.199, loss_interctc_layer2=121.306, loss=72.166, backward_time=0.052, grad_norm=1.347e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.307e-04, optim0_lr1=1.153e-05, train_time=1.223
#     2epoch:train:191-200batch: iter_time=0.367, forward_time=0.154, loss_ctc=154.868, loss_interctc_layer2=116.160, loss=71.628, backward_time=0.058, grad_norm=1.050e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.340e-04, optim0_lr1=1.170e-05, train_time=1.357
#     2epoch:train:201-210batch: iter_time=0.384, forward_time=0.161, loss_ctc=186.915, loss_interctc_layer2=117.532, loss=83.050, backward_time=0.062, grad_norm=2.923e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.373e-04, optim0_lr1=1.187e-05, train_time=1.438
#     2epoch:train:211-220batch: iter_time=0.349, forward_time=0.116, loss_ctc=151.868, loss_interctc_layer2=112.010, loss=69.955, backward_time=0.047, grad_norm=1.147e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.407e-04, optim0_lr1=1.203e-05, train_time=1.183
#     2epoch:train:221-230batch: iter_time=0.379, forward_time=0.178, loss_ctc=128.449, loss_interctc_layer2=112.471, loss=61.828, backward_time=0.062, grad_norm=1.001e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.440e-04, optim0_lr1=1.220e-05, train_time=1.458
#     2epoch:train:231-240batch: iter_time=0.394, forward_time=0.163, loss_ctc=133.334, loss_interctc_layer2=114.651, loss=63.865, backward_time=0.061, grad_norm=710.407, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.473e-04, optim0_lr1=1.237e-05, train_time=1.454
#     2epoch:train:241-250batch: iter_time=0.348, forward_time=0.119, loss_ctc=136.945, loss_interctc_layer2=110.209, loss=64.462, backward_time=0.049, grad_norm=1.088e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.507e-04, optim0_lr1=1.253e-05, train_time=1.202
#     2epoch:train:251-260batch: iter_time=0.357, forward_time=0.152, loss_ctc=176.878, loss_interctc_layer2=101.466, loss=77.127, backward_time=0.063, grad_norm=2.551e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.540e-04, optim0_lr1=1.270e-05, train_time=1.375
#     2epoch:train:261-270batch: iter_time=0.345, forward_time=0.134, loss_ctc=144.491, loss_interctc_layer2=97.675, loss=65.223, backward_time=0.051, grad_norm=1.969e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.573e-04, optim0_lr1=1.287e-05, train_time=1.235
#     2epoch:train:271-280batch: iter_time=0.344, forward_time=0.117, loss_ctc=97.445, loss_interctc_layer2=105.232, loss=49.891, backward_time=0.048, grad_norm=1.180e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.607e-04, optim0_lr1=1.303e-05, train_time=1.179
#     2epoch:train:281-290batch: iter_time=0.337, forward_time=0.117, loss_ctc=85.743, loss_interctc_layer2=99.746, loss=44.972, backward_time=0.046, grad_norm=205.009, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.640e-04, optim0_lr1=1.320e-05, train_time=1.146
#     2epoch:train:291-300batch: iter_time=0.345, forward_time=0.125, loss_ctc=80.838, loss_interctc_layer2=94.337, loss=42.444, backward_time=0.044, grad_norm=177.255, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.673e-04, optim0_lr1=1.337e-05, train_time=1.182
#     2epoch:train:301-310batch: iter_time=0.371, forward_time=0.139, loss_ctc=88.285, loss_interctc_layer2=99.739, loss=45.861, backward_time=0.058, grad_norm=290.398, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.707e-04, optim0_lr1=1.353e-05, train_time=1.343
#     2epoch:train:311-320batch: iter_time=0.376, forward_time=0.154, loss_ctc=86.091, loss_interctc_layer2=100.817, loss=45.255, backward_time=0.057, grad_norm=157.726, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.740e-04, optim0_lr1=1.370e-05, train_time=1.393
#     2epoch:train:321-330batch: iter_time=0.363, forward_time=0.153, loss_ctc=86.114, loss_interctc_layer2=99.250, loss=45.027, backward_time=0.067, grad_norm=177.115, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.773e-04, optim0_lr1=1.387e-05, train_time=1.395
#     2epoch:train:331-340batch: iter_time=0.375, forward_time=0.155, loss_ctc=82.940, loss_interctc_layer2=94.722, loss=43.237, backward_time=0.058, grad_norm=144.243, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.807e-04, optim0_lr1=1.403e-05, train_time=1.373
#     2epoch:train:341-350batch: iter_time=0.377, forward_time=0.134, loss_ctc=89.629, loss_interctc_layer2=102.232, loss=46.705, backward_time=0.049, grad_norm=194.526, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.840e-04, optim0_lr1=1.420e-05, train_time=1.278
#     2epoch:train:351-360batch: iter_time=0.351, forward_time=0.130, loss_ctc=84.425, loss_interctc_layer2=94.188, loss=43.677, backward_time=0.054, grad_norm=371.089, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.873e-04, optim0_lr1=1.437e-05, train_time=1.262
#     2epoch:train:361-370batch: iter_time=0.361, forward_time=0.129, loss_ctc=88.791, loss_interctc_layer2=99.315, loss=45.974, backward_time=0.044, grad_norm=215.307, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.907e-04, optim0_lr1=1.453e-05, train_time=1.216
#     2epoch:train:371-380batch: iter_time=0.371, forward_time=0.130, loss_ctc=87.000, loss_interctc_layer2=97.363, loss=45.055, backward_time=0.055, grad_norm=185.938, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.940e-04, optim0_lr1=1.470e-05, train_time=1.307
#     2epoch:train:381-390batch: iter_time=0.350, forward_time=0.137, loss_ctc=84.847, loss_interctc_layer2=97.162, loss=44.271, backward_time=0.054, grad_norm=134.913, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.973e-04, optim0_lr1=1.487e-05, train_time=1.281
#     2epoch:train:391-400batch: iter_time=0.371, forward_time=0.158, loss_ctc=86.491, loss_interctc_layer2=96.465, loss=44.742, backward_time=0.062, grad_norm=123.075, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.007e-04, optim0_lr1=1.503e-05, train_time=1.409
#     2epoch:train:401-410batch: iter_time=0.384, forward_time=0.183, loss_ctc=83.819, loss_interctc_layer2=100.794, loss=44.456, backward_time=0.059, grad_norm=172.035, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.040e-04, optim0_lr1=1.520e-05, train_time=1.494
#     2epoch:train:411-420batch: iter_time=0.348, forward_time=0.127, loss_ctc=81.949, loss_interctc_layer2=90.331, loss=42.232, backward_time=0.052, grad_norm=250.959, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.073e-04, optim0_lr1=1.537e-05, train_time=1.237
#     2epoch:train:421-430batch: iter_time=0.351, forward_time=0.128, loss_ctc=87.051, loss_interctc_layer2=95.535, loss=44.798, backward_time=0.046, grad_norm=141.212, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.107e-04, optim0_lr1=1.553e-05, train_time=1.196
#     2epoch:train:431-440batch: iter_time=0.348, forward_time=0.115, loss_ctc=82.893, loss_interctc_layer2=90.642, loss=42.609, backward_time=0.044, grad_norm=329.021, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.140e-04, optim0_lr1=1.570e-05, train_time=1.161
#     2epoch:train:441-450batch: iter_time=0.370, forward_time=0.143, loss_ctc=90.213, loss_interctc_layer2=98.744, loss=46.386, backward_time=0.059, grad_norm=144.357, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.173e-04, optim0_lr1=1.587e-05, train_time=1.362
#     2epoch:train:451-460batch: iter_time=0.409, forward_time=0.159, loss_ctc=85.826, loss_interctc_layer2=93.700, loss=44.094, backward_time=0.052, grad_norm=163.601, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.207e-04, optim0_lr1=1.603e-05, train_time=1.418
#     2epoch:train:461-470batch: iter_time=0.361, forward_time=0.165, loss_ctc=94.273, loss_interctc_layer2=105.881, loss=48.878, backward_time=0.063, grad_norm=254.198, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.240e-04, optim0_lr1=1.620e-05, train_time=1.395
#     2epoch:train:471-480batch: iter_time=0.350, forward_time=0.123, loss_ctc=82.285, loss_interctc_layer2=90.548, loss=42.382, backward_time=0.049, grad_norm=224.902, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.273e-04, optim0_lr1=1.637e-05, train_time=1.204
#     2epoch:train:481-490batch: iter_time=0.348, forward_time=0.128, loss_ctc=82.465, loss_interctc_layer2=92.046, loss=42.670, backward_time=0.048, grad_norm=152.491, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.307e-04, optim0_lr1=1.653e-05, train_time=1.211
#     2epoch:train:491-500batch: iter_time=0.365, forward_time=0.130, loss_ctc=87.725, loss_interctc_layer2=96.884, loss=45.236, backward_time=0.044, grad_norm=172.117, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.340e-04, optim0_lr1=1.670e-05, train_time=1.216
#     2epoch results: [train] iter_time=0.363, forward_time=0.143, loss_ctc=142.774, loss_interctc_layer2=175.494, loss=76.295, backward_time=0.055, grad_norm=1.301e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=2.530e-04, optim0_lr1=1.265e-05, train_time=1.313, time=5 minutes and 31.03 seconds, total_count=1008, gpu_max_cached_mem_GB=21.758, [valid] loss_ctc=99.556, cer_ctc=0.975, loss_interctc_layer2=112.395, cer_interctc_layer2=0.998, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=103.407, time=54.51 seconds, total_count=178, gpu_max_cached_mem_GB=21.758
#     There are no improvements in this epoch
#     3/45epoch started. Estimated time to finish: 4 hours, 39 minutes and 22.69 seconds
#     3epoch:train:1-10batch: iter_time=0.376, forward_time=0.152, loss_ctc=82.353, loss_interctc_layer2=89.497, loss=42.248, backward_time=0.053, grad_norm=264.085, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005optim0_lr0=3.387e-04, optim0_lr1=1.693e-05, train_time=1.363
#     3epoch:train:11-20batch: iter_time=0.317, forward_time=0.114, loss_ctc=75.886, loss_interctc_layer2=85.018, loss=39.313, backward_time=0.048, grad_norm=202.017, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.420e-04, optim0_lr1=1.710e-05, train_time=1.105
#     3epoch:train:21-30batch: iter_time=0.387, forward_time=0.155, loss_ctc=88.320, loss_interctc_layer2=96.009, loss=45.313, backward_time=0.054, grad_norm=366.762, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.453e-04, optim0_lr1=1.727e-05, train_time=1.380
#     3epoch:train:31-40batch: iter_time=0.352, forward_time=0.131, loss_ctc=86.557, loss_interctc_layer2=92.236, loss=44.130, backward_time=0.046, grad_norm=267.717, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.487e-04, optim0_lr1=1.743e-05, train_time=1.203
#     3epoch:train:41-50batch: iter_time=0.337, forward_time=0.138, loss_ctc=85.748, loss_interctc_layer2=93.358, loss=44.016, backward_time=0.053, grad_norm=299.834, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.520e-04, optim0_lr1=1.760e-05, train_time=1.248
#     3epoch:train:51-60batch: iter_time=0.339, forward_time=0.123, loss_ctc=76.387, loss_interctc_layer2=82.302, loss=39.081, backward_time=0.046, grad_norm=185.036, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.553e-04, optim0_lr1=1.777e-05, train_time=1.169
#     3epoch:train:61-70batch: iter_time=0.376, forward_time=0.150, loss_ctc=84.978, loss_interctc_layer2=92.253, loss=43.580, backward_time=0.057, grad_norm=151.590, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.587e-04, optim0_lr1=1.793e-05, train_time=1.372
#     3epoch:train:71-80batch: iter_time=0.354, forward_time=0.130, loss_ctc=79.799, loss_interctc_layer2=85.815, loss=40.802, backward_time=0.046, grad_norm=196.495, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.620e-04, optim0_lr1=1.810e-05, train_time=1.218
#     3epoch:train:81-90batch: iter_time=0.356, forward_time=0.133, loss_ctc=81.158, loss_interctc_layer2=89.154, loss=41.778, backward_time=0.055, grad_norm=224.652, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.653e-04, optim0_lr1=1.827e-05, train_time=1.289
#     3epoch:train:91-100batch: iter_time=0.355, forward_time=0.168, loss_ctc=93.673, loss_interctc_layer2=100.223, loss=47.819, backward_time=0.062, grad_norm=362.630, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.687e-04, optim0_lr1=1.843e-05, train_time=1.388
#     3epoch:train:101-110batch: iter_time=0.341, forward_time=0.139, loss_ctc=84.816, loss_interctc_layer2=111.028, loss=46.340, backward_time=0.048, grad_norm=222.455, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.720e-04, optim0_lr1=1.860e-05, train_time=1.223
#     3epoch:train:111-120batch: iter_time=0.349, forward_time=0.137, loss_ctc=80.742, loss_interctc_layer2=88.829, loss=41.584, backward_time=0.045, grad_norm=143.641, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.753e-04, optim0_lr1=1.877e-05, train_time=1.236
#     3epoch:train:121-130batch: iter_time=0.340, forward_time=0.125, loss_ctc=81.106, loss_interctc_layer2=89.881, loss=41.869, backward_time=0.047, grad_norm=151.259, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.787e-04, optim0_lr1=1.893e-05, train_time=1.165
#     3epoch:train:131-140batch: iter_time=0.372, forward_time=0.155, loss_ctc=85.542, loss_interctc_layer2=91.432, loss=43.655, backward_time=0.053, grad_norm=241.156, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.820e-04, optim0_lr1=1.910e-05, train_time=1.335
#     3epoch:train:141-150batch: iter_time=0.388, forward_time=0.189, loss_ctc=89.548, loss_interctc_layer2=96.614, loss=45.834, backward_time=0.063, grad_norm=126.771, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.853e-04, optim0_lr1=1.927e-05, train_time=1.516
#     3epoch:train:151-160batch: iter_time=0.372, forward_time=0.145, loss_ctc=82.231, loss_interctc_layer2=93.711, loss=42.837, backward_time=0.053, grad_norm=169.184, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.887e-04, optim0_lr1=1.943e-05, train_time=1.326
#     3epoch:train:161-170batch: iter_time=0.320, forward_time=0.110, loss_ctc=82.110, loss_interctc_layer2=89.381, loss=42.146, backward_time=0.044, grad_norm=157.518, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.920e-04, optim0_lr1=1.960e-05, train_time=1.083
#     3epoch:train:171-180batch: iter_time=0.352, forward_time=0.133, loss_ctc=84.447, loss_interctc_layer2=91.563, loss=43.291, backward_time=0.051, grad_norm=126.122, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.953e-04, optim0_lr1=1.977e-05, train_time=1.243
#     3epoch:train:181-190batch: iter_time=0.389, forward_time=0.164, loss_ctc=83.997, loss_interctc_layer2=90.632, loss=42.994, backward_time=0.060, grad_norm=156.252, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=3.987e-04, optim0_lr1=1.993e-05, train_time=1.438
#     3epoch:train:191-200batch: iter_time=0.343, forward_time=0.121, loss_ctc=82.296, loss_interctc_layer2=86.975, loss=41.850, backward_time=0.049, grad_norm=226.387, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.020e-04, optim0_lr1=2.010e-05, train_time=1.193
#     3epoch:train:201-210batch: iter_time=0.373, forward_time=0.128, loss_ctc=88.633, loss_interctc_layer2=93.487, loss=45.044, backward_time=0.047, grad_norm=286.495, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.053e-04, optim0_lr1=2.027e-05, train_time=1.253
#     3epoch:train:211-220batch: iter_time=0.374, forward_time=0.169, loss_ctc=81.276, loss_interctc_layer2=87.884, loss=41.629, backward_time=0.052, grad_norm=164.131, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.087e-04, optim0_lr1=2.043e-05, train_time=1.395
#     3epoch:train:221-230batch: iter_time=0.339, forward_time=0.114, loss_ctc=82.490, loss_interctc_layer2=87.641, loss=42.018, backward_time=0.044, grad_norm=182.846, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.120e-04, optim0_lr1=2.060e-05, train_time=1.136
#     3epoch:train:231-240batch: iter_time=0.387, forward_time=0.151, loss_ctc=90.507, loss_interctc_layer2=96.950, loss=46.220, backward_time=0.053, grad_norm=276.599, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.153e-04, optim0_lr1=2.077e-05, train_time=1.377
#     3epoch:train:241-250batch: iter_time=0.356, forward_time=0.122, loss_ctc=82.491, loss_interctc_layer2=87.567, loss=42.007, backward_time=0.050, grad_norm=227.056, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.187e-04, optim0_lr1=2.093e-05, train_time=1.234
#     3epoch:train:251-260batch: iter_time=0.361, forward_time=0.143, loss_ctc=82.256, loss_interctc_layer2=88.968, loss=42.135, backward_time=0.054, grad_norm=187.825, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.220e-04, optim0_lr1=2.110e-05, train_time=1.306
#     3epoch:train:261-270batch: iter_time=0.342, forward_time=0.128, loss_ctc=82.194, loss_interctc_layer2=88.835, loss=42.093, backward_time=0.050, grad_norm=187.886, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.253e-04, optim0_lr1=2.127e-05, train_time=1.211
#     3epoch:train:271-280batch: iter_time=0.403, forward_time=0.170, loss_ctc=87.754, loss_interctc_layer2=93.584, loss=44.751, backward_time=0.056, grad_norm=141.195, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.287e-04, optim0_lr1=2.143e-05, train_time=1.451
#     3epoch:train:281-290batch: iter_time=0.377, forward_time=0.156, loss_ctc=85.582, loss_interctc_layer2=91.201, loss=43.634, backward_time=0.055, grad_norm=147.458, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.320e-04, optim0_lr1=2.160e-05, train_time=1.363
#     3epoch:train:291-300batch: iter_time=0.361, forward_time=0.141, loss_ctc=86.471, loss_interctc_layer2=93.570, loss=44.300, backward_time=0.052, grad_norm=212.678, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.353e-04, optim0_lr1=2.177e-05, train_time=1.283
#     3epoch:train:301-310batch: iter_time=0.375, forward_time=0.148, loss_ctc=84.507, loss_interctc_layer2=90.211, loss=43.109, backward_time=0.053, grad_norm=226.880, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.387e-04, optim0_lr1=2.193e-05, train_time=1.340
#     3epoch:train:311-320batch: iter_time=0.387, forward_time=0.161, loss_ctc=82.413, loss_interctc_layer2=87.812, loss=42.016, backward_time=0.049, grad_norm=238.729, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.420e-04, optim0_lr1=2.210e-05, train_time=1.367
#     3epoch:train:321-330batch: iter_time=0.342, forward_time=0.144, loss_ctc=85.469, loss_interctc_layer2=91.521, loss=43.642, backward_time=0.055, grad_norm=137.336, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.453e-04, optim0_lr1=2.227e-05, train_time=1.273
#     3epoch:train:331-340batch: iter_time=0.386, forward_time=0.138, loss_ctc=88.132, loss_interctc_layer2=92.501, loss=44.721, backward_time=0.050, grad_norm=243.122, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.487e-04, optim0_lr1=2.243e-05, train_time=1.314
#     3epoch:train:341-350batch: iter_time=0.371, forward_time=0.145, loss_ctc=88.472, loss_interctc_layer2=94.202, loss=45.095, backward_time=0.054, grad_norm=119.335, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.520e-04, optim0_lr1=2.260e-05, train_time=1.336
#     3epoch:train:351-360batch: iter_time=0.388, forward_time=0.158, loss_ctc=81.475, loss_interctc_layer2=85.533, loss=41.346, backward_time=0.051, grad_norm=237.683, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.553e-04, optim0_lr1=2.277e-05, train_time=1.389
#     3epoch:train:361-370batch: iter_time=0.371, forward_time=0.185, loss_ctc=90.503, loss_interctc_layer2=94.640, loss=45.872, backward_time=0.063, grad_norm=287.659, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.587e-04, optim0_lr1=2.293e-05, train_time=1.458
#     3epoch:train:371-380batch: iter_time=0.370, forward_time=0.138, loss_ctc=84.582, loss_interctc_layer2=88.606, loss=42.894, backward_time=0.055, grad_norm=248.615, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.620e-04, optim0_lr1=2.310e-05, train_time=1.310
#     3epoch:train:381-390batch: iter_time=0.406, forward_time=0.145, loss_ctc=88.579, loss_interctc_layer2=93.546, loss=45.034, backward_time=0.055, grad_norm=142.555, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.653e-04, optim0_lr1=2.327e-05, train_time=1.407
#     3epoch:train:391-400batch: iter_time=0.367, forward_time=0.136, loss_ctc=81.329, loss_interctc_layer2=87.093, loss=41.529, backward_time=0.052, grad_norm=110.078, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.687e-04, optim0_lr1=2.343e-05, train_time=1.295
#     3epoch:train:401-410batch: iter_time=0.383, forward_time=0.161, loss_ctc=87.305, loss_interctc_layer2=92.817, loss=44.479, backward_time=0.055, grad_norm=128.770, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.720e-04, optim0_lr1=2.360e-05, train_time=1.388
#     3epoch:train:411-420batch: iter_time=0.342, forward_time=0.127, loss_ctc=78.069, loss_interctc_layer2=85.306, loss=40.120, backward_time=0.051, grad_norm=138.863, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.753e-04, optim0_lr1=2.377e-05, train_time=1.219
#     3epoch:train:421-430batch: iter_time=0.355, forward_time=0.127, loss_ctc=80.935, loss_interctc_layer2=86.233, loss=41.262, backward_time=0.050, grad_norm=105.924, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.787e-04, optim0_lr1=2.393e-05, train_time=1.235
#     3epoch:train:431-440batch: iter_time=0.373, forward_time=0.149, loss_ctc=82.983, loss_interctc_layer2=87.685, loss=42.197, backward_time=0.061, grad_norm=158.992, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.820e-04, optim0_lr1=2.410e-05, train_time=1.380
#     3epoch:train:441-450batch: iter_time=0.364, forward_time=0.159, loss_ctc=86.123, loss_interctc_layer2=91.838, loss=43.919, backward_time=0.051, grad_norm=104.857, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.853e-04, optim0_lr1=2.427e-05, train_time=1.315
#     3epoch:train:451-460batch: iter_time=0.346, forward_time=0.143, loss_ctc=86.201, loss_interctc_layer2=91.491, loss=43.894, backward_time=0.052, grad_norm=120.446, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.005, optim0_lr0=4.887e-04, optim0_lr1=2.443e-05, train_time=1.284
# ...
#     45epoch:train:11-20batch: iter_time=0.375, forward_time=0.136, loss_ctc=9.748, loss_interctc_layer2=75.594, loss=14.751, backward_time=0.053, grad_norm=73.496, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.677e-04, optim0_lr1=1.838e-05, train_time=1.319
#     45epoch:train:21-30batch: iter_time=0.408, forward_time=0.154, loss_ctc=6.642, loss_interctc_layer2=62.668, loss=11.725, backward_time=0.060, grad_norm=65.493, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.676e-04, optim0_lr1=1.838e-05, train_time=1.463
#     45epoch:train:31-40batch: iter_time=0.354, forward_time=0.118, loss_ctc=5.927, loss_interctc_layer2=59.903, loss=11.060, backward_time=0.051, grad_norm=55.972, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.675e-04, optim0_lr1=1.837e-05, train_time=1.207
#     45epoch:train:41-50batch: iter_time=0.359, forward_time=0.105, loss_ctc=5.028, loss_interctc_layer2=60.514, loss=10.837, backward_time=0.042, grad_norm=67.466, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.674e-04, optim0_lr1=1.837e-05, train_time=1.136
#     45epoch:train:51-60batch: iter_time=0.369, forward_time=0.132, loss_ctc=4.572, loss_interctc_layer2=54.559, loss=9.784, backward_time=0.048, grad_norm=53.460, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.673e-04, optim0_lr1=1.837e-05, train_time=1.255
#     45epoch:train:61-70batch: iter_time=0.422, forward_time=0.161, loss_ctc=6.254, loss_interctc_layer2=74.570, loss=13.374, backward_time=0.058, grad_norm=64.405, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.672e-04, optim0_lr1=1.836e-05, train_time=1.496
#     45epoch:train:71-80batch: iter_time=0.397, forward_time=0.181, loss_ctc=9.085, loss_interctc_layer2=72.994, loss=14.129, backward_time=0.057, grad_norm=69.082, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.672e-04, optim0_lr1=1.836e-05, train_time=1.470
#     45epoch:train:81-90batch: iter_time=0.393, forward_time=0.155, loss_ctc=6.877, loss_interctc_layer2=64.965, loss=12.152, backward_time=0.063, grad_norm=63.499, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.671e-04, optim0_lr1=1.835e-05, train_time=1.445
#     45epoch:train:91-100batch: iter_time=0.389, forward_time=0.141, loss_ctc=6.220, loss_interctc_layer2=67.279, loss=12.269, backward_time=0.057, grad_norm=72.844, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.670e-04, optim0_lr1=1.835e-05, train_time=1.368
#     45epoch:train:101-110batch: iter_time=0.397, forward_time=0.130, loss_ctc=5.397, loss_interctc_layer2=67.475, loss=12.010, backward_time=0.054, grad_norm=63.567, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.669e-04, optim0_lr1=1.835e-05, train_time=1.344
#     45epoch:train:111-120batch: iter_time=0.447, forward_time=0.177, loss_ctc=8.347, loss_interctc_layer2=79.972, loss=14.917, backward_time=0.063, grad_norm=77.194, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.668e-04, optim0_lr1=1.834e-05, train_time=1.599
#     45epoch:train:121-130batch: iter_time=0.374, forward_time=0.137, loss_ctc=6.106, loss_interctc_layer2=63.059, loss=11.596, backward_time=0.060, grad_norm=72.767, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.667e-04, optim0_lr1=1.834e-05, train_time=1.358
#     45epoch:train:131-140batch: iter_time=0.417, forward_time=0.126, loss_ctc=7.749, loss_interctc_layer2=71.854, loss=13.490, backward_time=0.051, grad_norm=70.131, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.667e-04, optim0_lr1=1.833e-05, train_time=1.361
#     45epoch:train:141-150batch: iter_time=0.414, forward_time=0.164, loss_ctc=8.465, loss_interctc_layer2=72.930, loss=13.902, backward_time=0.062, grad_norm=69.032, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.666e-04, optim0_lr1=1.833e-05, train_time=1.512
#     45epoch:train:151-160batch: iter_time=0.404, forward_time=0.136, loss_ctc=8.086, loss_interctc_layer2=70.688, loss=13.433, backward_time=0.049, grad_norm=64.267, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.665e-04, optim0_lr1=1.833e-05, train_time=1.334
#     45epoch:train:161-170batch: iter_time=0.388, forward_time=0.135, loss_ctc=7.346, loss_interctc_layer2=67.855, loss=12.750, backward_time=0.052, grad_norm=60.237, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.664e-04, optim0_lr1=1.832e-05, train_time=1.332
#     45epoch:train:171-180batch: iter_time=0.384, forward_time=0.158, loss_ctc=5.104, loss_interctc_layer2=60.425, loss=10.850, backward_time=0.059, grad_norm=48.888, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.663e-04, optim0_lr1=1.832e-05, train_time=1.397
#     45epoch:train:181-190batch: iter_time=0.349, forward_time=0.110, loss_ctc=7.639, loss_interctc_layer2=67.270, loss=12.764, backward_time=0.043, grad_norm=65.120, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.663e-04, optim0_lr1=1.831e-05, train_time=1.137
#     45epoch:train:191-200batch: iter_time=0.392, forward_time=0.155, loss_ctc=6.799, loss_interctc_layer2=68.482, loss=12.652, backward_time=0.058, grad_norm=61.450, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.662e-04, optim0_lr1=1.831e-05, train_time=1.414
#     45epoch:train:201-210batch: iter_time=0.409, forward_time=0.151, loss_ctc=7.193, loss_interctc_layer2=75.996, loss=13.917, backward_time=0.055, grad_norm=64.163, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.661e-04, optim0_lr1=1.830e-05, train_time=1.423
#     45epoch:train:211-220batch: iter_time=0.378, forward_time=0.129, loss_ctc=6.441, loss_interctc_layer2=68.330, loss=12.504, backward_time=0.049, grad_norm=57.929, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.660e-04, optim0_lr1=1.830e-05, train_time=1.273
#     45epoch:train:221-230batch: iter_time=0.427, forward_time=0.161, loss_ctc=8.006, loss_interctc_layer2=69.748, loss=13.264, backward_time=0.065, grad_norm=66.678, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.659e-04, optim0_lr1=1.830e-05, train_time=1.549
#     45epoch:train:231-240batch: iter_time=0.382, forward_time=0.131, loss_ctc=6.438, loss_interctc_layer2=63.817, loss=11.826, backward_time=0.044, grad_norm=55.850, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.658e-04, optim0_lr1=1.829e-05, train_time=1.252
#     45epoch:train:241-250batch: iter_time=0.371, forward_time=0.125, loss_ctc=7.175, loss_interctc_layer2=62.887, loss=11.944, backward_time=0.049, grad_norm=60.130, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.658e-04, optim0_lr1=1.829e-05, train_time=1.262
#     45epoch:train:251-260batch: iter_time=0.377, forward_time=0.139, loss_ctc=7.828, loss_interctc_layer2=69.514, loss=13.167, backward_time=0.058, grad_norm=72.484, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.657e-04, optim0_lr1=1.828e-05, train_time=1.357
#     45epoch:train:261-270batch: iter_time=0.383, forward_time=0.165, loss_ctc=6.042, loss_interctc_layer2=60.444, loss=11.181, backward_time=0.051, grad_norm=51.546, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.656e-04, optim0_lr1=1.828e-05, train_time=1.398
#     45epoch:train:271-280batch: iter_time=0.375, forward_time=0.142, loss_ctc=7.631, loss_interctc_layer2=65.017, loss=12.423, backward_time=0.061, grad_norm=80.042, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.655e-04, optim0_lr1=1.828e-05, train_time=1.378
#     45epoch:train:281-290batch: iter_time=0.379, forward_time=0.149, loss_ctc=6.014, loss_interctc_layer2=61.046, loss=11.262, backward_time=0.054, grad_norm=55.690, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.654e-04, optim0_lr1=1.827e-05, train_time=1.348
#     45epoch:train:291-300batch: iter_time=0.397, forward_time=0.148, loss_ctc=7.501, loss_interctc_layer2=74.942, loss=13.867, backward_time=0.052, grad_norm=70.869, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.654e-04, optim0_lr1=1.827e-05, train_time=1.369
#     45epoch:train:301-310batch: iter_time=0.377, forward_time=0.145, loss_ctc=7.010, loss_interctc_layer2=63.894, loss=12.038, backward_time=0.052, grad_norm=75.984, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.653e-04, optim0_lr1=1.826e-05, train_time=1.340
#     45epoch:train:311-320batch: iter_time=0.422, forward_time=0.160, loss_ctc=7.062, loss_interctc_layer2=65.536, loss=12.302, backward_time=0.055, grad_norm=71.032, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.652e-04, optim0_lr1=1.826e-05, train_time=1.457
#     45epoch:train:321-330batch: iter_time=0.425, forward_time=0.162, loss_ctc=6.939, loss_interctc_layer2=77.858, loss=14.107, backward_time=0.064, grad_norm=67.808, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.651e-04, optim0_lr1=1.826e-05, train_time=1.529
#     45epoch:train:331-340batch: iter_time=0.372, forward_time=0.114, loss_ctc=6.622, loss_interctc_layer2=65.711, loss=12.174, backward_time=0.048, grad_norm=64.219, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.650e-04, optim0_lr1=1.825e-05, train_time=1.227
#     45epoch:train:341-350batch: iter_time=0.348, forward_time=0.114, loss_ctc=6.138, loss_interctc_layer2=60.327, loss=11.197, backward_time=0.047, grad_norm=51.158, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.650e-04, optim0_lr1=1.825e-05, train_time=1.167
#     45epoch:train:351-360batch: iter_time=0.403, forward_time=0.155, loss_ctc=6.730, loss_interctc_layer2=68.547, loss=12.638, backward_time=0.056, grad_norm=64.782, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.649e-04, optim0_lr1=1.824e-05, train_time=1.423
#     45epoch:train:361-370batch: iter_time=0.389, forward_time=0.132, loss_ctc=6.142, loss_interctc_layer2=55.637, loss=10.495, backward_time=0.047, grad_norm=58.698, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.648e-04, optim0_lr1=1.824e-05, train_time=1.289
#     45epoch:train:371-380batch: iter_time=0.402, forward_time=0.148, loss_ctc=5.873, loss_interctc_layer2=64.009, loss=11.657, backward_time=0.054, grad_norm=66.639, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.647e-04, optim0_lr1=1.824e-05, train_time=1.390
#     45epoch:train:381-390batch: iter_time=0.366, forward_time=0.123, loss_ctc=6.997, loss_interctc_layer2=61.874, loss=11.730, backward_time=0.052, grad_norm=65.957, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.646e-04, optim0_lr1=1.823e-05, train_time=1.262
#     45epoch:train:391-400batch: iter_time=0.394, forward_time=0.131, loss_ctc=7.123, loss_interctc_layer2=65.023, loss=12.247, backward_time=0.052, grad_norm=64.856, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.645e-04, optim0_lr1=1.823e-05, train_time=1.331
#     45epoch:train:401-410batch: iter_time=0.369, forward_time=0.130, loss_ctc=8.081, loss_interctc_layer2=69.858, loss=13.307, backward_time=0.050, grad_norm=64.342, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.645e-04, optim0_lr1=1.822e-05, train_time=1.265
#     45epoch:train:411-420batch: iter_time=0.392, forward_time=0.133, loss_ctc=4.767, loss_interctc_layer2=60.785, loss=10.786, backward_time=0.050, grad_norm=56.284, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.644e-04, optim0_lr1=1.822e-05, train_time=1.315
#     45epoch:train:421-430batch: iter_time=0.381, forward_time=0.110, loss_ctc=7.168, loss_interctc_layer2=72.713, loss=13.416, backward_time=0.047, grad_norm=60.300, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.643e-04, optim0_lr1=1.822e-05, train_time=1.231
#     45epoch:train:431-440batch: iter_time=0.396, forward_time=0.166, loss_ctc=6.764, loss_interctc_layer2=67.126, loss=12.436, backward_time=0.049, grad_norm=66.296, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.642e-04, optim0_lr1=1.821e-05, train_time=1.403
#     45epoch:train:441-450batch: iter_time=0.391, forward_time=0.132, loss_ctc=5.636, loss_interctc_layer2=64.870, loss=11.703, backward_time=0.049, grad_norm=56.877, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.641e-04, optim0_lr1=1.821e-05, train_time=1.300
#     45epoch:train:451-460batch: iter_time=0.431, forward_time=0.176, loss_ctc=7.509, loss_interctc_layer2=70.651, loss=13.226, backward_time=0.067, grad_norm=70.985, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.641e-04, optim0_lr1=1.820e-05, train_time=1.595
#     45epoch:train:461-470batch: iter_time=0.374, forward_time=0.129, loss_ctc=5.392, loss_interctc_layer2=60.999, loss=11.037, backward_time=0.054, grad_norm=56.027, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.640e-04, optim0_lr1=1.820e-05, train_time=1.307
#     45epoch:train:471-480batch: iter_time=0.411, forward_time=0.181, loss_ctc=8.412, loss_interctc_layer2=72.758, loss=13.858, backward_time=0.062, grad_norm=67.601, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.639e-04, optim0_lr1=1.820e-05, train_time=1.534
#     45epoch:train:481-490batch: iter_time=0.415, forward_time=0.164, loss_ctc=8.755, loss_interctc_layer2=73.757, loss=14.128, backward_time=0.059, grad_norm=73.097, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.005, optim0_lr0=3.638e-04, optim0_lr1=1.819e-05, train_time=1.479
#     45epoch:train:491-500batch: iter_time=0.454, forward_time=0.176, loss_ctc=6.755, loss_interctc_layer2=76.316, loss=13.812, backward_time=0.064, grad_norm=68.752, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.637e-04, optim0_lr1=1.819e-05, train_time=1.618
#     45epoch results: [train] iter_time=0.392, forward_time=0.143, loss_ctc=6.840, loss_interctc_layer2=66.817, loss=12.416, backward_time=0.054, grad_norm=64.312, clip=100.000, loss_scale=2.097e+06, optim_step_time=0.006, optim0_lr0=3.657e-04, optim0_lr1=1.829e-05, train_time=1.365, time=5 minutes and 44.02 seconds, total_count=22680, gpu_max_cached_mem_GB=21.777, [valid] loss_ctc=84.220, cer_ctc=0.457, loss_interctc_layer2=85.784, cer_interctc_layer2=0.809, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=84.690, time=58.01 seconds, total_count=4005, gpu_max_cached_mem_GB=21.777
#     There are no improvements in this epoch
#     The training was finished at 45 epochs
# INFO:root:Vocabulary size: 50002
# INFO:root:Gradient checkpoint layers: []
# INFO:root:Gradient checkpoint layers: []
# WARNING:root:Set decoder to none as ctc_weight==1.0
#   evaluando con CTC greedy...
# /usr/local/lib/python3.12/dist-packages/espnet2/s2t/espnet_model.py:338: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(False):
#     [ctc] REF: you can see the code at this point as well
#     [ctc] HYP: you gin stee the god at this pont is wil
#     [ctc] REF: this is like a cruelty joke
#     [ctc] HYP: this is like a rorily tik
#     [ctc] REF: i have not gone back lately
#     [ctc] HYP: i have not goone pick litly
#     por trial: mediana=0.400 p10=0.209 p90=0.550 · 8% por debajo de 0.2
#   [CTC greedy] cer_ctc(micro, comparable con el log)=0.402 · CER texto=0.396 · WER texto=0.675
#   (objetivo char: la cabeza CTC y el decoder usan vocabularios distintos, el beam search hibrido no aplica)
#   hecho en 306.2 min (~8.73 compute units)
#
# ==============================================================================
# BARRIDO COMPLETO en 320 min (~9.1 compute units)
# Resultados en: /content/drive/MyDrive/TFG/resultados/resultados.csv

# %% [markdown]
# ## 13. Resultados y curvas
#
# Tabla comparativa para la memoria y curvas de entrenamiento de cada experimento.

# %%
import matplotlib.pyplot as plt

df = pd.read_csv(CSV_RESULTADOS)
cols = ["nombre", "frontend", "capa_sesion", "norm", "unfreeze_encoder", "lr", "enc_lr_scale",
        "ctc_weight", "n_train", "best_epoch", "best_valid_loss", "best_valid_acc",
        "best_valid_cer_ctc", "cer_ctc_greedy", "wer_ctc_greedy", "cer_beam", "wer_beam",
        "minutos", "compute_units"]
cols = [c for c in cols if c in df.columns]
resumen = df[cols].sort_values("best_valid_loss" if "best_valid_loss" in df else "nombre")
display(resumen)

resumen.to_csv(f"{RESULTS_DIR}/tabla_resumen.csv", index=False)
print("Tabla guardada en", f"{RESULTS_DIR}/tabla_resumen.csv")
print("\nLaTeX para la memoria:\n")
print(resumen.to_latex(index=False, float_format="%.3f"))
# Out:
#          nombre frontend capa_sesion     norm  unfreeze_encoder     lr  \
# 8       overfit   linear       False    trial              True  0.001
# 12  charOverfit   linear       False    trial              True  0.001
# 14  charOverfit   linear       False    trial              True  0.001
# 0        sanity   linear         NaN      NaN              True  0.001
# 3        linear   linear         NaN      NaN              True  0.001
# 9     sinSesion   linear       False    trial              True  0.001
# 10    conSesion   linear        True    trial              True  0.001
# 4        conv1d   conv1d         NaN      NaN              True  0.001
# 11         gen1   linear       False    trial              True  0.001
# 20         deep     deep        True    trial              True  0.001
# 21           v2     deep        True  ninguna              True  0.001
# 19        lrdif   linear        True    trial              True  0.001
# 18          c1d   conv1d        True    trial              True  0.001
# 16      fullCon   linear        True    trial              True  0.001
# 17     fullCon2   linear        True    trial              True  0.001
# 15     charGen1   linear       False    trial              True  0.001
# 1          base   conv2d         NaN      NaN              True  0.001
# 2         lrdif   conv2d         NaN      NaN              True  0.001
# 5        frozen   conv2d         NaN      NaN             False  0.001
# 6         ctc00   conv2d         NaN      NaN              True  0.001
# 7         ctc05   conv2d         NaN      NaN              True  0.001
# 13     charGen1   linear       False    trial              True  0.001
#
#     enc_lr_scale  ctc_weight  n_train  best_epoch  best_valid_loss  \
# 8           1.00         1.0      348       199.0            1.724
# 12          1.00         1.0      348        75.0            3.679
# 14          1.00         1.0      348        50.0           13.976
# 0           1.00         0.3      545        14.0           28.731
# 3           1.00         0.3     2296         5.0           36.759
# 9           0.01         0.3     2296         4.0           36.913
# 10          0.01         0.3     2296         5.0           37.102
# 4           1.00         0.3     2296         1.0           37.523
# 11          1.00         1.0      348         1.0           48.928
# 20          0.05         1.0     8072        56.0           59.108
# 21          0.05         1.0     8072        27.0           73.709
# 19          0.01         1.0     7051        28.0           81.805
# 18          0.01         1.0     7051        11.0           83.916
# 16          1.00         1.0     7051        23.0           84.117
# 17          1.00         1.0     7051        62.0           84.351
# 15          1.00         1.0      348        19.0           87.430
# 1           1.00         0.3     2296         NaN              NaN
# 2           0.01         0.3     2296         NaN              NaN
# 5           1.00         0.3     2296         NaN              NaN
# 6           1.00         0.0     2296         NaN              NaN
# 7           1.00         0.5     2296         NaN              NaN
# 13          1.00         1.0      348         NaN              NaN
#
#     best_valid_acc  best_valid_cer_ctc  cer_ctc_greedy  wer_ctc_greedy  \
# 8              NaN               0.117        0.581225        0.684772
# 12             NaN               0.052        0.450994        0.779190
# 14             NaN               0.231        0.537149        0.886817
# 0            0.605               0.868             NaN             NaN
# 3            0.564               0.924             NaN             NaN
# 9            0.559               0.952        0.986814        0.987778
# 10           0.553               0.989        0.995862        0.997778
# 4            0.558               1.000             NaN             NaN
# 11             NaN               1.000        0.795170        0.969841
# 20             NaN               0.550        0.431454        0.715029
# 21             NaN               0.479        0.395745        0.674820
# 19             NaN               0.870        0.745797        1.108095
# 18             NaN               0.826        0.714165        1.204857
# 16             NaN               0.875        0.721311        1.193896
# 17             NaN               0.882        0.837675        1.000000
# 15             NaN               0.939        0.734234        0.972857
# 1              NaN                 NaN             NaN             NaN
# 2              NaN                 NaN             NaN             NaN
# 5              NaN                 NaN             NaN             NaN
# 6              NaN                 NaN             NaN             NaN
# 7              NaN                 NaN             NaN             NaN
# 13             NaN                 NaN             NaN             NaN
#
#     cer_beam  wer_beam  minutos  compute_units
# 8        NaN       NaN     82.5           2.35
# 12       NaN       NaN     25.7           0.73
# 14       NaN       NaN     17.3           0.49
# 0   0.749266  1.056681     17.3           0.34
# 3   0.795415  1.069532    101.7           2.02
# 9   0.862936  1.397937     59.2           1.69
# 10  0.796121  1.128944     59.4           1.69
# 4   0.842685  1.235167    104.0           2.06
# 11       NaN       NaN     51.0           1.45
# 20       NaN       NaN    584.8          16.67
# 21       NaN       NaN    306.2           8.73
# 19       NaN       NaN    163.8           4.67
# 18       NaN       NaN    168.9           4.81
# 16       NaN       NaN    133.1           3.79
# 17       NaN       NaN    521.0          14.85
# 15       NaN       NaN     34.8           0.99
# 1        NaN       NaN      0.1           0.00
# 2        NaN       NaN      0.1           0.00
# 5        NaN       NaN      0.1           0.00
# 6        NaN       NaN      0.0           0.00
# 7        NaN       NaN      0.1           0.00
# 13       NaN       NaN      0.1           0.00
# Tabla guardada en /content/drive/MyDrive/TFG/resultados/tabla_resumen.csv
#
# LaTeX para la memoria:
#
# \begin{tabular}{llllrrrrrrrrrrrrrrr}
# \toprule
# nombre & frontend & capa_sesion & norm & unfreeze_encoder & lr & enc_lr_scale & ctc_weight & n_train & best_epoch & best_valid_loss & best_valid_acc & best_valid_cer_ctc & cer_ctc_greedy & wer_ctc_greedy & cer_beam & wer_beam & minutos & compute_units \\
# \midrule
# overfit & linear & False & trial & True & 0.001 & 1.000 & 1.000 & 348 & 199.000 & 1.724 & NaN & 0.117 & 0.581 & 0.685 & NaN & NaN & 82.500 & 2.350 \\
# charOverfit & linear & False & trial & True & 0.001 & 1.000 & 1.000 & 348 & 75.000 & 3.679 & NaN & 0.052 & 0.451 & 0.779 & NaN & NaN & 25.700 & 0.730 \\
# charOverfit & linear & False & trial & True & 0.001 & 1.000 & 1.000 & 348 & 50.000 & 13.976 & NaN & 0.231 & 0.537 & 0.887 & NaN & NaN & 17.300 & 0.490 \\
# sanity & linear & NaN & NaN & True & 0.001 & 1.000 & 0.300 & 545 & 14.000 & 28.731 & 0.605 & 0.868 & NaN & NaN & 0.749 & 1.057 & 17.300 & 0.340 \\
# linear & linear & NaN & NaN & True & 0.001 & 1.000 & 0.300 & 2296 & 5.000 & 36.759 & 0.564 & 0.924 & NaN & NaN & 0.795 & 1.070 & 101.700 & 2.020 \\
# sinSesion & linear & False & trial & True & 0.001 & 0.010 & 0.300 & 2296 & 4.000 & 36.913 & 0.559 & 0.952 & 0.987 & 0.988 & 0.863 & 1.398 & 59.200 & 1.690 \\
# conSesion & linear & True & trial & True & 0.001 & 0.010 & 0.300 & 2296 & 5.000 & 37.102 & 0.553 & 0.989 & 0.996 & 0.998 & 0.796 & 1.129 & 59.400 & 1.690 \\
# conv1d & conv1d & NaN & NaN & True & 0.001 & 1.000 & 0.300 & 2296 & 1.000 & 37.523 & 0.558 & 1.000 & NaN & NaN & 0.843 & 1.235 & 104.000 & 2.060 \\
# gen1 & linear & False & trial & True & 0.001 & 1.000 & 1.000 & 348 & 1.000 & 48.928 & NaN & 1.000 & 0.795 & 0.970 & NaN & NaN & 51.000 & 1.450 \\
# deep & deep & True & trial & True & 0.001 & 0.050 & 1.000 & 8072 & 56.000 & 59.108 & NaN & 0.550 & 0.431 & 0.715 & NaN & NaN & 584.800 & 16.670 \\
# v2 & deep & True & ninguna & True & 0.001 & 0.050 & 1.000 & 8072 & 27.000 & 73.709 & NaN & 0.479 & 0.396 & 0.675 & NaN & NaN & 306.200 & 8.730 \\
# lrdif & linear & True & trial & True & 0.001 & 0.010 & 1.000 & 7051 & 28.000 & 81.805 & NaN & 0.870 & 0.746 & 1.108 & NaN & NaN & 163.800 & 4.670 \\
# c1d & conv1d & True & trial & True & 0.001 & 0.010 & 1.000 & 7051 & 11.000 & 83.916 & NaN & 0.826 & 0.714 & 1.205 & NaN & NaN & 168.900 & 4.810 \\
# fullCon & linear & True & trial & True & 0.001 & 1.000 & 1.000 & 7051 & 23.000 & 84.117 & NaN & 0.875 & 0.721 & 1.194 & NaN & NaN & 133.100 & 3.790 \\
# fullCon2 & linear & True & trial & True & 0.001 & 1.000 & 1.000 & 7051 & 62.000 & 84.351 & NaN & 0.882 & 0.838 & 1.000 & NaN & NaN & 521.000 & 14.850 \\
# charGen1 & linear & False & trial & True & 0.001 & 1.000 & 1.000 & 348 & 19.000 & 87.430 & NaN & 0.939 & 0.734 & 0.973 & NaN & NaN & 34.800 & 0.990 \\
# base & conv2d & NaN & NaN & True & 0.001 & 1.000 & 0.300 & 2296 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & 0.100 & 0.000 \\
# lrdif & conv2d & NaN & NaN & True & 0.001 & 0.010 & 0.300 & 2296 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & 0.100 & 0.000 \\
# frozen & conv2d & NaN & NaN & False & 0.001 & 1.000 & 0.300 & 2296 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & 0.100 & 0.000 \\
# ctc00 & conv2d & NaN & NaN & True & 0.001 & 1.000 & 0.000 & 2296 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & 0.000 & 0.000 \\
# ctc05 & conv2d & NaN & NaN & True & 0.001 & 1.000 & 0.500 & 2296 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & 0.100 & 0.000 \\
# charGen1 & linear & False & trial & True & 0.001 & 1.000 & 1.000 & 348 & NaN & NaN & NaN & NaN & NaN & NaN & NaN & NaN & 0.100 & 0.000 \\
# \bottomrule
# \end{tabular}

# %%
# Curvas de todos los experimentos con epocas.csv
fig, axes = plt.subplots(1, 3, figsize=(16, 4.2))
for tag in df["exp_tag"]:
    p = f"{RESULTS_DIR}/{tag}/epocas.csv"
    if not os.path.exists(p):
        continue
    e = pd.read_csv(p)
    etiqueta = tag.split("_")[0]
    if "train_loss" in e: axes[0].plot(e["epoch"], e["train_loss"], label=etiqueta)
    if "valid_loss" in e: axes[1].plot(e["epoch"], e["valid_loss"], label=etiqueta)
    if "valid_cer"  in e: axes[2].plot(e["epoch"], e["valid_cer"],  label=etiqueta)

for ax, t in zip(axes, ["Loss (train)", "Loss (valid)", "CER (valid)"]):
    ax.set_title(t); ax.set_xlabel("epoca"); ax.grid(alpha=0.3)
axes[0].legend(fontsize=8)
plt.tight_layout()
plt.savefig(f"{RESULTS_DIR}/curvas.png", dpi=150, bbox_inches="tight")
plt.show()
print("Figura guardada en", f"{RESULTS_DIR}/curvas.png")
# Out:
# Figura guardada en /content/drive/MyDrive/TFG/resultados/curvas.png

# %% [markdown]
# ---
#
# ## Cómo leer `gen1`
#
# Es el mismo experimento que el `overfit` (que llegó a `cer_ctc` = 0.117) con **una sola** variable cambiada: la validación es ahora un split real en vez de `val = train`.
#
# | `min_valid_cer_ctc` | Lectura | Siguiente paso |
# |---|---|---|
# | < 0.5 | Generaliza dentro de un día. El cuello de botella es multi-sesión. | Rama A: la ablación de la capa por sesión, ya sobre algo que aprende. |
# | 0.7 – 0.9 | Generaliza un poco. Falta señal o faltan datos. | Rama B: las 45 sesiones. |
# | ≈ 0.9 y `pendiente_cer_ctc` ≈ 0 | No generaliza ni con un día, sin deriva ni confusión entre sesiones. | Rama B + cambiar la cabeza CTC (ver abajo). |
#
# Mira siempre `pendiente_cer_ctc` (ajuste lineal sobre las últimas 10 épocas). En `sinSesion` valía −0.0008/época — plano. En el `overfit` a la misma altura valía −0.014/época — despegando. Es lo que distingue "va lento" de "está atascado".
#
# ## El problema de las 50.002 clases
#
# Si `gen1` sale plano, este es el cambio estructural que toca. Los pipelines de referencia de B2T'25 no predicen BPE: su capa final tiene **41 clases** (39 fonemas + blank + espacio), y las palabras salen después con un n-grama o un LLM. Tú le estás pidiendo a la cabeza CTC que aprenda un mapeo neuronal → 50.002 tokens con 2.296 frases.
#
# Dos versiones, de menos a más trabajo:
#
# 1. **Caracteres (~30 clases).** No hace falta ninguna dependencia nueva: tokenizas `text_ctc` letra a letra y sustituyes `model.ctc.ctc_lo` por un `nn.Linear(384, 30)`. Captura casi toda la reducción de clases.
# 2. **Fonemas (41 clases).** Lo que hace la literatura, con `g2p_en`. Comparable con los números publicados del benchmark, que es lo que quieres para la memoria.
#
# En los dos casos `cer_ctc` deja de ser comparable con las tablas anteriores (pasa a ser CER de caracteres o PER), así que conviene documentarlo como una fase aparte.
#
# ## Ajustes de rendimiento
#
# - Si la GPU va a menos del 70 % (mira `!nvidia-smi` desde el Terminal), sube `batch_size` o pasa a `batch_type="numel"` con `batch_bins` (agrupa por número de elementos, mucho mejor con longitudes de 138 a 1966 frames).
# - `num_workers=0` es lo seguro con HDF5. Súbelo solo si ves la GPU esperando.
# - El reintento automático por OOM baja el batch a la mitad y luego a un cuarto antes de rendirse, así que un experimento mal dimensionado ya no tumba el barrido entero.
