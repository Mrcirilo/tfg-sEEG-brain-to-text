# %% [markdown]
# # Adaptación de OWSM v3.1 a señales neuronales intracorticales
#
# **Kiril · TFG · Brain-to-Text 2025**
#
# Este notebook parte del que me pasasteis en la primera reunión
# (`ASR_finetune_owsm.ipynb`, de Masao Someki) y lo lleva hasta nuestro problema:
# en vez de audio, la entrada son 512 características neuronales por ventana
# temporal, grabadas con cuatro arrays de Utah implantados en el cortex motor
# del participante T15.
#
# Sigue la misma estructura que el notebook original, para que se vea qué cambia
# y qué no. Las secciones **3**, **4** y **10** son las que he añadido:
#
# | Sección | Qué es |
# |---|---|
# | 1–2 | Configuración y datos |
# | **3** | **Qué espera ESPnet y qué tenemos nosotros** |
# | **4** | **La adaptación: los cuatro cambios sobre el modelo** |
# | 5–7 | Dataset, configuración y entrenamiento (ESPnet-EZ sin tocar) |
# | 8–9 | Métricas e inferencia |
# | **10** | **Por qué el vocabulario de subpalabras de OWSM no puede funcionar aquí** |
#
# Las piezas de ESPnet que hubo que modificar están en `espnet_eeg.py`, en un
# fichero aparte y documentadas una a una, para no ensuciar el notebook con
# código de librería.
#
# > **Objetivo de este notebook.** No es obtener un buen resultado: es dejar
# > establecido que la adaptación está hecha correctamente y que el fracaso con
# > el vocabulario de palabras es *estructural*, no un error de programación.
# > La sección 10 lo demuestra con el mismo código y una sola variable cambiada.

# %% [markdown]
# ## 0. Instalación
#
# Ejecutar una sola vez al principio de la sesión.

# %%
# !pip install -q "espnet==202511" espnet_model_zoo editdistance h5py

import espnet2, torch
print("ESPnet :", espnet2.__version__)
print("PyTorch:", torch.__version__)
print("GPU    :", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "NO HAY GPU")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 117.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 29.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 kB 22.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 88.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 86.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 109.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.1/163.1 kB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 64.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 64.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 25.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 130.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 62.7 MB/s eta 0:00:00
#   Building wheel for fast-bss-eval (setup.py) ... done
#   Building wheel for sentencepiece (setup.py) ... done
#   Building wheel for pyworld (pyproject.toml) ... done
#   Building wheel for ci_sdr (setup.py) ... done
#   Building wheel for distance (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# ESPnet : 202511
# PyTorch: 2.11.0+cu128
# GPU    : NVIDIA L4

# %% [markdown]
# ## 1. Configuración
#
# Todo lo configurable está aquí. Lo único importante es `MODO`:
#
# - `"palabras"` — el experimento real. Varias sesiones, partición de validación
#   de verdad, objetivo CTC sobre el vocabulario de subpalabras de OWSM.
# - `"overfit"` — el control. Una sola sesión y `validación = entrenamiento`.
#   Si el código estuviera mal, el modelo no podría ni memorizar. Se usa en la
#   sección 10.

# %%
from google.colab import drive; drive.mount("/content/drive")
import sys
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# Carpeta de Drive donde está espnet_eeg.py
CODIGO = "/content/drive/MyDrive/TFG"

if not os.path.exists(f"{CODIGO}/espnet_eeg.py"):
    raise FileNotFoundError(
        f"No encuentro espnet_eeg.py en {CODIGO}\n"
        f"Contenido de esa carpeta: {sorted(os.listdir(CODIGO))}")

if CODIGO not in sys.path:
    sys.path.insert(0, CODIGO)

import espnet_eeg as eeg

import re, glob, json, argparse, logging, string
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt

import espnetez as ez
from espnet2.bin.s2t_inference import Speech2Text
from espnet2.tasks.s2t import S2TTask

# ── MODO ──────────────────────────────────────────────────────────────
MODO = "palabras"          # "palabras" | "overfit"

CONF = {
    "palabras": dict(n_sesiones=45, max_epoch=20, warmup=200, val_igual_train=False),
    "overfit":  dict(n_sesiones=1,  max_epoch=40, warmup=20,  val_igual_train=True),
}[MODO]

DATA_ROOT = "/content/drive/MyDrive/TFG/DatosEEG_crudos/hdf5_data_final"


# ── Modelo ────────────────────────────────────────────────────────────
MODELO   = "espnet/owsm_v3.1_ebf_base"   # ~101 M parámetros
IDIOMA   = "eng"
FRONTEND = "conv2d"        # "conv2d" (la clase de ESPnet con idim=512) | "lineal"

# ── Entrenamiento ─────────────────────────────────────────────────────
BATCH_SIZE  = 16
LR          = 1e-3
GRAD_CLIP   = 5.0
NUM_WORKERS = 2
CTC_WEIGHT  = 1.0          # 1.0 = solo CTC, el decodificador no entra en la pérdida

EXP_DIR   = f"/content/exp/{MODO}"
STATS_DIR = f"/content/exp/stats_{MODO}"
LOG_PATH  = f"{EXP_DIR}/train.log"
os.makedirs(EXP_DIR, exist_ok=True); os.makedirs(STATS_DIR, exist_ok=True)

print(f"MODO         : {MODO}")
print(f"Sesiones     : {CONF['n_sesiones']}   ·   val = train: {CONF['val_igual_train']}")
print(f"Épocas       : {CONF['max_epoch']}   ·   warmup: {CONF['warmup']}")
print(f"Frontend     : {FRONTEND}   ·   ctc_weight: {CTC_WEIGHT}")
# Out:
# Mounted at /content/drive
# Failed to import Flash Attention, using ESPnet default: No module named 'flash_attn'
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# /usr/local/lib/python3.13/dist-packages/espnet2/enh/encoder/stft_encoder.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /usr/local/lib/python3.13/dist-packages/espnet2/enh/layers/uses2_swin.py:329: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# MODO         : palabras
# Sesiones     : 45   ·   val = train: False
# Épocas       : 20   ·   warmup: 200
# Frontend     : conv2d   ·   ctc_weight: 1.0

# %% [markdown]
# ## 2. Los datos
#
# Cada *trial* es un intento de pronunciar una frase. La señal son 512
# características por ventana de 20 ms: potencia de banda y tasa de cruces por
# umbral de los 256 electrodos.

# %%
sesiones = sorted(os.listdir(DATA_ROOT))[:CONF["n_sesiones"]]
print(f"{len(os.listdir(DATA_ROOT))} sesiones disponibles, uso {len(sesiones)}\n")

train_trials = eeg.cargar_split(DATA_ROOT, sesiones, "train")
val_trials   = (train_trials if CONF["val_igual_train"]
                else eeg.cargar_split(DATA_ROOT, sesiones, "val"))

longitudes = np.array([t["input_features"].shape[0] for t in train_trials])
print(f"\nTrain: {len(train_trials)} trials   ·   Val: {len(val_trials)} trials")
print(f"Duración (frames): min {longitudes.min()}  max {longitudes.max()}  "
      f"media {longitudes.mean():.0f}")
print(f"\nEjemplo — shape {train_trials[0]['input_features'].shape}  "
      f"({longitudes[0]*0.02:.1f} s a 50 Hz)")
print(f"          texto '{train_trials[0]['text_raw']}'")
# Out:
# 45 sesiones disponibles, uso 45
#
#   t15.2023.08.11/train:  288 trials
#   t15.2023.08.13/train:  348 trials
#   t15.2023.08.18/train:  197 trials
#   t15.2023.08.20/train:  278 trials
#   t15.2023.08.25/train:   88 trials
#   t15.2023.08.27/train:  150 trials
#   t15.2023.09.01/train:  297 trials
#   t15.2023.09.03/train:  322 trials
#   t15.2023.09.24/train:  245 trials
#   t15.2023.09.29/train:  153 trials
#   t15.2023.10.01/train:  218 trials
#   t15.2023.10.06/train:  174 trials
#   t15.2023.10.08/train:  284 trials
#   t15.2023.10.13/train:  155 trials
#   t15.2023.10.15/train:  239 trials
#   t15.2023.10.20/train:   98 trials
#   t15.2023.10.22/train:  134 trials
#   t15.2023.11.03/train:  149 trials
#   t15.2023.11.04/train:   80 trials
#   t15.2023.11.17/train:  100 trials
#   t15.2023.11.19/train:   60 trials
#   t15.2023.11.26/train:  198 trials
#   t15.2023.12.03/train:  228 trials
#   t15.2023.12.08/train:  198 trials
#   t15.2023.12.10/train:  131 trials
#   t15.2023.12.17/train:  135 trials
#   t15.2023.12.29/train:  198 trials
#   t15.2024.02.25/train:  193 trials
#   t15.2024.03.03/train:  219 trials
#   t15.2024.03.08/train:  163 trials
#   t15.2024.03.15/train:  239 trials
#   t15.2024.03.17/train:  246 trials
#   t15.2024.04.25/train:  364 trials
#   t15.2024.04.28/train:  150 trials
#   t15.2024.05.10/train:  110 trials
#   t15.2024.06.14/train:   90 trials
#   t15.2024.07.19/train:  169 trials
#   t15.2024.07.21/train:  160 trials
#   t15.2024.07.28/train:  161 trials
#   t15.2025.01.10/train:  106 trials
#   t15.2025.01.12/train:  163 trials
#   t15.2025.03.14/train:   59 trials
#   t15.2025.03.16/train:  101 trials
#   t15.2025.03.30/train:  165 trials
#   t15.2025.04.13/train:   69 trials
#   [aviso] no existe t15.2023.08.11/data_val.hdf5, se salta
#   t15.2023.08.13/val:   35 trials
#   t15.2023.08.18/val:   49 trials
#   t15.2023.08.20/val:   48 trials
#   t15.2023.08.25/val:   25 trials
#   t15.2023.08.27/val:   25 trials
#   t15.2023.09.01/val:   49 trials
#   t15.2023.09.03/val:   34 trials
#   t15.2023.09.24/val:   35 trials
#   t15.2023.09.29/val:   48 trials
#   t15.2023.10.01/val:   44 trials
#   t15.2023.10.06/val:   36 trials
#   t15.2023.10.08/val:   17 trials
#   t15.2023.10.13/val:   44 trials
#   t15.2023.10.15/val:   44 trials
#   t15.2023.10.20/val:    9 trials
#   t15.2023.10.22/val:   33 trials
#   t15.2023.11.03/val:   50 trials
#   t15.2023.11.04/val:   15 trials
#   t15.2023.11.17/val:   25 trials
#   t15.2023.11.19/val:   20 trials
#   t15.2023.11.26/val:   44 trials
#   t15.2023.12.03/val:   34 trials
#   t15.2023.12.08/val:   50 trials
#   t15.2023.12.10/val:   25 trials
#   t15.2023.12.17/val:   30 trials
#   t15.2023.12.29/val:   50 trials
#   t15.2024.02.25/val:   23 trials
#   [aviso] no existe t15.2024.03.03/data_val.hdf5, se salta
#   t15.2024.03.08/val:   24 trials
#   t15.2024.03.15/val:   48 trials
#   t15.2024.03.17/val:   48 trials
#   [aviso] no existe t15.2024.04.25/data_val.hdf5, se salta
#   [aviso] no existe t15.2024.04.28/data_val.hdf5, se salta
#   t15.2024.05.10/val:   25 trials
#   t15.2024.06.14/val:   25 trials
#   t15.2024.07.19/val:   48 trials
#   t15.2024.07.21/val:   46 trials
#   t15.2024.07.28/val:   48 trials
#   t15.2025.01.10/val:   23 trials
#   t15.2025.01.12/val:   47 trials
#   t15.2025.03.14/val:   24 trials
#   t15.2025.03.16/val:   24 trials
#   t15.2025.03.30/val:   30 trials
#   t15.2025.04.13/val:   25 trials
#
# Train: 8072 trials   ·   Val: 1426 trials
# Duración (frames): min 138  max 2475  media 875
#
# Ejemplo — shape (321, 512)  (6.4 s a 50 Hz)
#           texto 'Bring it closer.'

# %%
fig, ax = plt.subplots(1, 2, figsize=(13, 3.5))

ax[0].hist(longitudes * 0.02, bins=40, color="steelblue", edgecolor="white")
ax[0].set_xlabel("duración del trial (s)"); ax[0].set_ylabel("nº de trials")
ax[0].set_title("Distribución de duraciones")

señal = eeg.znorm(train_trials[0]["input_features"])
im = ax[1].imshow(señal.T, aspect="auto", origin="lower", cmap="RdBu_r",
                  vmin=-3, vmax=3, interpolation="nearest")
ax[1].set_xlabel("frame (20 ms)"); ax[1].set_ylabel("canal (0–511)")
ax[1].set_title(f"Trial 0 tras z-score  ·  '{train_trials[0]['text_raw'][:40]}'")
fig.colorbar(im, ax=ax[1])
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3. Qué espera ESPnet y qué tenemos nosotros
#
# Aquí está el problema de fondo, y conviene verlo antes de tocar nada.
#
# Un modelo de la tarea `s2t` de ESPnet recibe una **forma de onda de una sola
# dimensión** a 16 kHz. Su `frontend` la convierte en un banco de filtros mel de
# 80 dimensiones, y el `encoder.embed` proyecta esas 80 a las 384 del encoder.
#
# Nosotros no tenemos forma de onda. Tenemos una matriz de 512 columnas ya
# extraída. Vamos a comprobar exactamente qué dimensiones espera el modelo
# haciendo pasar un segundo de audio sintético por su frontend.

# %%
pretrained = Speech2Text.from_pretrained(MODELO, lang_sym=f"<{IDIOMA}>", beam_size=5)
pretrain_config = vars(pretrained.s2t_train_args)
tokenizer = pretrained.tokenizer
converter = pretrained.converter
modelo_original = pretrained.s2t_model
modelo_original.eval()

# ── Qué le entra al encoder cuando la entrada es audio ────────────────
with torch.no_grad():
    onda = torch.randn(1, 16000)                       # 1 segundo a 16 kHz
    feats, _ = modelo_original.frontend(onda, torch.tensor([16000]))

print("PIPELINE ORIGINAL DE OWSM")
print("-" * 62)
print(f"  entrada           : forma de onda {tuple(onda.shape)}  (16 kHz, 1-D)")
print(f"  frontend          : {type(modelo_original.frontend).__name__}")
print(f"      -> produce    : {tuple(feats.shape)}   (batch, frames, mel)")
print(f"  specaug           : {type(modelo_original.specaug).__name__}")
print(f"  normalize         : {type(modelo_original.normalize).__name__}")
print(f"  encoder.embed     : {type(modelo_original.encoder.embed).__name__}")
print(f"      -> Linear     : {modelo_original.encoder.embed.out[0]}")
print(f"  encoder d_model   : {modelo_original.encoder.output_size()}")

print()
print("LO QUE TENEMOS NOSOTROS")
print("-" * 62)
print(f"  entrada           : matriz {train_trials[0]['input_features'].shape}  "
      f"(50 Hz, 2-D)")
print(f"  frontend          : ninguno, las características ya están extraídas")
print(f"  dimensión de rasgo: 512  (frente a las {feats.shape[-1]} que espera el embed)")
# Out:
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 29 files:   0%|          | 0/29 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# PIPELINE ORIGINAL DE OWSM
# --------------------------------------------------------------
#   entrada           : forma de onda (1, 16000)  (16 kHz, 1-D)
#   frontend          : DefaultFrontend
#       -> produce    : (1, 101, 80)   (batch, frames, mel)
#   specaug           : SpecAug
#   normalize         : GlobalMVN
#   encoder.embed     : Conv2dSubsampling
#       -> Linear     : Linear(in_features=7296, out_features=384, bias=True)
#   encoder d_model   : 384
#
# LO QUE TENEMOS NOSOTROS
# --------------------------------------------------------------
#   entrada           : matriz (321, 512)  (50 Hz, 2-D)
#   frontend          : ninguno, las características ya están extraídas
#   dimensión de rasgo: 512  (frente a las 80 que espera el embed)

# %% [markdown]
# El `Conv2dSubsampling` de ESPnet construye su capa de salida como
# `Linear(odim · ((idim−1)//2 − 1)//2, odim)`. Con `idim=80` son 7.296 entradas.
# Con `idim=512` son 48.768. Es decir: **el frontend pasa de 2,8 M a 18,7 M de
# parámetros** sólo por cambiar la dimensión de entrada, y esos 18,7 M se
# inicializan de cero porque no existen pesos preentrenados para ellos.
#
# Este número ya anticipa parte del problema, y lo retomo en la sección 10.

# %% [markdown]
# ## 4. La adaptación
#
# Cuatro cambios sobre el modelo, todos en `espnet_eeg.adaptar_a_seeg()`:
#
# | # | Componente | ESPnet | Adaptado | Por qué |
# |---|---|---|---|---|
# | 1 | `model.frontend` | `DefaultFrontend` (STFT → mel) | `None` | Con `frontend=None`, `_extract_feats()` devuelve la entrada tal cual. No hay onda que analizar. |
# | 2 | `model.specaug` | `SpecAug` | `None` | Enmascarar «frecuencias» no tiene sentido: el eje son electrodos, no un espectro ordenado. |
# | 3 | `model.normalize` | `GlobalMVN` | `None` | Se sustituye por z-score por trial: la ganancia de los electrodos deriva entre sesiones. |
# | 4 | `encoder.embed` | `Conv2dSubsampling(80, 384)` | `Conv2dSubsampling(512, 384)` | Única capa cuya entrada depende de la modalidad. |
#
# El resto del modelo —los seis bloques E-Branchformer, la cabeza CTC, el
# decodificador— se queda exactamente como está.
#
# > **Detalle que costó tiempo:** si el frontend nuevo no hereda de
# > `Conv2dSubsampling`, el encoder lo llama **sin la máscara de relleno**
# > (`e_branchformer_encoder.py:483` decide con un `isinstance`) y falla con
# > `TypeError: forward() missing 1 required positional argument: 'x_mask'`.
# > Está comentado en `espnet_eeg.py`.

# %%
def build_model_fn(args):
    # ── El ctc_weight hay que inyectarlo en model_conf, no sólo arriba ──
    # Si se construye desde pretrain_config a secas, el modelo se queda con el
    # 0.3 de OWSM diga lo que diga la configuración, y en el log aparece
    # "0.3*loss_ctc + 0.7*loss_att = loss". Costó un experimento entero darse
    # cuenta de que el panel no estaba haciendo nada.
    conf = dict(pretrain_config)
    conf["model_conf"] = {**conf.get("model_conf", {}), "ctc_weight": CTC_WEIGHT}

    model = S2TTask.build_model(argparse.Namespace(**conf))
    model.load_state_dict(modelo_original.state_dict(), strict=False)

    # ── LOS CUATRO CAMBIOS ──────────────────────────────────────────────
    eeg.adaptar_a_seeg(model, idim=512, frontend=FRONTEND, verbose=False)

    model.train()
    total, entrenables = eeg.contar_parametros(model)
    print(f"Parámetros totales     : {total:,}")
    print(f"Parámetros entrenables : {entrenables:,} ({entrenables/total*100:.1f} %)")
    return model


print("build_model_fn definido")
# Out:
# build_model_fn definido

# %% [markdown]
# Comprobación de que funciona. Construimos el modelo **sin adaptar**, le
# aplicamos los cuatro cambios mostrando el antes y el después, y le hacemos
# pasar un trial real de principio a fin.

# %%
_dev = "cuda" if torch.cuda.is_available() else "cpu"

_conf = dict(pretrain_config)
_conf["model_conf"] = {**_conf.get("model_conf", {}), "ctc_weight": CTC_WEIGHT}
_m = S2TTask.build_model(argparse.Namespace(**_conf))      # todavía es de audio

eeg.adaptar_a_seeg(_m, idim=512, frontend=FRONTEND, verbose=True)

_total, _ = eeg.contar_parametros(_m)
print(f"\nParámetros del modelo adaptado: {_total:,}")

with torch.no_grad():
    _m.eval().to(_dev)
    x = torch.as_tensor(eeg.znorm(train_trials[0]["input_features"])).unsqueeze(0).to(_dev)
    enc, _ = _m.encode(x, torch.tensor([x.size(1)], device=_dev))
    if isinstance(enc, tuple): enc = enc[0]
    logits = _m.ctc.log_softmax(enc)

print(f"\n  señal        {tuple(x.shape)}     (batch, frames, canales)")
print(f"  -> encoder   {tuple(enc.shape)}     (batch, frames/4, d_model)")
print(f"  -> cabeza CTC{tuple(logits.shape)}  (batch, frames/4, vocabulario)")
print("\nEl modelo procesa señal neuronal de extremo a extremo.")

del _m
torch.cuda.empty_cache() if torch.cuda.is_available() else None
# Out:
# WARNING:root:Set decoder to none as ctc_weight==1.0
# componente    ESPnet original           adaptado
# ------------------------------------------------------------------
# frontend      DefaultFrontend           NoneType
# specaug       SpecAug                   NoneType
# normalize     GlobalMVN                 NoneType
# embed_in      7296                      48768
#
# Parámetros del modelo adaptado: 64,456,018
# /usr/local/lib/python3.13/dist-packages/espnet2/s2t/espnet_model.py:338: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(False):
#   señal        (1, 321, 512)     (batch, frames, canales)
#   -> encoder   (1, 79, 384)     (batch, frames/4, d_model)
#   -> cabeza CTC(1, 79, 50002)  (batch, frames/4, vocabulario)
#
# El modelo procesa señal neuronal de extremo a extremo.

# %% [markdown]
# ## 5. Dataset y `data_info`
#
# Igual que en el notebook original: el dataset devuelve un diccionario y
# `data_info` dice cómo convertir cada campo a `np.array`. El único cambio es que
# `speech` no carga un `.wav` con librosa, sino que devuelve la matriz ya
# normalizada.

# %%
train_raw = eeg.SeeGDataset(train_trials, idioma=IDIOMA)
valid_raw = eeg.SeeGDataset(val_trials,   idioma=IDIOMA)

def tokenize(texto):
    return np.array(converter.tokens2ids(tokenizer.text2tokens(texto)))

data_info = {
    "speech":    lambda d: eeg.znorm(d["input_features"]),   # <-- antes: librosa.load(...)
    "text":      lambda d: tokenize(d["text"]),
    "text_prev": lambda d: tokenize(d["text_prev"]),
    "text_ctc":  lambda d: tokenize(d["text_ctc"]),
}

train_dataset = ez.dataset.ESPnetEZDataset(train_raw, data_info=data_info)
valid_dataset = ez.dataset.ESPnetEZDataset(valid_raw, data_info=data_info)

it = train_raw[0]
print("text     :", it["text"])
print("text_ctc :", it["text_ctc"])
print("speech   :", data_info["speech"](it).shape)
print("tokens   :", tokenize(it["text_ctc"]))
print(f"\nTrain: {len(train_dataset)}  ·  Valid: {len(valid_dataset)}")
# Out:
# text     : <eng><asr><notimestamps> bring it closer.
# text_ctc : bring it closer
# speech   : (321, 512)
# tokens   : [ 3083  1697 11977]
#
# Train: 8072  ·  Valid: 1426

# %% [markdown]
# ## 6. Configuración de entrenamiento
#
# El YAML es el mismo del notebook original, con `specaug: null` (ya no aplica) y
# los valores del panel inyectados encima.

# %%
yaml_content = f'''
use_lora: false

rir_scp: null
noise_scp: null
speech_volume_normalize: null
non_linguistic_symbols: null

preprocessor_conf:
  speech_name: speech
  text_name: text

seed: 2024
num_workers: {NUM_WORKERS}
ngpu: 1
batch_type: sorted
batch_size: {BATCH_SIZE}
accum_grad: 1
max_epoch: {CONF['max_epoch']}
patience: null
init: null
best_model_criterion:
- [valid, loss, min]
keep_nbest_models: 1
use_amp: true

optim: adam
optim_conf:
    lr: {LR}
    weight_decay: 0.000001
scheduler: warmuplr
scheduler_conf:
    warmup_steps: {CONF['warmup']}

specaug: null
ctc_weight: {CTC_WEIGHT}
grad_clip: {GRAD_CLIP}
'''

with open("finetune_b2t25.yaml", "w") as f:
    f.write(yaml_content)

finetune_config = ez.config.update_finetune_config(
    "s2t", pretrain_config, "finetune_b2t25.yaml")

finetune_config["cudnn_deterministic"] = False    # el True por defecto cuesta ~25 %
finetune_config["multiple_iterator"]   = False
finetune_config["iterator_type"]       = "sequence"
finetune_config["log_interval"]        = 20

finetune_config["batch_type"] = "numel"
finetune_config["batch_bins"] = 4_000_000    # ~9 trials medios, ~3 de los largos
finetune_config["accum_grad"] = 2

NOMBRES = ["speech_shape", "text_shape", "text_prev_shape", "text_ctc_shape"]
finetune_config["train_shape_file"] = [f"{STATS_DIR}/train/{n}" for n in NOMBRES]
finetune_config["valid_shape_file"] = [f"{STATS_DIR}/valid/{n}" for n in NOMBRES]

finetune_config["num_iters_per_epoch"] = None   # una época = una pasada, no lo de OWSM
finetune_config["cudnn_benchmark"] = False      # ver más abajo

pasos = max(1, len(train_dataset) // BATCH_SIZE)
print(f"~{pasos} pasos/época  ·  warmup {CONF['warmup']} pasos "
      f"(~{CONF['warmup']/pasos:.1f} épocas)")
print(f"lr {LR}  ·  batch {BATCH_SIZE}  ·  grad_clip {GRAD_CLIP}  ·  "
      f"ctc_weight {CTC_WEIGHT}")

print("CONFIGURACIÓN EFECTIVA")
for k in ("num_iters_per_epoch", "batch_type", "batch_bins", "accum_grad",
          "max_epoch", "cudnn_benchmark", "cudnn_deterministic"):
    print(f"  {k:22s} {finetune_config.get(k)}")
assert finetune_config["num_iters_per_epoch"] is None, "OWSM está mandando otra vez"
# Out:
# ~504 pasos/época  ·  warmup 200 pasos (~0.4 épocas)
# lr 0.001  ·  batch 16  ·  grad_clip 5.0  ·  ctc_weight 1.0
# CONFIGURACIÓN EFECTIVA
#   num_iters_per_epoch    None
#   batch_type             numel
#   batch_bins             4000000
#   accum_grad             2
#   max_epoch              20
#   cudnn_benchmark        False
#   cudnn_deterministic    False

# %% [markdown]
# ## 7. Entrenamiento
#
# `ez.Trainer` es el de ESPnet-EZ sin modificar. `collect_stats()` recorre el
# corpus una vez para escribir los ficheros de formas que necesita el
# agrupador por lotes.

# %%
trainer = ez.Trainer(
    task="s2t",
    train_config=finetune_config,
    train_dataset=train_dataset,
    valid_dataset=valid_dataset,
    build_model_fn=build_model_fn,
    data_info=data_info,
    output_dir=EXP_DIR,
    stats_dir=STATS_DIR,
    ngpu=1,
)

if all(os.path.exists(p) and os.path.getsize(p) > 0
       for p in finetune_config["train_shape_file"] + finetune_config["valid_shape_file"]):
    print("Los shape files ya existen, salto collect_stats.")
else:
    trainer.collect_stats()

for p in finetune_config["train_shape_file"]:
    print(f"  {os.path.basename(p):18s} {sum(1 for _ in open(p))} líneas")
# Out:
# /usr/bin/python3 /usr/local/lib/python3.13/dist-packages/colab_kernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-865e2ea1-41ad-4bfc-91ee-2b764b05b318.json
# WARNING:root:Set decoder to none as ctc_weight==1.0
# Parámetros totales     : 64,456,018
# Parámetros entrenables : 64,456,018 (100.0 %)
#   speech_shape       8072 líneas
#   text_shape         8072 líneas
#   text_prev_shape    8072 líneas
#   text_ctc_shape     8072 líneas

# %%
# basicConfig es un no-op en Colab (el root ya tiene handlers), hay que forzarlo
raiz = logging.getLogger()
raiz.setLevel(logging.INFO)
raiz.handlers.clear()

fmt = logging.Formatter("%(asctime)s %(message)s", "%H:%M:%S")
for h in (logging.FileHandler(LOG_PATH, mode="w"), logging.StreamHandler(sys.stdout)):
    h.setFormatter(fmt)
    raiz.addHandler(h)

logging.info("=== arranca el entrenamiento ===")
trainer.train()
# Out:
# 23:04:10 === arranca el entrenamiento ===
# 23:04:10 Vocabulary size: 50002
# 23:04:10 Gradient checkpoint layers: []
# /usr/bin/python3 /usr/local/lib/python3.13/dist-packages/colab_kernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-865e2ea1-41ad-4bfc-91ee-2b764b05b318.json
# 23:04:10 Gradient checkpoint layers: []
# 23:04:10 Set decoder to none as ctc_weight==1.0
# Parámetros totales     : 64,456,018
# Parámetros entrenables : 64,456,018 (100.0 %)
# 23:04:11 pytorch.version=2.11.0+cu128, cuda.available=True, cudnn.version=91900, cudnn.benchmark=False, cudnn.deterministic=False
# 23:04:11 Model structure:
# ESPnetS2TModel(
#   (frontend): None
#   (normalize): None
#   (encoder): EBranchformerEncoder(
#     (embed): Conv2dSubsampling(
#       (conv): Sequential(
#         (0): Conv2d(1, 384, kernel_size=(3, 3), stride=(2, 2))
#         (1): ReLU()
#         (2): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2))
#         (3): ReLU()
#       )
#       (out): Sequential(
#         (0): Linear(in_features=48768, out_features=384, bias=True)
#         (1): PositionalEncoding(
#           (dropout): Dropout(p=0.05, inplace=False)
#         )
#       )
#     )
#     (encoders): MultiSequential(
#       (0): EBranchformerEncoderLayer(
#         (attn): MultiHeadedAttention(
#           (linear_q): Linear(in_features=384, out_features=384, bias=True)
#           (linear_k): Linear(in_features=384, out_features=384, bias=True)
#           (linear_v): Linear(in_features=384, out_features=384, bias=True)
#           (linear_out): Linear(in_features=384, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (q_norm): Identity()
#           (k_norm): Identity()
#         )
#         (cgmlp): ConvolutionalGatingMLP(
#           (channel_proj1): Sequential(
#             (0): Linear(in_features=384, out_features=1536, bias=True)
#             (1): GELU(approximate='none')
#           )
#           (csgu): ConvolutionalSpatialGatingUnit(
#             (norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (conv): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#             (act): Identity()
#             (dropout): Dropout(p=0.05, inplace=False)
#           )
#           (channel_proj2): Linear(in_features=768, out_features=384, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (feed_forward_macaron): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (norm_ff): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_ff_macaron): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mha): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mlp): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_final): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.05, inplace=False)
#         (depthwise_conv_fusion): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#         (merge_proj): Linear(in_features=768, out_features=384, bias=True)
#       )
#       (1): EBranchformerEncoderLayer(
#         (attn): MultiHeadedAttention(
#           (linear_q): Linear(in_features=384, out_features=384, bias=True)
#           (linear_k): Linear(in_features=384, out_features=384, bias=True)
#           (linear_v): Linear(in_features=384, out_features=384, bias=True)
#           (linear_out): Linear(in_features=384, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (q_norm): Identity()
#           (k_norm): Identity()
#         )
#         (cgmlp): ConvolutionalGatingMLP(
#           (channel_proj1): Sequential(
#             (0): Linear(in_features=384, out_features=1536, bias=True)
#             (1): GELU(approximate='none')
#           )
#           (csgu): ConvolutionalSpatialGatingUnit(
#             (norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (conv): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#             (act): Identity()
#             (dropout): Dropout(p=0.05, inplace=False)
#           )
#           (channel_proj2): Linear(in_features=768, out_features=384, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (feed_forward_macaron): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (norm_ff): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_ff_macaron): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mha): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mlp): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_final): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.05, inplace=False)
#         (depthwise_conv_fusion): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#         (merge_proj): Linear(in_features=768, out_features=384, bias=True)
#       )
#       (2): EBranchformerEncoderLayer(
#         (attn): MultiHeadedAttention(
#           (linear_q): Linear(in_features=384, out_features=384, bias=True)
#           (linear_k): Linear(in_features=384, out_features=384, bias=True)
#           (linear_v): Linear(in_features=384, out_features=384, bias=True)
#           (linear_out): Linear(in_features=384, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (q_norm): Identity()
#           (k_norm): Identity()
#         )
#         (cgmlp): ConvolutionalGatingMLP(
#           (channel_proj1): Sequential(
#             (0): Linear(in_features=384, out_features=1536, bias=True)
#             (1): GELU(approximate='none')
#           )
#           (csgu): ConvolutionalSpatialGatingUnit(
#             (norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (conv): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#             (act): Identity()
#             (dropout): Dropout(p=0.05, inplace=False)
#           )
#           (channel_proj2): Linear(in_features=768, out_features=384, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (feed_forward_macaron): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (norm_ff): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_ff_macaron): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mha): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mlp): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_final): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.05, inplace=False)
#         (depthwise_conv_fusion): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#         (merge_proj): Linear(in_features=768, out_features=384, bias=True)
#       )
#       (3): EBranchformerEncoderLayer(
#         (attn): MultiHeadedAttention(
#           (linear_q): Linear(in_features=384, out_features=384, bias=True)
#           (linear_k): Linear(in_features=384, out_features=384, bias=True)
#           (linear_v): Linear(in_features=384, out_features=384, bias=True)
#           (linear_out): Linear(in_features=384, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (q_norm): Identity()
#           (k_norm): Identity()
#         )
#         (cgmlp): ConvolutionalGatingMLP(
#           (channel_proj1): Sequential(
#             (0): Linear(in_features=384, out_features=1536, bias=True)
#             (1): GELU(approximate='none')
#           )
#           (csgu): ConvolutionalSpatialGatingUnit(
#             (norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (conv): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#             (act): Identity()
#             (dropout): Dropout(p=0.05, inplace=False)
#           )
#           (channel_proj2): Linear(in_features=768, out_features=384, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (feed_forward_macaron): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (norm_ff): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_ff_macaron): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mha): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mlp): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_final): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.05, inplace=False)
#         (depthwise_conv_fusion): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#         (merge_proj): Linear(in_features=768, out_features=384, bias=True)
#       )
#       (4): EBranchformerEncoderLayer(
#         (attn): MultiHeadedAttention(
#           (linear_q): Linear(in_features=384, out_features=384, bias=True)
#           (linear_k): Linear(in_features=384, out_features=384, bias=True)
#           (linear_v): Linear(in_features=384, out_features=384, bias=True)
#           (linear_out): Linear(in_features=384, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (q_norm): Identity()
#           (k_norm): Identity()
#         )
#         (cgmlp): ConvolutionalGatingMLP(
#           (channel_proj1): Sequential(
#             (0): Linear(in_features=384, out_features=1536, bias=True)
#             (1): GELU(approximate='none')
#           )
#           (csgu): ConvolutionalSpatialGatingUnit(
#             (norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (conv): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#             (act): Identity()
#             (dropout): Dropout(p=0.05, inplace=False)
#           )
#           (channel_proj2): Linear(in_features=768, out_features=384, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (feed_forward_macaron): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (norm_ff): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_ff_macaron): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mha): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mlp): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_final): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.05, inplace=False)
#         (depthwise_conv_fusion): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#         (merge_proj): Linear(in_features=768, out_features=384, bias=True)
#       )
#       (5): EBranchformerEncoderLayer(
#         (attn): MultiHeadedAttention(
#           (linear_q): Linear(in_features=384, out_features=384, bias=True)
#           (linear_k): Linear(in_features=384, out_features=384, bias=True)
#           (linear_v): Linear(in_features=384, out_features=384, bias=True)
#           (linear_out): Linear(in_features=384, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (q_norm): Identity()
#           (k_norm): Identity()
#         )
#         (cgmlp): ConvolutionalGatingMLP(
#           (channel_proj1): Sequential(
#             (0): Linear(in_features=384, out_features=1536, bias=True)
#             (1): GELU(approximate='none')
#           )
#           (csgu): ConvolutionalSpatialGatingUnit(
#             (norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (conv): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#             (act): Identity()
#             (dropout): Dropout(p=0.05, inplace=False)
#           )
#           (channel_proj2): Linear(in_features=768, out_features=384, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (feed_forward_macaron): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (norm_ff): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_ff_macaron): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mha): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mlp): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_final): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.05, inplace=False)
#         (depthwise_conv_fusion): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#         (merge_proj): Linear(in_features=768, out_features=384, bias=True)
#       )
#     )
#     (after_norm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#   )
#   (criterion_att): LabelSmoothingLoss(
#     (criterion): KLDivLoss()
#   )
#   (ctc): CTC(
#     (ctc_lo): Linear(in_features=384, out_features=50002, bias=True)
#     (ctc_loss): CTCLoss()
#   )
# )
#
# Model summary:
#     Class Name: ESPnetS2TModel
#     Total Number of model parameters: 64.46 M
#     Number of trainable parameters: 64.46 M (100.0%)
#     Size: 257.82 MB
#     Type: torch.float32
# 23:04:11 Optimizer:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.001
#     lr: 5e-06
#     maximize: False
#     weight_decay: 1e-06
# )
# 23:04:11 Scheduler: WarmupLR(warmup_steps=200)
# 23:04:11 Saving the configuration in /content/exp/palabras/config.yaml
# 23:04:11 Optional Data Names: ('text_prev', 'text_ctc', 'text_spk2', 'text_spk3', 'text_spk4')
# 23:04:11 [train] dataset:
# <espnetez.dataset.ESPnetEZDataset object at 0x7fd1681a17f0>
# 23:04:11 [train] Batch sampler: NumElementsBatchSampler(N-batch=888, batch_bins=4000000, sort_in_batch=descending, sort_batch=descending)
# 23:04:11 [train] mini-batch sizes summary: N-batch=888, mean=9.1, min=2, max=23
# 23:04:11 Optional Data Names: ('text_prev', 'text_ctc', 'text_spk2', 'text_spk3', 'text_spk4')
# 23:04:11 [valid] dataset:
# <espnetez.dataset.ESPnetEZDataset object at 0x7fd3f5632e90>
# 23:04:11 [valid] Batch sampler: NumElementsBatchSampler(N-batch=163, batch_bins=4000000, sort_in_batch=descending, sort_batch=descending)
# 23:04:12 [valid] mini-batch sizes summary: N-batch=163, mean=8.7, min=4, max=17
# /usr/local/lib/python3.13/dist-packages/espnet2/train/trainer.py:219: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# 23:04:16 1/20epoch started
# /usr/local/lib/python3.13/dist-packages/espnet2/train/trainer.py:638: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(
# 23:04:24 1epoch:train:1-20batch: iter_time=0.005, forward_time=0.116, loss_ctc=31.002, loss=31.002, backward_time=0.105, grad_norm=2.340e+03, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.023, optim0_lr0=3.250e-05, train_time=0.743
# 23:04:30 1epoch:train:21-40batch: iter_time=1.653e-04, forward_time=0.088, loss_ctc=23.763, loss=23.763, backward_time=0.083, grad_norm=194.692, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=8.250e-05, train_time=0.572
# 23:04:36 1epoch:train:41-60batch: iter_time=1.914e-04, forward_time=0.096, loss_ctc=25.214, loss=25.214, backward_time=0.088, grad_norm=123.107, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=1.325e-04, train_time=0.620
# 23:04:42 1epoch:train:61-80batch: iter_time=1.660e-04, forward_time=0.095, loss_ctc=21.445, loss=21.445, backward_time=0.083, grad_norm=124.528, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=1.825e-04, train_time=0.587
# 23:04:48 1epoch:train:81-100batch: iter_time=1.750e-04, forward_time=0.095, loss_ctc=21.717, loss=21.717, backward_time=0.086, grad_norm=125.806, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=2.325e-04, train_time=0.611
# 23:04:54 1epoch:train:101-120batch: iter_time=1.400e-04, forward_time=0.091, loss_ctc=22.937, loss=22.937, backward_time=0.085, grad_norm=139.773, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=2.825e-04, train_time=0.595
# 23:05:00 1epoch:train:121-140batch: iter_time=1.636e-04, forward_time=0.094, loss_ctc=23.013, loss=23.013, backward_time=0.085, grad_norm=107.429, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=3.325e-04, train_time=0.610
# 23:05:06 1epoch:train:141-160batch: iter_time=1.679e-04, forward_time=0.099, loss_ctc=22.162, loss=22.162, backward_time=0.091, grad_norm=108.129, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=3.825e-04, train_time=0.643
# 23:05:12 1epoch:train:161-180batch: iter_time=1.647e-04, forward_time=0.090, loss_ctc=22.438, loss=22.438, backward_time=0.085, grad_norm=90.156, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.325e-04, train_time=0.588
# 23:05:18 1epoch:train:181-200batch: iter_time=1.501e-04, forward_time=0.092, loss_ctc=23.057, loss=23.057, backward_time=0.084, grad_norm=71.793, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.825e-04, train_time=0.592
# 23:05:25 1epoch:train:201-220batch: iter_time=1.414e-04, forward_time=0.103, loss_ctc=19.110, loss=19.110, backward_time=0.093, grad_norm=104.387, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.325e-04, train_time=0.668
# 23:05:31 1epoch:train:221-240batch: iter_time=2.195e-04, forward_time=0.090, loss_ctc=20.446, loss=20.446, backward_time=0.081, grad_norm=87.423, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.825e-04, train_time=0.582
# 23:05:36 1epoch:train:241-260batch: iter_time=2.085e-04, forward_time=0.091, loss_ctc=20.988, loss=20.988, backward_time=0.085, grad_norm=104.363, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.325e-04, train_time=0.590
# 23:05:43 1epoch:train:261-280batch: iter_time=1.895e-04, forward_time=0.097, loss_ctc=19.191, loss=19.191, backward_time=0.087, grad_norm=82.327, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.825e-04, train_time=0.632
# 23:05:49 1epoch:train:281-300batch: iter_time=2.043e-04, forward_time=0.098, loss_ctc=21.453, loss=21.453, backward_time=0.089, grad_norm=122.854, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=7.325e-04, train_time=0.635
# 23:05:56 1epoch:train:301-320batch: iter_time=2.462e-04, forward_time=0.106, loss_ctc=21.286, loss=21.286, backward_time=0.095, grad_norm=87.358, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=7.825e-04, train_time=0.689
# 23:06:02 1epoch:train:321-340batch: iter_time=2.225e-04, forward_time=0.096, loss_ctc=27.433, loss=27.433, backward_time=0.086, grad_norm=119.928, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=8.325e-04, train_time=0.620
# 23:06:09 1epoch:train:341-360batch: iter_time=1.441e-04, forward_time=0.114, loss_ctc=22.471, loss=22.471, backward_time=0.092, grad_norm=160.143, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=8.825e-04, train_time=0.689
# 23:06:16 1epoch:train:361-380batch: iter_time=1.538e-04, forward_time=0.108, loss_ctc=21.187, loss=21.187, backward_time=0.094, grad_norm=144.028, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=9.325e-04, train_time=0.698
# 23:06:22 1epoch:train:381-400batch: iter_time=1.927e-04, forward_time=0.097, loss_ctc=24.132, loss=24.132, backward_time=0.087, grad_norm=111.895, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=9.818e-04, train_time=0.627
# 23:06:28 1epoch:train:401-420batch: iter_time=1.869e-04, forward_time=0.093, loss_ctc=24.431, loss=24.431, backward_time=0.084, grad_norm=84.304, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=9.842e-04, train_time=0.598
# 23:06:35 1epoch:train:421-440batch: iter_time=1.930e-04, forward_time=0.102, loss_ctc=22.696, loss=22.696, backward_time=0.089, grad_norm=140.490, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=9.612e-04, train_time=0.654
# 23:06:41 1epoch:train:441-460batch: iter_time=2.034e-04, forward_time=0.097, loss_ctc=21.014, loss=21.014, backward_time=0.088, grad_norm=57.463, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=9.397e-04, train_time=0.625
# 23:06:48 1epoch:train:461-480batch: iter_time=1.719e-04, forward_time=0.099, loss_ctc=20.160, loss=20.160, backward_time=0.088, grad_norm=62.296, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=9.197e-04, train_time=0.642
# 23:06:53 1epoch:train:481-500batch: iter_time=1.435e-04, forward_time=0.090, loss_ctc=21.829, loss=21.829, backward_time=0.083, grad_norm=70.374, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=9.008e-04, train_time=0.583
# 23:07:00 1epoch:train:501-520batch: iter_time=1.735e-04, forward_time=0.098, loss_ctc=22.604, loss=22.604, backward_time=0.087, grad_norm=55.386, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=8.831e-04, train_time=0.628
# 23:07:06 1epoch:train:521-540batch: iter_time=1.415e-04, forward_time=0.103, loss_ctc=21.474, loss=21.474, backward_time=0.090, grad_norm=69.813, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=8.663e-04, train_time=0.668
# 23:07:13 1epoch:train:541-560batch: iter_time=1.324e-04, forward_time=0.100, loss_ctc=22.700, loss=22.700, backward_time=0.089, grad_norm=80.080, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=8.505e-04, train_time=0.645
# 23:07:19 1epoch:train:561-580batch: iter_time=1.819e-04, forward_time=0.092, loss_ctc=20.807, loss=20.807, backward_time=0.086, grad_norm=84.068, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=8.355e-04, train_time=0.599
# 23:07:25 1epoch:train:581-600batch: iter_time=1.628e-04, forward_time=0.100, loss_ctc=19.580, loss=19.580, backward_time=0.090, grad_norm=93.994, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=8.213e-04, train_time=0.648
# 23:07:32 1epoch:train:601-620batch: iter_time=1.558e-04, forward_time=0.097, loss_ctc=22.628, loss=22.628, backward_time=0.089, grad_norm=38.876, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=8.078e-04, train_time=0.633
# 23:07:38 1epoch:train:621-640batch: iter_time=1.674e-04, forward_time=0.093, loss_ctc=21.310, loss=21.310, backward_time=0.085, grad_norm=44.416, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=7.950e-04, train_time=0.606
# 23:07:44 1epoch:train:641-660batch: iter_time=1.733e-04, forward_time=0.099, loss_ctc=21.048, loss=21.048, backward_time=0.087, grad_norm=76.338, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=7.827e-04, train_time=0.635
# 23:07:50 1epoch:train:661-680batch: iter_time=1.683e-04, forward_time=0.090, loss_ctc=24.894, loss=24.894, backward_time=0.081, grad_norm=97.213, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=7.710e-04, train_time=0.580
# 23:07:56 1epoch:train:681-700batch: iter_time=1.469e-04, forward_time=0.100, loss_ctc=19.456, loss=19.456, backward_time=0.090, grad_norm=100.980, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=7.598e-04, train_time=0.649
# 23:08:02 1epoch:train:701-720batch: iter_time=1.681e-04, forward_time=0.090, loss_ctc=17.462, loss=17.462, backward_time=0.083, grad_norm=85.109, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=7.490e-04, train_time=0.584
# 23:08:08 1epoch:train:721-740batch: iter_time=1.797e-04, forward_time=0.093, loss_ctc=20.278, loss=20.278, backward_time=0.085, grad_norm=99.484, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=7.387e-04, train_time=0.601
# 23:08:14 1epoch:train:741-760batch: iter_time=1.793e-04, forward_time=0.096, loss_ctc=19.324, loss=19.324, backward_time=0.088, grad_norm=62.245, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=7.289e-04, train_time=0.621
# 23:08:21 1epoch:train:761-780batch: iter_time=1.624e-04, forward_time=0.101, loss_ctc=20.744, loss=20.744, backward_time=0.091, grad_norm=53.253, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=7.194e-04, train_time=0.652
# 23:08:28 1epoch:train:781-800batch: iter_time=1.672e-04, forward_time=0.103, loss_ctc=23.983, loss=23.983, backward_time=0.092, grad_norm=84.603, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=7.102e-04, train_time=0.666
# 23:08:34 1epoch:train:801-820batch: iter_time=1.347e-04, forward_time=0.099, loss_ctc=23.575, loss=23.575, backward_time=0.091, grad_norm=77.198, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=7.014e-04, train_time=0.647
# 23:08:40 1epoch:train:821-840batch: iter_time=1.762e-04, forward_time=0.095, loss_ctc=19.793, loss=19.793, backward_time=0.087, grad_norm=51.344, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.930e-04, train_time=0.615
# 23:08:46 1epoch:train:841-860batch: iter_time=1.515e-04, forward_time=0.095, loss_ctc=21.867, loss=21.867, backward_time=0.089, grad_norm=61.126, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.848e-04, train_time=0.618
# 23:08:53 1epoch:train:861-880batch: iter_time=1.660e-04, forward_time=0.096, loss_ctc=18.935, loss=18.935, backward_time=0.089, grad_norm=60.421, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.769e-04, train_time=0.626
# /usr/local/lib/python3.13/dist-packages/espnet2/train/trainer.py:856: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(
# 23:09:15 1epoch results: [train] iter_time=2.836e-04, forward_time=0.097, loss_ctc=21.870, loss=21.870, backward_time=0.088, grad_norm=143.244, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.689e-04, train_time=0.627, time=4 minutes and 38.93 seconds, total_count=888, gpu_max_cached_mem_GB=20.996, [valid] loss_ctc=49.559, cer_ctc=0.941, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=49.559, time=19.99 seconds, total_count=163, gpu_max_cached_mem_GB=21.617
# 23:09:19 The best model has been updated: valid.loss
# 23:09:19 2/20epoch started. Estimated time to finish: 1 hour, 35 minutes and 50.89 seconds
# 23:09:26 2epoch:train:1-20batch: iter_time=0.006, forward_time=0.103, loss_ctc=17.454, loss=17.454, backward_time=0.105, grad_norm=81.002, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.663e-04, train_time=0.727
# 23:09:33 2epoch:train:21-40batch: iter_time=1.703e-04, forward_time=0.098, loss_ctc=19.302, loss=19.302, backward_time=0.085, grad_norm=109.590, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.590e-04, train_time=0.639
# 23:09:39 2epoch:train:41-60batch: iter_time=1.590e-04, forward_time=0.091, loss_ctc=22.413, loss=22.413, backward_time=0.079, grad_norm=80.814, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.520e-04, train_time=0.597
# 23:09:45 2epoch:train:61-80batch: iter_time=1.600e-04, forward_time=0.104, loss_ctc=18.575, loss=18.575, backward_time=0.088, grad_norm=91.373, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.452e-04, train_time=0.681
# 23:09:51 2epoch:train:81-100batch: iter_time=1.859e-04, forward_time=0.089, loss_ctc=24.865, loss=24.865, backward_time=0.078, grad_norm=114.613, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.386e-04, train_time=0.589
# 23:09:58 2epoch:train:101-120batch: iter_time=1.489e-04, forward_time=0.096, loss_ctc=21.441, loss=21.441, backward_time=0.080, grad_norm=62.899, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.321e-04, train_time=0.625
# 23:10:04 2epoch:train:121-140batch: iter_time=1.898e-04, forward_time=0.093, loss_ctc=18.759, loss=18.759, backward_time=0.082, grad_norm=53.143, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.259e-04, train_time=0.610
# 23:10:10 2epoch:train:141-160batch: iter_time=1.706e-04, forward_time=0.093, loss_ctc=21.468, loss=21.468, backward_time=0.081, grad_norm=84.220, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.199e-04, train_time=0.611
# 23:10:16 2epoch:train:161-180batch: iter_time=1.567e-04, forward_time=0.090, loss_ctc=21.348, loss=21.348, backward_time=0.079, grad_norm=89.408, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.140e-04, train_time=0.595
# 23:10:21 2epoch:train:181-200batch: iter_time=1.405e-04, forward_time=0.085, loss_ctc=20.233, loss=20.233, backward_time=0.078, grad_norm=52.266, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.083e-04, train_time=0.565
# 23:10:28 2epoch:train:201-220batch: iter_time=1.754e-04, forward_time=0.096, loss_ctc=21.092, loss=21.092, backward_time=0.085, grad_norm=65.950, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=6.028e-04, train_time=0.632
# 23:10:34 2epoch:train:221-240batch: iter_time=1.438e-04, forward_time=0.094, loss_ctc=22.026, loss=22.026, backward_time=0.081, grad_norm=46.014, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.974e-04, train_time=0.614
# 23:10:40 2epoch:train:241-260batch: iter_time=1.569e-04, forward_time=0.093, loss_ctc=21.127, loss=21.127, backward_time=0.081, grad_norm=36.338, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.921e-04, train_time=0.611
# 23:10:46 2epoch:train:261-280batch: iter_time=1.528e-04, forward_time=0.094, loss_ctc=20.189, loss=20.189, backward_time=0.081, grad_norm=60.289, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.870e-04, train_time=0.616
# 23:10:52 2epoch:train:281-300batch: iter_time=1.805e-04, forward_time=0.096, loss_ctc=19.832, loss=19.832, backward_time=0.085, grad_norm=43.246, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.820e-04, train_time=0.632
# 23:10:59 2epoch:train:301-320batch: iter_time=1.646e-04, forward_time=0.101, loss_ctc=20.150, loss=20.150, backward_time=0.083, grad_norm=52.386, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.771e-04, train_time=0.657
# 23:11:05 2epoch:train:321-340batch: iter_time=1.945e-04, forward_time=0.091, loss_ctc=20.681, loss=20.681, backward_time=0.078, grad_norm=52.759, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.724e-04, train_time=0.596
# 23:11:11 2epoch:train:341-360batch: iter_time=1.653e-04, forward_time=0.099, loss_ctc=20.516, loss=20.516, backward_time=0.084, grad_norm=71.155, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.677e-04, train_time=0.645
# 23:11:18 2epoch:train:361-380batch: iter_time=2.121e-04, forward_time=0.100, loss_ctc=16.668, loss=16.668, backward_time=0.085, grad_norm=60.527, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.632e-04, train_time=0.656
# 23:11:24 2epoch:train:381-400batch: iter_time=1.411e-04, forward_time=0.092, loss_ctc=19.135, loss=19.135, backward_time=0.081, grad_norm=77.973, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.588e-04, train_time=0.605
# 23:11:30 2epoch:train:401-420batch: iter_time=1.602e-04, forward_time=0.092, loss_ctc=19.693, loss=19.693, backward_time=0.080, grad_norm=92.071, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.545e-04, train_time=0.604
# 23:11:36 2epoch:train:421-440batch: iter_time=1.578e-04, forward_time=0.092, loss_ctc=21.773, loss=21.773, backward_time=0.080, grad_norm=105.130, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.503e-04, train_time=0.605
# 23:11:42 2epoch:train:441-460batch: iter_time=1.741e-04, forward_time=0.090, loss_ctc=20.647, loss=20.647, backward_time=0.079, grad_norm=71.989, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.462e-04, train_time=0.592
# 23:11:48 2epoch:train:461-480batch: iter_time=1.705e-04, forward_time=0.092, loss_ctc=25.083, loss=25.083, backward_time=0.081, grad_norm=74.736, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.421e-04, train_time=0.604
# 23:11:54 2epoch:train:481-500batch: iter_time=1.511e-04, forward_time=0.096, loss_ctc=20.559, loss=20.559, backward_time=0.083, grad_norm=107.837, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.382e-04, train_time=0.626
# 23:12:01 2epoch:train:501-520batch: iter_time=1.510e-04, forward_time=0.094, loss_ctc=18.966, loss=18.966, backward_time=0.081, grad_norm=63.587, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.343e-04, train_time=0.620
# 23:12:07 2epoch:train:521-540batch: iter_time=1.460e-04, forward_time=0.094, loss_ctc=21.764, loss=21.764, backward_time=0.081, grad_norm=51.998, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.306e-04, train_time=0.616
# 23:12:13 2epoch:train:541-560batch: iter_time=1.306e-04, forward_time=0.089, loss_ctc=19.474, loss=19.474, backward_time=0.077, grad_norm=40.576, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.269e-04, train_time=0.580
# 23:12:19 2epoch:train:561-580batch: iter_time=1.376e-04, forward_time=0.093, loss_ctc=19.770, loss=19.770, backward_time=0.082, grad_norm=77.022, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.232e-04, train_time=0.614
# 23:12:25 2epoch:train:581-600batch: iter_time=1.487e-04, forward_time=0.099, loss_ctc=20.862, loss=20.862, backward_time=0.085, grad_norm=56.889, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.197e-04, train_time=0.651
# 23:12:31 2epoch:train:601-620batch: iter_time=1.500e-04, forward_time=0.095, loss_ctc=18.747, loss=18.747, backward_time=0.082, grad_norm=50.399, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.162e-04, train_time=0.620
# 23:12:38 2epoch:train:621-640batch: iter_time=1.410e-04, forward_time=0.095, loss_ctc=19.631, loss=19.631, backward_time=0.082, grad_norm=54.868, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.128e-04, train_time=0.623
# 23:12:44 2epoch:train:641-660batch: iter_time=1.622e-04, forward_time=0.100, loss_ctc=19.146, loss=19.146, backward_time=0.086, grad_norm=68.577, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.095e-04, train_time=0.657
# 23:12:50 2epoch:train:661-680batch: iter_time=1.568e-04, forward_time=0.092, loss_ctc=19.021, loss=19.021, backward_time=0.082, grad_norm=53.668, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.062e-04, train_time=0.609
# 23:12:58 2epoch:train:681-700batch: iter_time=1.845e-04, forward_time=0.118, loss_ctc=19.925, loss=19.925, backward_time=0.088, grad_norm=42.299, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.030e-04, train_time=0.719
# 23:13:04 2epoch:train:701-720batch: iter_time=1.433e-04, forward_time=0.097, loss_ctc=20.274, loss=20.274, backward_time=0.081, grad_norm=59.999, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.998e-04, train_time=0.631
# 23:13:10 2epoch:train:721-740batch: iter_time=1.546e-04, forward_time=0.094, loss_ctc=17.993, loss=17.993, backward_time=0.082, grad_norm=54.906, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.968e-04, train_time=0.616
# 23:13:16 2epoch:train:741-760batch: iter_time=1.396e-04, forward_time=0.092, loss_ctc=24.558, loss=24.558, backward_time=0.082, grad_norm=63.408, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.937e-04, train_time=0.609
# 23:13:22 2epoch:train:761-780batch: iter_time=1.485e-04, forward_time=0.090, loss_ctc=23.887, loss=23.887, backward_time=0.081, grad_norm=47.434, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.907e-04, train_time=0.595
# 23:13:28 2epoch:train:781-800batch: iter_time=1.823e-04, forward_time=0.095, loss_ctc=20.886, loss=20.886, backward_time=0.085, grad_norm=43.279, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.878e-04, train_time=0.626
# 23:13:35 2epoch:train:801-820batch: iter_time=1.997e-04, forward_time=0.100, loss_ctc=19.409, loss=19.409, backward_time=0.084, grad_norm=34.669, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.849e-04, train_time=0.653
# 23:13:41 2epoch:train:821-840batch: iter_time=1.595e-04, forward_time=0.093, loss_ctc=22.111, loss=22.111, backward_time=0.082, grad_norm=55.925, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.821e-04, train_time=0.612
# 23:13:47 2epoch:train:841-860batch: iter_time=1.600e-04, forward_time=0.091, loss_ctc=22.318, loss=22.318, backward_time=0.081, grad_norm=38.523, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.793e-04, train_time=0.598
# 23:13:53 2epoch:train:861-880batch: iter_time=1.351e-04, forward_time=0.096, loss_ctc=20.167, loss=20.167, backward_time=0.083, grad_norm=50.444, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.766e-04, train_time=0.630
# 23:14:16 2epoch results: [train] iter_time=2.936e-04, forward_time=0.095, loss_ctc=20.437, loss=20.437, backward_time=0.082, grad_norm=64.649, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=5.553e-04, train_time=0.623, time=4 minutes and 36.85 seconds, total_count=1776, gpu_max_cached_mem_GB=21.617, [valid] loss_ctc=48.763, cer_ctc=0.941, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=48.763, time=19.65 seconds, total_count=326, gpu_max_cached_mem_GB=21.617
# 23:14:19 The best model has been updated: valid.loss
# 23:14:19 The model files were removed: /content/exp/palabras/1epoch.pth
# 23:14:19 3/20epoch started. Estimated time to finish: 1 hour, 30 minutes and 24.04 seconds
# 23:14:25 3epoch:train:1-20batch: iter_time=0.005, forward_time=0.091, loss_ctc=21.974, loss=21.974, backward_time=0.084, grad_norm=69.678, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.729e-04, train_time=0.645
# 23:14:33 3epoch:train:21-40batch: iter_time=1.959e-04, forward_time=0.120, loss_ctc=19.319, loss=19.319, backward_time=0.091, grad_norm=39.851, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.702e-04, train_time=0.738
# 23:14:39 3epoch:train:41-60batch: iter_time=1.607e-04, forward_time=0.097, loss_ctc=15.783, loss=15.783, backward_time=0.086, grad_norm=40.714, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.677e-04, train_time=0.640
# 23:14:45 3epoch:train:61-80batch: iter_time=1.584e-04, forward_time=0.089, loss_ctc=17.666, loss=17.666, backward_time=0.077, grad_norm=49.068, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.651e-04, train_time=0.584
# 23:14:51 3epoch:train:81-100batch: iter_time=1.827e-04, forward_time=0.090, loss_ctc=20.220, loss=20.220, backward_time=0.078, grad_norm=37.535, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.626e-04, train_time=0.586
# 23:14:58 3epoch:train:101-120batch: iter_time=1.851e-04, forward_time=0.103, loss_ctc=16.032, loss=16.032, backward_time=0.088, grad_norm=45.590, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.602e-04, train_time=0.675
# 23:15:04 3epoch:train:121-140batch: iter_time=2.016e-04, forward_time=0.094, loss_ctc=21.045, loss=21.045, backward_time=0.080, grad_norm=96.522, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.578e-04, train_time=0.616
# 23:15:10 3epoch:train:141-160batch: iter_time=1.484e-04, forward_time=0.092, loss_ctc=21.216, loss=21.216, backward_time=0.080, grad_norm=51.448, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.554e-04, train_time=0.603
# 23:15:16 3epoch:train:161-180batch: iter_time=1.606e-04, forward_time=0.084, loss_ctc=17.833, loss=17.833, backward_time=0.078, grad_norm=60.486, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.530e-04, train_time=0.562
# 23:15:22 3epoch:train:181-200batch: iter_time=1.865e-04, forward_time=0.092, loss_ctc=18.886, loss=18.886, backward_time=0.081, grad_norm=58.821, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.507e-04, train_time=0.606
# 23:15:28 3epoch:train:201-220batch: iter_time=1.557e-04, forward_time=0.091, loss_ctc=19.974, loss=19.974, backward_time=0.083, grad_norm=38.355, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.484e-04, train_time=0.605
# 23:15:34 3epoch:train:221-240batch: iter_time=1.771e-04, forward_time=0.097, loss_ctc=22.116, loss=22.116, backward_time=0.083, grad_norm=50.569, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.462e-04, train_time=0.632
# 23:15:40 3epoch:train:241-260batch: iter_time=1.651e-04, forward_time=0.090, loss_ctc=21.427, loss=21.427, backward_time=0.080, grad_norm=66.802, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.440e-04, train_time=0.596
# 23:15:46 3epoch:train:261-280batch: iter_time=1.272e-04, forward_time=0.093, loss_ctc=22.539, loss=22.539, backward_time=0.082, grad_norm=65.995, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.418e-04, train_time=0.615
# 23:15:52 3epoch:train:281-300batch: iter_time=1.426e-04, forward_time=0.095, loss_ctc=21.608, loss=21.608, backward_time=0.081, grad_norm=40.473, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.397e-04, train_time=0.620
# 23:15:59 3epoch:train:301-320batch: iter_time=1.736e-04, forward_time=0.098, loss_ctc=18.886, loss=18.886, backward_time=0.084, grad_norm=32.503, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.376e-04, train_time=0.643
# 23:16:05 3epoch:train:321-340batch: iter_time=1.748e-04, forward_time=0.101, loss_ctc=19.953, loss=19.953, backward_time=0.085, grad_norm=49.922, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.355e-04, train_time=0.662
# 23:16:11 3epoch:train:341-360batch: iter_time=1.436e-04, forward_time=0.089, loss_ctc=20.249, loss=20.249, backward_time=0.080, grad_norm=32.941, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.335e-04, train_time=0.588
# 23:16:18 3epoch:train:361-380batch: iter_time=1.647e-04, forward_time=0.099, loss_ctc=20.855, loss=20.855, backward_time=0.082, grad_norm=57.585, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.314e-04, train_time=0.643
# 23:16:24 3epoch:train:381-400batch: iter_time=1.733e-04, forward_time=0.100, loss_ctc=21.275, loss=21.275, backward_time=0.083, grad_norm=55.696, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.294e-04, train_time=0.652
# 23:16:31 3epoch:train:401-420batch: iter_time=1.595e-04, forward_time=0.100, loss_ctc=19.803, loss=19.803, backward_time=0.084, grad_norm=56.987, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.275e-04, train_time=0.652
# 23:16:36 3epoch:train:421-440batch: iter_time=1.512e-04, forward_time=0.087, loss_ctc=21.017, loss=21.017, backward_time=0.077, grad_norm=63.559, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.255e-04, train_time=0.576
# 23:16:42 3epoch:train:441-460batch: iter_time=1.527e-04, forward_time=0.091, loss_ctc=21.252, loss=21.252, backward_time=0.082, grad_norm=46.368, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.236e-04, train_time=0.604
# 23:16:49 3epoch:train:461-480batch: iter_time=1.505e-04, forward_time=0.104, loss_ctc=18.427, loss=18.427, backward_time=0.084, grad_norm=33.264, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.217e-04, train_time=0.673
# 23:16:55 3epoch:train:481-500batch: iter_time=2.085e-04, forward_time=0.085, loss_ctc=21.703, loss=21.703, backward_time=0.077, grad_norm=55.967, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.199e-04, train_time=0.561
# 23:17:02 3epoch:train:501-520batch: iter_time=1.584e-04, forward_time=0.110, loss_ctc=20.761, loss=20.761, backward_time=0.090, grad_norm=59.145, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.180e-04, train_time=0.714
# 23:17:08 3epoch:train:521-540batch: iter_time=1.430e-04, forward_time=0.093, loss_ctc=24.112, loss=24.112, backward_time=0.082, grad_norm=56.842, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.162e-04, train_time=0.609
# 23:17:14 3epoch:train:541-560batch: iter_time=1.292e-04, forward_time=0.094, loss_ctc=20.283, loss=20.283, backward_time=0.083, grad_norm=84.810, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.144e-04, train_time=0.622
# 23:17:21 3epoch:train:561-580batch: iter_time=1.530e-04, forward_time=0.096, loss_ctc=19.403, loss=19.403, backward_time=0.081, grad_norm=78.135, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.127e-04, train_time=0.627
# 23:17:27 3epoch:train:581-600batch: iter_time=1.545e-04, forward_time=0.099, loss_ctc=21.116, loss=21.116, backward_time=0.084, grad_norm=44.289, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.109e-04, train_time=0.648
# 23:17:33 3epoch:train:601-620batch: iter_time=1.614e-04, forward_time=0.093, loss_ctc=20.313, loss=20.313, backward_time=0.081, grad_norm=79.724, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.092e-04, train_time=0.608
# 23:17:39 3epoch:train:621-640batch: iter_time=1.403e-04, forward_time=0.093, loss_ctc=19.346, loss=19.346, backward_time=0.081, grad_norm=66.026, clip=100.000, loss_scale=6.554e+04, optim_step_time=0.006, optim0_lr0=4.075e-04, train_time=0.608
# ...
# 00:37:36 19epoch:train:581-600batch: iter_time=1.643e-04, forward_time=0.097, loss_ctc=16.959, loss=16.959, backward_time=0.083, grad_norm=48.089, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.553e-04, train_time=0.634
# 00:37:43 19epoch:train:601-620batch: iter_time=1.353e-04, forward_time=0.102, loss_ctc=18.384, loss=18.384, backward_time=0.084, grad_norm=46.509, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.552e-04, train_time=0.661
# 00:37:50 19epoch:train:621-640batch: iter_time=1.703e-04, forward_time=0.100, loss_ctc=20.673, loss=20.673, backward_time=0.082, grad_norm=48.767, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.552e-04, train_time=0.646
# 00:37:56 19epoch:train:641-660batch: iter_time=1.826e-04, forward_time=0.097, loss_ctc=17.553, loss=17.553, backward_time=0.083, grad_norm=51.202, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.551e-04, train_time=0.636
# 00:38:02 19epoch:train:661-680batch: iter_time=2.425e-04, forward_time=0.092, loss_ctc=18.641, loss=18.641, backward_time=0.081, grad_norm=63.129, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.550e-04, train_time=0.602
# 00:38:09 19epoch:train:681-700batch: iter_time=1.423e-04, forward_time=0.102, loss_ctc=18.090, loss=18.090, backward_time=0.084, grad_norm=41.562, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.549e-04, train_time=0.662
# 00:38:15 19epoch:train:701-720batch: iter_time=1.593e-04, forward_time=0.103, loss_ctc=16.975, loss=16.975, backward_time=0.087, grad_norm=48.567, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.548e-04, train_time=0.671
# 00:38:21 19epoch:train:721-740batch: iter_time=1.333e-04, forward_time=0.095, loss_ctc=17.823, loss=17.823, backward_time=0.082, grad_norm=44.467, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.547e-04, train_time=0.620
# 00:38:27 19epoch:train:741-760batch: iter_time=1.614e-04, forward_time=0.088, loss_ctc=18.993, loss=18.993, backward_time=0.079, grad_norm=67.595, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.546e-04, train_time=0.581
# 00:38:34 19epoch:train:761-780batch: iter_time=1.597e-04, forward_time=0.095, loss_ctc=18.270, loss=18.270, backward_time=0.083, grad_norm=38.076, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.545e-04, train_time=0.624
# 00:38:39 19epoch:train:781-800batch: iter_time=1.781e-04, forward_time=0.086, loss_ctc=18.326, loss=18.326, backward_time=0.079, grad_norm=51.857, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.544e-04, train_time=0.571
# 00:38:45 19epoch:train:801-820batch: iter_time=1.832e-04, forward_time=0.095, loss_ctc=19.382, loss=19.382, backward_time=0.082, grad_norm=59.737, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.543e-04, train_time=0.619
# 00:38:52 19epoch:train:821-840batch: iter_time=1.594e-04, forward_time=0.115, loss_ctc=20.072, loss=20.072, backward_time=0.084, grad_norm=55.664, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.542e-04, train_time=0.691
# 00:38:58 19epoch:train:841-860batch: iter_time=1.418e-04, forward_time=0.090, loss_ctc=17.233, loss=17.233, backward_time=0.080, grad_norm=84.560, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.541e-04, train_time=0.591
# 00:39:04 19epoch:train:861-880batch: iter_time=1.920e-04, forward_time=0.095, loss_ctc=17.850, loss=17.850, backward_time=0.082, grad_norm=51.108, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.540e-04, train_time=0.625
# 00:39:27 19epoch results: [train] iter_time=2.701e-04, forward_time=0.095, loss_ctc=18.208, loss=18.208, backward_time=0.082, grad_norm=53.613, clip=100.000, loss_scale=1.039e+06, optim_step_time=0.006, optim0_lr0=1.560e-04, train_time=0.620, time=4 minutes and 35.83 seconds, total_count=16872, gpu_max_cached_mem_GB=21.773, [valid] loss_ctc=53.667, cer_ctc=0.928, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=53.667, time=19.7 seconds, total_count=3097, gpu_max_cached_mem_GB=21.773
# 00:39:34 There are no improvements in this epoch
# 00:39:34 The model files were removed: /content/exp/palabras/18epoch.pth
# 00:39:34 20/20epoch started. Estimated time to finish: 5 minutes and 0.91 seconds
# 00:39:40 20epoch:train:1-20batch: iter_time=0.006, forward_time=0.091, loss_ctc=19.526, loss=19.526, backward_time=0.081, grad_norm=79.251, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.539e-04, train_time=0.642
# 00:39:47 20epoch:train:21-40batch: iter_time=1.611e-04, forward_time=0.112, loss_ctc=20.950, loss=20.950, backward_time=0.090, grad_norm=55.334, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.538e-04, train_time=0.702
# 00:39:53 20epoch:train:41-60batch: iter_time=1.633e-04, forward_time=0.091, loss_ctc=17.779, loss=17.779, backward_time=0.081, grad_norm=49.965, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.537e-04, train_time=0.601
# 00:39:59 20epoch:train:61-80batch: iter_time=1.898e-04, forward_time=0.093, loss_ctc=19.159, loss=19.159, backward_time=0.083, grad_norm=56.847, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.536e-04, train_time=0.616
# 00:40:06 20epoch:train:81-100batch: iter_time=1.794e-04, forward_time=0.097, loss_ctc=18.084, loss=18.084, backward_time=0.084, grad_norm=62.306, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.536e-04, train_time=0.633
# 00:40:12 20epoch:train:101-120batch: iter_time=1.752e-04, forward_time=0.099, loss_ctc=17.810, loss=17.810, backward_time=0.083, grad_norm=60.374, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.535e-04, train_time=0.643
# 00:40:19 20epoch:train:121-140batch: iter_time=1.577e-04, forward_time=0.108, loss_ctc=18.620, loss=18.620, backward_time=0.090, grad_norm=68.618, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.534e-04, train_time=0.707
# 00:40:25 20epoch:train:141-160batch: iter_time=1.335e-04, forward_time=0.091, loss_ctc=17.009, loss=17.009, backward_time=0.079, grad_norm=47.585, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.533e-04, train_time=0.601
# 00:40:31 20epoch:train:161-180batch: iter_time=1.591e-04, forward_time=0.095, loss_ctc=19.822, loss=19.822, backward_time=0.081, grad_norm=55.468, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.532e-04, train_time=0.621
# 00:40:38 20epoch:train:181-200batch: iter_time=1.569e-04, forward_time=0.094, loss_ctc=20.061, loss=20.061, backward_time=0.080, grad_norm=64.796, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.531e-04, train_time=0.612
# 00:40:44 20epoch:train:201-220batch: iter_time=1.615e-04, forward_time=0.095, loss_ctc=16.116, loss=16.116, backward_time=0.083, grad_norm=55.059, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.530e-04, train_time=0.626
# 00:40:50 20epoch:train:221-240batch: iter_time=1.442e-04, forward_time=0.091, loss_ctc=16.716, loss=16.716, backward_time=0.082, grad_norm=42.153, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.529e-04, train_time=0.602
# 00:40:56 20epoch:train:241-260batch: iter_time=1.396e-04, forward_time=0.088, loss_ctc=18.164, loss=18.164, backward_time=0.078, grad_norm=49.584, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.528e-04, train_time=0.579
# 00:41:02 20epoch:train:261-280batch: iter_time=1.972e-04, forward_time=0.098, loss_ctc=18.787, loss=18.787, backward_time=0.082, grad_norm=45.239, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.527e-04, train_time=0.638
# 00:41:08 20epoch:train:281-300batch: iter_time=1.435e-04, forward_time=0.088, loss_ctc=18.037, loss=18.037, backward_time=0.080, grad_norm=52.007, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.527e-04, train_time=0.584
# 00:41:14 20epoch:train:301-320batch: iter_time=1.447e-04, forward_time=0.093, loss_ctc=18.540, loss=18.540, backward_time=0.081, grad_norm=60.699, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.526e-04, train_time=0.611
# 00:41:20 20epoch:train:321-340batch: iter_time=2.051e-04, forward_time=0.095, loss_ctc=18.244, loss=18.244, backward_time=0.082, grad_norm=47.372, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.525e-04, train_time=0.619
# 00:41:26 20epoch:train:341-360batch: iter_time=1.524e-04, forward_time=0.095, loss_ctc=17.359, loss=17.359, backward_time=0.082, grad_norm=45.130, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.524e-04, train_time=0.624
# 00:41:33 20epoch:train:361-380batch: iter_time=1.544e-04, forward_time=0.107, loss_ctc=19.494, loss=19.494, backward_time=0.088, grad_norm=69.993, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.523e-04, train_time=0.692
# 00:41:39 20epoch:train:381-400batch: iter_time=1.739e-04, forward_time=0.092, loss_ctc=16.753, loss=16.753, backward_time=0.079, grad_norm=53.022, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.522e-04, train_time=0.600
# 00:41:45 20epoch:train:401-420batch: iter_time=1.759e-04, forward_time=0.092, loss_ctc=18.140, loss=18.140, backward_time=0.079, grad_norm=79.747, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.521e-04, train_time=0.603
# 00:41:52 20epoch:train:421-440batch: iter_time=1.349e-04, forward_time=0.097, loss_ctc=17.913, loss=17.913, backward_time=0.083, grad_norm=56.058, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.520e-04, train_time=0.631
# 00:41:58 20epoch:train:441-460batch: iter_time=1.732e-04, forward_time=0.099, loss_ctc=17.481, loss=17.481, backward_time=0.083, grad_norm=48.286, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.519e-04, train_time=0.642
# 00:42:04 20epoch:train:461-480batch: iter_time=1.477e-04, forward_time=0.095, loss_ctc=17.719, loss=17.719, backward_time=0.082, grad_norm=53.028, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.519e-04, train_time=0.621
# 00:42:10 20epoch:train:481-500batch: iter_time=1.834e-04, forward_time=0.087, loss_ctc=18.456, loss=18.456, backward_time=0.077, grad_norm=44.466, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.518e-04, train_time=0.571
# 00:42:16 20epoch:train:501-520batch: iter_time=1.613e-04, forward_time=0.097, loss_ctc=18.837, loss=18.837, backward_time=0.085, grad_norm=51.662, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.517e-04, train_time=0.635
# 00:42:22 20epoch:train:521-540batch: iter_time=1.946e-04, forward_time=0.089, loss_ctc=18.904, loss=18.904, backward_time=0.080, grad_norm=47.247, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.516e-04, train_time=0.587
# 00:42:28 20epoch:train:541-560batch: iter_time=1.678e-04, forward_time=0.095, loss_ctc=17.575, loss=17.575, backward_time=0.080, grad_norm=51.033, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.515e-04, train_time=0.618
# 00:42:35 20epoch:train:561-580batch: iter_time=1.903e-04, forward_time=0.115, loss_ctc=16.770, loss=16.770, backward_time=0.086, grad_norm=50.860, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.514e-04, train_time=0.691
# 00:42:41 20epoch:train:581-600batch: iter_time=2.045e-04, forward_time=0.095, loss_ctc=19.854, loss=19.854, backward_time=0.082, grad_norm=50.784, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.513e-04, train_time=0.619
# 00:42:47 20epoch:train:601-620batch: iter_time=1.501e-04, forward_time=0.092, loss_ctc=21.321, loss=21.321, backward_time=0.080, grad_norm=54.671, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.513e-04, train_time=0.600
# 00:42:54 20epoch:train:621-640batch: iter_time=1.441e-04, forward_time=0.094, loss_ctc=19.646, loss=19.646, backward_time=0.081, grad_norm=47.573, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.512e-04, train_time=0.615
# 00:43:00 20epoch:train:641-660batch: iter_time=1.682e-04, forward_time=0.096, loss_ctc=15.918, loss=15.918, backward_time=0.084, grad_norm=40.561, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.511e-04, train_time=0.630
# 00:43:06 20epoch:train:661-680batch: iter_time=1.306e-04, forward_time=0.085, loss_ctc=16.401, loss=16.401, backward_time=0.076, grad_norm=60.617, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.510e-04, train_time=0.560
# 00:43:12 20epoch:train:681-700batch: iter_time=2.095e-04, forward_time=0.096, loss_ctc=16.932, loss=16.932, backward_time=0.081, grad_norm=56.353, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.509e-04, train_time=0.627
# 00:43:18 20epoch:train:701-720batch: iter_time=1.739e-04, forward_time=0.090, loss_ctc=17.960, loss=17.960, backward_time=0.077, grad_norm=51.525, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.508e-04, train_time=0.590
# 00:43:24 20epoch:train:721-740batch: iter_time=2.111e-04, forward_time=0.094, loss_ctc=16.685, loss=16.685, backward_time=0.083, grad_norm=45.628, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.507e-04, train_time=0.619
# 00:43:30 20epoch:train:741-760batch: iter_time=1.762e-04, forward_time=0.098, loss_ctc=17.313, loss=17.313, backward_time=0.084, grad_norm=50.363, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.506e-04, train_time=0.640
# 00:43:36 20epoch:train:761-780batch: iter_time=1.898e-04, forward_time=0.092, loss_ctc=19.423, loss=19.423, backward_time=0.079, grad_norm=66.120, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.506e-04, train_time=0.602
# 00:43:42 20epoch:train:781-800batch: iter_time=1.459e-04, forward_time=0.090, loss_ctc=16.737, loss=16.737, backward_time=0.078, grad_norm=57.410, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.505e-04, train_time=0.588
# 00:43:48 20epoch:train:801-820batch: iter_time=1.713e-04, forward_time=0.093, loss_ctc=21.059, loss=21.059, backward_time=0.079, grad_norm=70.551, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.504e-04, train_time=0.604
# 00:43:54 20epoch:train:821-840batch: iter_time=1.646e-04, forward_time=0.091, loss_ctc=19.946, loss=19.946, backward_time=0.079, grad_norm=53.494, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.503e-04, train_time=0.598
# 00:44:01 20epoch:train:841-860batch: iter_time=1.724e-04, forward_time=0.097, loss_ctc=16.175, loss=16.175, backward_time=0.083, grad_norm=54.850, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.502e-04, train_time=0.636
# 00:44:07 20epoch:train:861-880batch: iter_time=1.922e-04, forward_time=0.098, loss_ctc=16.274, loss=16.274, backward_time=0.085, grad_norm=50.570, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.501e-04, train_time=0.643
# 00:44:29 20epoch results: [train] iter_time=2.890e-04, forward_time=0.095, loss_ctc=18.128, loss=18.128, backward_time=0.082, grad_norm=54.760, clip=100.000, loss_scale=1.049e+06, optim_step_time=0.006, optim0_lr0=1.520e-04, train_time=0.620, time=4 minutes and 35.71 seconds, total_count=17760, gpu_max_cached_mem_GB=21.773, [valid] loss_ctc=53.617, cer_ctc=0.902, loss_att=nan, acc=nan, cer=nan, wer=nan, loss=53.617, time=19.67 seconds, total_count=3260, gpu_max_cached_mem_GB=21.773
# 00:44:33 There are no improvements in this epoch
# 00:44:33 The model files were removed: /content/exp/palabras/19epoch.pth
# 00:44:33 The training was finished at 20 epochs

# %% [markdown]
# ## 8. Métricas
#
# Se leen del log que acaba de escribir ESPnet. La métrica que importa es
# `cer_ctc` de validación: es la tasa de error por carácter de la decodificación
# voraz de la rama CTC, y la calcula el propio ESPnet con su `ErrorCalculator`.

# %%
filas = []
for linea in open(LOG_PATH, errors="ignore"):
    m = re.search(r"(\d+)epoch results:(.*)", linea)
    if not m:
        continue
    ep, resto = int(m.group(1)), m.group(2)
    fila = {"epoch": ep}
    for split in ("train", "valid"):
        trozo = re.search(rf"\[{split}\](.*?)(?=\[|$)", resto)
        if trozo:
            for k, v in re.findall(r"(\w+)=([-\d.]+(?:[eE][-+]?\d+)?)", trozo.group(1)):
                fila[f"{split}_{k}"] = float(v)
    filas.append(fila)

hist = pd.DataFrame(filas).drop_duplicates("epoch").sort_values("epoch")
cols = [c for c in ["epoch", "train_loss", "valid_loss", "train_loss_ctc",
                    "valid_loss_ctc", "valid_cer_ctc"] if c in hist.columns]
display(hist[cols].tail(10))
# Out:
#     epoch  train_loss  valid_loss  train_loss_ctc  valid_loss_ctc  \
# 10     11      18.795      50.430          18.795          50.430
# 11     12      18.731      51.056          18.731          51.056
# 12     13      18.625      52.144          18.625          52.144
# 13     14      18.554      51.349          18.554          51.349
# 14     15      18.479      52.192          18.479          52.192
# 15     16      18.392      52.807          18.392          52.807
# 16     17      18.320      53.033          18.320          53.033
# 17     18      18.272      53.597          18.272          53.597
# 18     19      18.208      53.667          18.208          53.667
# 19     20      18.128      53.617          18.128          53.617
#
#     valid_cer_ctc
# 10          0.932
# 11          0.924
# 12          0.904
# 13          0.929
# 14          0.912
# 15          0.922
# 16          0.880
# 17          0.939
# 18          0.928
# 19          0.902

# %%
fig, ax = plt.subplots(1, 2, figsize=(13, 4))

for c, col in [("train_loss", "steelblue"), ("valid_loss", "indianred")]:
    if c in hist: ax[0].plot(hist["epoch"], hist[c], label=c, color=col)
ax[0].set_xlabel("época"); ax[0].set_ylabel("pérdida"); ax[0].legend()
ax[0].set_title("Pérdida"); ax[0].grid(alpha=.3)

if "valid_cer_ctc" in hist:
    ax[1].plot(hist["epoch"], hist["valid_cer_ctc"], color="darkgreen")
    mejor = hist["valid_cer_ctc"].min()
    ax[1].axhline(mejor, ls="--", c="gray")
    ax[1].text(hist["epoch"].iloc[0], mejor, f"  mínimo {mejor:.3f}", va="bottom")
ax[1].set_xlabel("época"); ax[1].set_ylabel("CER"); ax[1].set_ylim(0, 1.6)
ax[1].set_title("CER de la rama CTC (validación)"); ax[1].grid(alpha=.3)

plt.tight_layout(); plt.show()

# %% [markdown]
# ## 9. Inferencia
#
# Con `ctc_weight = 1.0` el decodificador autorregresivo no participa en la
# pérdida, así que la salida del sistema es la de la rama CTC. Decodificamos con
# la regla voraz: el token más probable en cada frame, y luego la función de
# colapso de CTC (quitar repeticiones, quitar blancos).

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

ckpt = next(p for p in [f"{EXP_DIR}/valid.loss.best.pth",
                        f"{EXP_DIR}/valid.acc.best.pth",
                        f"{EXP_DIR}/train.loss.best.pth"] if os.path.exists(p))
print("Checkpoint:", os.path.basename(ckpt))

modelo = build_model_fn(None)
modelo.load_state_dict(torch.load(ckpt, map_location="cpu"))
modelo.to(device).eval()
# Out:
# Checkpoint: valid.loss.best.pth
# 00:44:33 Vocabulary size: 50002
# 00:44:34 Gradient checkpoint layers: []
# 00:44:34 Gradient checkpoint layers: []
# 00:44:35 Set decoder to none as ctc_weight==1.0
# Parámetros totales     : 64,456,018
# Parámetros entrenables : 64,456,018 (100.0 %)
# ESPnetS2TModel(
#   (frontend): None
#   (normalize): None
#   (encoder): EBranchformerEncoder(
#     (embed): Conv2dSubsampling(
#       (conv): Sequential(
#         (0): Conv2d(1, 384, kernel_size=(3, 3), stride=(2, 2))
#         (1): ReLU()
#         (2): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2))
#         (3): ReLU()
#       )
#       (out): Sequential(
#         (0): Linear(in_features=48768, out_features=384, bias=True)
#         (1): PositionalEncoding(
#           (dropout): Dropout(p=0.05, inplace=False)
#         )
#       )
#     )
#     (encoders): MultiSequential(
#       (0): EBranchformerEncoderLayer(
#         (attn): MultiHeadedAttention(
#           (linear_q): Linear(in_features=384, out_features=384, bias=True)
#           (linear_k): Linear(in_features=384, out_features=384, bias=True)
#           (linear_v): Linear(in_features=384, out_features=384, bias=True)
#           (linear_out): Linear(in_features=384, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (q_norm): Identity()
#           (k_norm): Identity()
#         )
#         (cgmlp): ConvolutionalGatingMLP(
#           (channel_proj1): Sequential(
#             (0): Linear(in_features=384, out_features=1536, bias=True)
#             (1): GELU(approximate='none')
#           )
#           (csgu): ConvolutionalSpatialGatingUnit(
#             (norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (conv): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#             (act): Identity()
#             (dropout): Dropout(p=0.05, inplace=False)
#           )
#           (channel_proj2): Linear(in_features=768, out_features=384, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (feed_forward_macaron): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (norm_ff): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_ff_macaron): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mha): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mlp): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_final): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.05, inplace=False)
#         (depthwise_conv_fusion): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#         (merge_proj): Linear(in_features=768, out_features=384, bias=True)
#       )
#       (1): EBranchformerEncoderLayer(
#         (attn): MultiHeadedAttention(
#           (linear_q): Linear(in_features=384, out_features=384, bias=True)
#           (linear_k): Linear(in_features=384, out_features=384, bias=True)
#           (linear_v): Linear(in_features=384, out_features=384, bias=True)
#           (linear_out): Linear(in_features=384, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (q_norm): Identity()
#           (k_norm): Identity()
#         )
#         (cgmlp): ConvolutionalGatingMLP(
#           (channel_proj1): Sequential(
#             (0): Linear(in_features=384, out_features=1536, bias=True)
#             (1): GELU(approximate='none')
#           )
#           (csgu): ConvolutionalSpatialGatingUnit(
#             (norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (conv): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#             (act): Identity()
#             (dropout): Dropout(p=0.05, inplace=False)
#           )
#           (channel_proj2): Linear(in_features=768, out_features=384, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (feed_forward_macaron): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (norm_ff): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_ff_macaron): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mha): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mlp): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_final): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.05, inplace=False)
#         (depthwise_conv_fusion): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#         (merge_proj): Linear(in_features=768, out_features=384, bias=True)
#       )
#       (2): EBranchformerEncoderLayer(
#         (attn): MultiHeadedAttention(
#           (linear_q): Linear(in_features=384, out_features=384, bias=True)
#           (linear_k): Linear(in_features=384, out_features=384, bias=True)
#           (linear_v): Linear(in_features=384, out_features=384, bias=True)
#           (linear_out): Linear(in_features=384, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (q_norm): Identity()
#           (k_norm): Identity()
#         )
#         (cgmlp): ConvolutionalGatingMLP(
#           (channel_proj1): Sequential(
#             (0): Linear(in_features=384, out_features=1536, bias=True)
#             (1): GELU(approximate='none')
#           )
#           (csgu): ConvolutionalSpatialGatingUnit(
#             (norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (conv): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#             (act): Identity()
#             (dropout): Dropout(p=0.05, inplace=False)
#           )
#           (channel_proj2): Linear(in_features=768, out_features=384, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (feed_forward_macaron): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (norm_ff): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_ff_macaron): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mha): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mlp): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_final): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.05, inplace=False)
#         (depthwise_conv_fusion): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#         (merge_proj): Linear(in_features=768, out_features=384, bias=True)
#       )
#       (3): EBranchformerEncoderLayer(
#         (attn): MultiHeadedAttention(
#           (linear_q): Linear(in_features=384, out_features=384, bias=True)
#           (linear_k): Linear(in_features=384, out_features=384, bias=True)
#           (linear_v): Linear(in_features=384, out_features=384, bias=True)
#           (linear_out): Linear(in_features=384, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (q_norm): Identity()
#           (k_norm): Identity()
#         )
#         (cgmlp): ConvolutionalGatingMLP(
#           (channel_proj1): Sequential(
#             (0): Linear(in_features=384, out_features=1536, bias=True)
#             (1): GELU(approximate='none')
#           )
#           (csgu): ConvolutionalSpatialGatingUnit(
#             (norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (conv): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#             (act): Identity()
#             (dropout): Dropout(p=0.05, inplace=False)
#           )
#           (channel_proj2): Linear(in_features=768, out_features=384, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (feed_forward_macaron): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (norm_ff): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_ff_macaron): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mha): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mlp): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_final): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.05, inplace=False)
#         (depthwise_conv_fusion): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#         (merge_proj): Linear(in_features=768, out_features=384, bias=True)
#       )
#       (4): EBranchformerEncoderLayer(
#         (attn): MultiHeadedAttention(
#           (linear_q): Linear(in_features=384, out_features=384, bias=True)
#           (linear_k): Linear(in_features=384, out_features=384, bias=True)
#           (linear_v): Linear(in_features=384, out_features=384, bias=True)
#           (linear_out): Linear(in_features=384, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (q_norm): Identity()
#           (k_norm): Identity()
#         )
#         (cgmlp): ConvolutionalGatingMLP(
#           (channel_proj1): Sequential(
#             (0): Linear(in_features=384, out_features=1536, bias=True)
#             (1): GELU(approximate='none')
#           )
#           (csgu): ConvolutionalSpatialGatingUnit(
#             (norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (conv): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#             (act): Identity()
#             (dropout): Dropout(p=0.05, inplace=False)
#           )
#           (channel_proj2): Linear(in_features=768, out_features=384, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (feed_forward_macaron): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (norm_ff): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_ff_macaron): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mha): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mlp): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_final): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.05, inplace=False)
#         (depthwise_conv_fusion): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#         (merge_proj): Linear(in_features=768, out_features=384, bias=True)
#       )
#       (5): EBranchformerEncoderLayer(
#         (attn): MultiHeadedAttention(
#           (linear_q): Linear(in_features=384, out_features=384, bias=True)
#           (linear_k): Linear(in_features=384, out_features=384, bias=True)
#           (linear_v): Linear(in_features=384, out_features=384, bias=True)
#           (linear_out): Linear(in_features=384, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (q_norm): Identity()
#           (k_norm): Identity()
#         )
#         (cgmlp): ConvolutionalGatingMLP(
#           (channel_proj1): Sequential(
#             (0): Linear(in_features=384, out_features=1536, bias=True)
#             (1): GELU(approximate='none')
#           )
#           (csgu): ConvolutionalSpatialGatingUnit(
#             (norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (conv): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#             (act): Identity()
#             (dropout): Dropout(p=0.05, inplace=False)
#           )
#           (channel_proj2): Linear(in_features=768, out_features=384, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (feed_forward_macaron): PositionwiseFeedForward(
#           (w_1): Linear(in_features=384, out_features=1536, bias=True)
#           (w_2): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.05, inplace=False)
#           (activation): Swish()
#         )
#         (norm_ff): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_ff_macaron): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mha): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_mlp): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (norm_final): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.05, inplace=False)
#         (depthwise_conv_fusion): Conv1d(768, 768, kernel_size=(31,), stride=(1,), padding=(15,), groups=768)
#         (merge_proj): Linear(in_features=768, out_features=384, bias=True)
#       )
#     )
#     (after_norm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#   )
#   (criterion_att): LabelSmoothingLoss(
#     (criterion): KLDivLoss()
#   )
#   (ctc): CTC(
#     (ctc_lo): Linear(in_features=384, out_features=50002, bias=True)
#     (ctc_loss): CTCLoss()
#   )
# )

# %%
N = min(150, len(val_trials))
filas = []
for t in val_trials[:N]:
    hyp, blanco, _ = eeg.decodificar_voraz(
        modelo, t["input_features"], device, tokenizer, converter,
        blank=modelo.blank_id)
    filas.append({
        "referencia": eeg.normalizar_para_evaluar(t["text_raw"]),
        "hipótesis":  eeg.normalizar_para_evaluar(hyp),
        "blancos":    blanco,
        "cer":        eeg.tasa_error(t["text_raw"], hyp, "caracter"),
        "wer":        eeg.tasa_error(t["text_raw"], hyp, "palabra"),
    })
pred = pd.DataFrame(filas)

print(f"Evaluado sobre {len(pred)} trials de validación\n")
print(f"  CER  : {pred['cer'].mean():.3f}")
print(f"  WER  : {pred['wer'].mean():.3f}")
print(f"  Tasa media de blancos por frame : {pred['blancos'].mean():.1%}")
print(f"  Hipótesis vacías                : {(pred['hipótesis'].str.len()==0).mean():.1%}")
print(f"  Hipótesis distintas             : {pred['hipótesis'].nunique()} de {len(pred)}")
# Out:
# /usr/local/lib/python3.13/dist-packages/espnet2/s2t/espnet_model.py:338: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(False):
# Evaluado sobre 150 trials de validación
#
#   CER  : 0.998
#   WER  : 0.997
#   Tasa media de blancos por frame : 100.0%
#   Hipótesis vacías                : 92.0%
#   Hipótesis distintas             : 2 de 150

# %%
pd.set_option("display.max_colwidth", 60)
display(pred[["referencia", "hipótesis", "cer", "wer"]].head(15))
# Out:
#                                       referencia hipótesis  cer  wer
# 0     you can see the code at this point as well            1.0  1.0
# 1                 how does it keep the cost down            1.0  1.0
# 2                          not too controversial            1.0  1.0
# 3       the jury and a judge work together on it            1.0  1.0
# 4                      were quite vocal about it            1.0  1.0
# 5   he said the decision to part ways was mutual            1.0  1.0
# 6    in fact this morning when they were talking            1.0  1.0
# 7                    this is like a cruelty joke            1.0  1.0
# 8                   has such a high clay content            1.0  1.0
# 9                            woodworking mastery            1.0  1.0
# 10         wait a minute we know this thing isnt            1.0  1.0
# 11               up in new england where im from            1.0  1.0
# 12                        one thing or the other            1.0  1.0
# 13         hes one of the big proponents of that            1.0  1.0
# 14                   i have not gone back lately            1.0  1.0

# %% [markdown]
# ## 10. Por qué esto no podía funcionar
#
# Hasta aquí, todo lo anterior es el notebook que me pedisteis: la adaptación
# hecha, el modelo entrenado y una inferencia. El resultado es malo. La pregunta
# de la segunda reunión era si eso se debe a un error de programación.
#
# No lo es, y esta sección lo demuestra en dos pasos: primero la aritmética del
# problema, y después un control experimental.
#
# ### 10.1 La aritmética del vocabulario
#
# El objetivo CTC de este notebook son las subpalabras de OWSM, que es el
# vocabulario que trae el modelo. Vamos a contar cuántas hay y cuántas veces se
# observa cada una.

# %%
V = len(converter.token_list)
todos = np.concatenate([tokenize(train_raw[i]["text_ctc"]) for i in range(len(train_raw))])
vistos, cuentas = np.unique(todos, return_counts=True)
d_model = modelo.encoder.output_size()

print("EL OBJETIVO CTC")
print("-" * 66)
print(f"  Vocabulario de OWSM                    : {V:,} clases")
print(f"  Frases de entrenamiento                : {len(train_raw):,}")
print(f"  Tokens objetivo en total               : {len(todos):,}")
print(f"  Media de tokens por frase              : {len(todos)/len(train_raw):.1f}")
print()
print(f"  Clases observadas al menos una vez     : {len(vistos):,} "
      f"({len(vistos)/V:.2%} del vocabulario)")
print(f"  Clases NUNCA observadas                : {V-len(vistos):,} "
      f"({1-len(vistos)/V:.2%})")
print(f"  Clases observadas una sola vez         : {(cuentas==1).sum():,}")
print()
print(f"  Parámetros de la cabeza CTC            : {d_model} x {V} = {d_model*V:,}")
print(f"  Observaciones por parámetro de la cabeza: {len(todos)/(d_model*V):.4f}")
# Out:
# EL OBJETIVO CTC
# ------------------------------------------------------------------
#   Vocabulario de OWSM                    : 50,002 clases
#   Frases de entrenamiento                : 8,072
#   Tokens objetivo en total               : 53,619
#   Media de tokens por frase              : 6.6
#
#   Clases observadas al menos una vez     : 3,643 (7.29% del vocabulario)
#   Clases NUNCA observadas                : 46,359 (92.71%)
#   Clases observadas una sola vez         : 1,536
#
#   Parámetros de la cabeza CTC            : 384 x 50002 = 19,200,768
#   Observaciones por parámetro de la cabeza: 0.0028

# %%
fig, ax = plt.subplots(1, 2, figsize=(13, 3.8))

ax[0].bar(["observadas", "nunca vistas"], [len(vistos), V - len(vistos)],
          color=["steelblue", "lightgray"], edgecolor="black")
ax[0].set_ylabel("nº de clases"); ax[0].set_title(f"Cobertura del vocabulario (V = {V:,})")
for i, v in enumerate([len(vistos), V - len(vistos)]):
    ax[0].text(i, v, f"{v:,}", ha="center", va="bottom")

ax[1].hist(cuentas, bins=np.logspace(0, np.log10(cuentas.max()), 40),
           color="steelblue", edgecolor="white")
ax[1].set_xscale("log"); ax[1].set_yscale("log")
ax[1].set_xlabel("veces que aparece la clase"); ax[1].set_ylabel("nº de clases")
ax[1].set_title("Frecuencia de las clases observadas")

plt.tight_layout(); plt.show()

# %% [markdown]
# El resultado es el esperable de esos números. CTC asume independencia
# condicional entre posiciones: cada frame es una clasificación entre las 50.002
# clases **sin ningún contexto lingüístico**. Con la inmensa mayoría del
# vocabulario sin observar ni una sola vez, la forma de minimizar la pérdida es
# emitir blanco casi siempre y, cuando no, uno de los pocos tokens frecuentes.
# Eso es exactamente lo que muestra la tasa de blancos de la sección 9.
#
# El problema no es que el modelo esté mal entrenado. Es que **el objetivo no es
# aprendible con esta cantidad de datos**, y ninguna corrección de código lo
# arregla.
#
# ### 10.2 El control: ¿es el código o es la tarea?
#
# Si hubiera un error de programación —la señal no llega, los gradientes no
# fluyen, las etiquetas están desalineadas— el modelo **no podría ni memorizar**
# un puñado de frases.
#
# Vuelve a la sección 1, pon `MODO = "overfit"` y ejecuta el notebook entero.
# Eso entrena con una sola sesión y con `validación = entrenamiento`, con
# exactamente el mismo código: mismo `build_model_fn`, mismo `data_info`, mismo
# `Trainer`.
#
# Los dos desenlaces posibles, y qué significa cada uno:
#
# | Resultado del control | Interpretación |
# |---|---|
# | El CER **no baja** | Hay un error real en el código. Habría que buscarlo. |
# | El CER **baja mucho** | El pipeline es correcto. El fracaso de 10.1 es de generalización y escala de datos, no de programación. |
#
# En mis ejecuciones el CER de este control baja hasta ~0,12, es decir, el
# segundo caso. Anota aquí abajo el número que te salga a ti:

# %%
# Ejecutar DESPUÉS de haber corrido el notebook en los dos modos.
# Rellena a mano con el mínimo de valid_cer_ctc de cada ejecución.
resumen = pd.DataFrame([
    {"modo": "overfit (val = train)", "sesiones": 1,  "cer_ctc": None},
    {"modo": "palabras (val real)",   "sesiones": 10, "cer_ctc": None},
])
display(resumen)

print("Mínimo de valid_cer_ctc en esta ejecución "
      f"({MODO}): {hist['valid_cer_ctc'].min():.3f}"
      if "valid_cer_ctc" in hist else "sin valid_cer_ctc en el log")
# Out:
#                     modo  sesiones cer_ctc
# 0  overfit (val = train)         1    None
# 1    palabras (val real)        10    None
# Mínimo de valid_cer_ctc en esta ejecución (palabras): 0.880

# %% [markdown]
# ## Conclusión
#
# Lo que queda establecido en este notebook:
#
# 1. **La adaptación de ESPnet está hecha y es correcta.** Son cuatro cambios
#    localizados (`espnet_eeg.py`), y el modelo procesa señal de 512 canales de
#    principio a fin, como se comprueba en la sección 4.
# 2. **Con el vocabulario de subpalabras de OWSM el problema no es aprendible**
#    a esta escala: más del 99 % del vocabulario no aparece ni una vez en el
#    entrenamiento, y la cabeza CTC tiene más parámetros que tokens de
#    entrenamiento hay en total.
# 3. **No es un error de programación**, y el control de sobreajuste de la
#    sección 10.2 lo demuestra con el mismo código.
#
# La conclusión que se sigue es que hay que **cambiar la unidad de salida**, no
# seguir depurando. Es lo que hago en los dos notebooks siguientes:
#
# - **Caracteres** (~30 clases en vez de 50.002), que es la configuración con la
#   que el sistema empieza a funcionar de verdad.
# - **Fonemas**, que es la unidad estándar en la literatura de neuroprótesis del
#   habla, y que permite comparar con Willett *et al.* y con el sistema de
#   referencia oficial del reto.
#
# Sobre esas salidas sí tiene sentido añadir un modelo de lenguaje de $n$-gramas
# por fusión superficial, porque CTC no aporta ninguno por su cuenta.
